# %%
import pandas as pd
import requests
import json
import geopandas as gp
import numpy as np

# %%
poligonos = gp.read_file("../archivos_originales/889463142683_s/conjunto_de_datos/areas_geoestadisticas_municipales.shp")

# %%
poligonos.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2458 entries, 0 to 2457
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CVE_ENT   2458 non-null   object
#  1   CVE_MUN   2458 non-null   object
#  2   NOM_MUN   2458 non-null   object
#  3   geometry  2458 non-null   geometry
# dtypes: geometry(1), object(3)
# memory usage: 76.9+ KB

# %%
poligonos
# Out:
#      CVE_ENT CVE_MUN                    NOM_MUN  \
# 0         01     002                   Asientos
# 1         01     011  San Francisco de los Romo
# 2         01     007            Rincón de Romos
# 3         01     008         San José de Gracia
# 4         01     005                Jesús María
# ...      ...     ...                        ...
# 2453      15     090          Tenango del Valle
# 2454      15     106                     Toluca
# 2455      15     058             Nezahualcóyotl
# 2456      09     005          Gustavo A. Madero
# 2457      20     227     San Lorenzo Cacaotepec
#
#                                                geometry
# 0     POLYGON ((2494680.261 1141224.506, 2494749.948...
# 1     POLYGON ((2471901.164 1118837.535, 2471903.404...
# 2     POLYGON ((2476760.231 1150329.046, 2476783.634...
# 3     POLYGON ((2453254.179 1144800.521, 2453326.553...
# 4     POLYGON ((2466710.861 1102163.965, 2466673.583...
# ...

# %%
poligonos_df = poligonos.to_crs("EPSG:4326")
poligonos_df["geometry"] = poligonos_df["geometry"].simplify(tolerance = 0.001, preserve_topology = True)

# %%
poligonos_df
# Out:
#      CVE_ENT CVE_MUN                    NOM_MUN  \
# 0         01     002                   Asientos
# 1         01     011  San Francisco de los Romo
# 2         01     007            Rincón de Romos
# 3         01     008         San José de Gracia
# 4         01     005                Jesús María
# ...      ...     ...                        ...
# 2453      15     090          Tenango del Valle
# 2454      15     106                     Toluca
# 2455      15     058             Nezahualcóyotl
# 2456      09     005          Gustavo A. Madero
# 2457      20     227     San Lorenzo Cacaotepec
#
#                                                geometry
# 0     POLYGON ((-102.05189 22.29144, -102.04348 22.2...
# 1     POLYGON ((-102.27368 22.08798, -102.26852 22.0...
# 2     POLYGON ((-102.22684 22.37393, -102.22517 22.3...
# 3     POLYGON ((-102.45611 22.32323, -102.45537 22.3...
# 4     POLYGON ((-102.32387 21.93653, -102.34340 21.9...
# ...

# %%
poligonos_df.to_file("estados.geojson", driver='GeoJSON')
