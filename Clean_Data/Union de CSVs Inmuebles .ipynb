# %%
# Dependencies and Setup
import pandas as pd

#Import CSV of Scrapping from 1M to 1.25M

file_to_load_Pue1 = "SCRAPPING ML/DE 1M a 1.25M/PropiedadesPuebla1.csv"
file_to_load_Mor1 = "SCRAPPING ML/DE 1M a 1.25M/PropiedadesMorelos1.csv"
file_to_load_Hgo1 = "SCRAPPING ML/DE 1M a 1.25M/PropiedadesHidalgo1.csv"
file_to_load_EDOMEX1 = "SCRAPPING ML/DE 1M a 1.25M/Propiedadesestado-de-mexico1.csv"
file_to_load_CDMX1 = "SCRAPPING ML/DE 1M a 1.25M/Propiedadesdistrito-federal1.csv"

# Read CSVs and store into Pandas data frames
Puebla1_DF = pd.read_csv(file_to_load_Pue1)
Morelos1_DF = pd.read_csv(file_to_load_Mor1)
Hidalgo1_DF = pd.read_csv(file_to_load_Hgo1)
EDOMEX1_DF = pd.read_csv(file_to_load_EDOMEX1)
CDMX1_DF = pd.read_csv(file_to_load_CDMX1)

# %%
# JOIN all STATE_DF1

Megalopolis1_DF = [Puebla1_DF, Morelos1_DF, Hidalgo1_DF, EDOMEX1_DF, CDMX1_DF]
Megalopolis1_DF = pd.concat(Megalopolis1_DF)
Megalopolis1_DF
# Out:
#      Categoria   Tipo  V o R                 Propiedad            Ciudad  \
# 0    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 1    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 2    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 3    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 4    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# ..         ...    ...    ...                       ...               ...
# 188  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 189  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 190  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 191  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 192  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
#
#              Municipio                    Colonia     Precio  \
# ...

# %%
#Import CSV of Scrapping from 1.25M to 1.5M

file_to_load_Pue2 = "SCRAPPING ML/DE 1.24M a 1.49M/PropiedadesPuebla2.csv"
file_to_load_Mor2 = "SCRAPPING ML/DE 1.24M a 1.49M/PropiedadesMorelos2.csv"
file_to_load_Hgo2 = "SCRAPPING ML/DE 1.24M a 1.49M/PropiedadesHidalgo2.csv"
file_to_load_EDOMEX2 = "SCRAPPING ML/DE 1.24M a 1.49M/Propiedadesestado-de-mexico2.csv"
file_to_load_CDMX2 = "SCRAPPING ML/DE 1.24M a 1.49M/Propiedadesdistrito-federal2.csv"

# Read CSVs and store into Pandas data frames
Puebla2_DF = pd.read_csv(file_to_load_Pue2)
Morelos2_DF = pd.read_csv(file_to_load_Mor2)
Hidalgo2_DF = pd.read_csv(file_to_load_Hgo2)
EDOMEX2_DF = pd.read_csv(file_to_load_EDOMEX2)
CDMX2_DF = pd.read_csv(file_to_load_CDMX2)

# %%
# JOIN all STATE_DF2

Megalopolis2_DF = [Puebla2_DF, Morelos2_DF, Hidalgo2_DF, EDOMEX2_DF, CDMX2_DF]
Megalopolis2_DF = pd.concat(Megalopolis2_DF)
Megalopolis2_DF
# Out:
#      Categoria   Tipo  V o R                 Propiedad            Ciudad  \
# 0    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 1    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 2    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 3    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 4    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# ..         ...    ...    ...                       ...               ...
# 164  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 165  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 166  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 167  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 168  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
#
#               Municipio                      Colonia     Precio  \
# ...

# %%
#Import CSV of Scrapping from 1.5M to 1.75M

file_to_load_Pue3 = "SCRAPPING ML/DE 1.5M a 1.74M/PropiedadesPuebla3.csv"
file_to_load_Mor3 = "SCRAPPING ML/DE 1.5M a 1.74M/PropiedadesMorelos3.csv"
file_to_load_Hgo3 = "SCRAPPING ML/DE 1.5M a 1.74M/PropiedadesHidalgo3.csv"
file_to_load_EDOMEX3 = "SCRAPPING ML/DE 1.5M a 1.74M/Propiedadesestado-de-mexico3.csv"
file_to_load_CDMX3 = "SCRAPPING ML/DE 1.5M a 1.74M/Propiedadesdistrito-federal3.csv"

# Read CSVs and store into Pandas data frames
Puebla3_DF = pd.read_csv(file_to_load_Pue3)
Morelos3_DF = pd.read_csv(file_to_load_Mor3)
Hidalgo3_DF = pd.read_csv(file_to_load_Hgo3)
EDOMEX3_DF = pd.read_csv(file_to_load_EDOMEX3)
CDMX3_DF = pd.read_csv(file_to_load_CDMX3)

# %%
# JOIN all STATE_DF3

Megalopolis3_DF = [Puebla3_DF, Morelos3_DF, Hidalgo3_DF, EDOMEX3_DF, CDMX3_DF]
Megalopolis3_DF = pd.concat(Megalopolis3_DF)
Megalopolis3_DF
# Out:
#      Categoria   Tipo  V o R                 Propiedad            Ciudad  \
# 0    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 1    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 2    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 3    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 4    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# ..         ...    ...    ...                       ...               ...
# 157  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 158  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 159  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 160  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 161  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
#
#              Municipio                         Colonia     Precio  \
# ...

# %%
#Import CSV of Scrapping from 1.75M to 2M

file_to_load_Pue4 = "SCRAPPING ML/De 1.75M a 2M/PropiedadesPuebla4.csv"
file_to_load_Mor4 = "SCRAPPING ML/De 1.75M a 2M/PropiedadesMorelos4.csv"
file_to_load_Hgo4 = "SCRAPPING ML/De 1.75M a 2M/PropiedadesHidalgo4.csv"
file_to_load_EDOMEX4 = "SCRAPPING ML/De 1.75M a 2M/Propiedadesestado-de-mexico4.csv"
file_to_load_CDMX4 = "SCRAPPING ML/De 1.75M a 2M/Propiedadesdistrito-federal4.csv"

# Read CSVs and store into Pandas data frames
Puebla4_DF = pd.read_csv(file_to_load_Pue4)
Morelos4_DF = pd.read_csv(file_to_load_Mor4)
Hidalgo4_DF = pd.read_csv(file_to_load_Hgo4)
EDOMEX4_DF = pd.read_csv(file_to_load_EDOMEX4)
CDMX4_DF = pd.read_csv(file_to_load_CDMX4)

# %%
# JOIN all STATE_DF3

Megalopolis4_DF = [Puebla4_DF, Morelos4_DF, Hidalgo4_DF, EDOMEX4_DF, CDMX4_DF]
Megalopolis4_DF = pd.concat(Megalopolis4_DF)
Megalopolis4_DF
# Out:
#      Categoria   Tipo  V o R                 Propiedad            Ciudad  \
# 0    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 1    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 2    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 3    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# 4    Inmuebles  Casas  Venta  Propiedades Individuales            Puebla
# ..         ...    ...    ...                       ...               ...
# 182  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 183  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 184  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 185  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
# 186  Inmuebles  Casas  Venta  Propiedades Individuales  Distrito Federal
#
#               Municipio                    Colonia     Precio  \
# ...

# %%
#Import CSV of Scrapping TLAXCALA

file_to_load_Tlx = "SCRAPPING ML/PropiedadesTlaxcala4.csv"

# Read CSVs and store into Pandas data frames
Tlaxcala_DF = pd.read_csv(file_to_load_Tlx)
Tlaxcala_DF
# Out:
#     Categoria   Tipo  V o R                 Propiedad    Ciudad  \
# 0   Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 1   Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 2   Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 3   Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 4   Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 5   Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 6   Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 7   Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 8   Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 9   Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 10  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 11  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 12  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 13  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# ...

# %%
# JOIN All MEGALOPOLIS

Megalopolis_DF = [Megalopolis1_DF, Megalopolis2_DF, Megalopolis3_DF, Megalopolis4_DF, Tlaxcala_DF]
Megalopolis_DF = pd.concat(Megalopolis_DF)
Megalopolis_DF
# Out:
#     Categoria   Tipo  V o R                 Propiedad    Ciudad  \
# 0   Inmuebles  Casas  Venta  Propiedades Individuales    Puebla
# 1   Inmuebles  Casas  Venta  Propiedades Individuales    Puebla
# 2   Inmuebles  Casas  Venta  Propiedades Individuales    Puebla
# 3   Inmuebles  Casas  Venta  Propiedades Individuales    Puebla
# 4   Inmuebles  Casas  Venta  Propiedades Individuales    Puebla
# ..        ...    ...    ...                       ...       ...
# 37  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 38  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 39  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 40  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 41  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
#
#         Municipio                    Colonia     Precio  \
# 0   Cuautlancingo  Misiones de San Francisco  1,150,000
# 1   Cuautlancingo                  4 Caminos  1,150,000
# ...

# %%
Megalopolis_DF =Megalopolis_DF.drop(columns=['Pilar'])

# %%
Megalopolis_DF.dropna(
    axis=0,
    how='any',
    thresh=None,
    subset=None,
    inplace=True
)


Megalopolis_DF
# Out:
#      Categoria   Tipo  V o R                 Propiedad  Ciudad  \
# 0    Inmuebles  Casas  Venta  Propiedades Individuales  Puebla
# 2    Inmuebles  Casas  Venta  Propiedades Individuales  Puebla
# 3    Inmuebles  Casas  Venta  Propiedades Individuales  Puebla
# 4    Inmuebles  Casas  Venta  Propiedades Individuales  Puebla
# 6    Inmuebles  Casas  Venta  Propiedades Individuales  Puebla
# ..         ...    ...    ...                       ...     ...
# 286  Inmuebles  Casas  Venta  Propiedades Individuales  Puebla
# 287  Inmuebles  Casas  Venta  Propiedades Individuales  Puebla
# 288  Inmuebles  Casas  Venta  Propiedades Individuales  Puebla
# 289  Inmuebles  Casas  Venta  Propiedades Individuales  Puebla
# 290  Inmuebles  Casas  Venta  Propiedades Individuales  Puebla
#
#               Municipio                     Colonia     Precio  \
# 0                   ...      San Juan Cuautlancingo  1,970,000
# 2     San Pedro Cholula                     Cholula  1,970,000
# ...

# %%
dataTypeSeries = Megalopolis_DF.dtypes
print(dataTypeSeries)
# Out:
# Categoria                 object
# Tipo                      object
# V o R                     object
# Propiedad                 object
# Ciudad                    object
# Municipio                 object
# Colonia                   object
# Precio                    object
# Superficie total          object
# Superficie construida     object
# Recámaras                 object
# Baños                     object
# Estacionamientos          object
# url                       object
# lat                       object
# lon                      float64
# Pilar                     object
# dtype: object

# %%
Megalopolis_DF = Megalopolis_DF.astype({"Precio": str})
Megalopolis_DF = Megalopolis_DF.astype({"Superficie total": str})
Megalopolis_DF = Megalopolis_DF.astype({"Superficie construida": str})
Megalopolis_DF = Megalopolis_DF.astype({"Baños": str})
Megalopolis_DF = Megalopolis_DF.astype({"Recámaras": str})
Megalopolis_DF = Megalopolis_DF.astype({"Estacionamientos": str})

# %%
dataTypeSeries = Megalopolis_DF.dtypes
print(dataTypeSeries)
# Out:
# Categoria                 object
# Tipo                      object
# V o R                     object
# Propiedad                 object
# Ciudad                    object
# Municipio                 object
# Colonia                   object
# Precio                    object
# Superficie total          object
# Superficie construida     object
# Recámaras                 object
# Baños                     object
# Estacionamientos          object
# url                       object
# lat                       object
# lon                      float64
# Pilar                     object
# dtype: object

# %%
# Read CSVs and store into Pandas data frames


Megalopolis_DF['Precio'] = Megalopolis_DF['Precio'].str.replace(',','')
Megalopolis_DF = Megalopolis_DF.astype({"Precio": int})
Megalopolis_DF["Superficie total"] = Megalopolis_DF["Superficie total"].str.replace("Superficie total", "")
Megalopolis_DF["Superficie total"] = Megalopolis_DF["Superficie total"].str.replace(" m²", "")
Megalopolis_DF["Superficie construida"] = Megalopolis_DF["Superficie construida"].str.replace("Superficie construida", "")
Megalopolis_DF["Superficie construida"] = Megalopolis_DF["Superficie construida"].str.replace(" m²", "")
Megalopolis_DF["Estacionamientos"] = Megalopolis_DF["Estacionamientos"].str.replace("Estacionamientos", "")
Megalopolis_DF["Recámaras"] = Megalopolis_DF["Recámaras"].str.replace("Recámaras", "")
Megalopolis_DF["Baños"] = Megalopolis_DF["Baños"].str.replace("Baños", "")
#Megalopolis_DF = Megalopolis_DF.astype({"Superficie total": int})
#Megalopolis_DF = Megalopolis_DF.astype({"Superficie construida": int})
#Megalopolis_DF = Megalopolis_DF.astype({"Baños": int})
#Megalopolis_DF = Megalopolis_DF.astype({"Recámaras": int})
#Megalopolis_DF = Megalopolis_DF.astype({"Estacionamientos": int})
#Megalopolis_DF.round(0) 
Megalopolis_DF
# Out:
#     Categoria   Tipo  V o R                 Propiedad    Ciudad  \
# 0   Inmuebles  Casas  Venta  Propiedades Individuales    Puebla
# 1   Inmuebles  Casas  Venta  Propiedades Individuales    Puebla
# 2   Inmuebles  Casas  Venta  Propiedades Individuales    Puebla
# 3   Inmuebles  Casas  Venta  Propiedades Individuales    Puebla
# 4   Inmuebles  Casas  Venta  Propiedades Individuales    Puebla
# ..        ...    ...    ...                       ...       ...
# 37  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 38  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 39  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 40  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
# 41  Inmuebles  Casas  Venta  Propiedades Individuales  Tlaxcala
#
#         Municipio                    Colonia   Precio Superficie total  \
# 0   Cuautlancingo  Misiones de San Francisco  1150000              115
# ...

# %%
Megalopolis_DF.to_csv('PropiedadesMegalopolis.csv', index=False, encoding='utf-8-sig')

# %%
Megalopolis_DF.type()
