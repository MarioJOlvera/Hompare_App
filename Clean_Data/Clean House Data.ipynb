# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
from re import search

# %%
DataA = "Final_House_data.csv"
#DataB = "SCRAPPING Inmuebles 24/Propiedades Inmuebles Todo Mexico2.csv"


# Read CSVs and store into Pandas data frames
DataA_DF = pd.read_csv(DataA)
#DataB_DF = pd.read_csv(DataB)

# %%
DataA_DF

# %%
DataA_DF.dtypes
# Out:
# Unnamed: 0                 int64
# Marca                     object
# Clasificacion             object
# Tipo                      object
# Estado                    object
# Municipio                 object
# Colonia                   object
# Colonia2                  object
# Street                    object
# Price                     object
# Moneda                    object
# PriceClean                 int64
# Price MXN                float64
# Superficie_Terreno         int64
# Superficie_Construida      int64
# Recamaras                  int64
# Banos                      int64
# Medio_Bano                 int64
# Estacionamientos           int64
# CordA                     object
# URL                       object
# Lat                      float64
# Lon                      float64
# geometry                  object
# OBJECTID_x                 int64
# CVEGEO                    object
# CVE_ENT_x                  int64
# CVE_MUN_x                  int64
# ...

# %%
for i, row in DataA_DF.iterrows():
    Banos = str(row["Banos"])
    #Columna Terreno
    try:
        if len(Banos) <= 1:
            New_Banos = Banos
            DataA_DF.at[i,'Banos'] = New_Banos
        else:
            #if len(Banos) == 1:
            New_Banos = Banos[0]
            DataA_DF.at[i,'Banos'] = New_Banos
            #else:
             #   pass
    except:
        New_Banos = Banos
        DataA_DF.at[i,'Banos'] = New_Banos

# %%
for i, row in DataA_DF.iterrows():
    Banos = str(row["Recamaras"])
    #Columna Terreno
    try:
        if len(Banos) <= 1:
            New_Banos = Banos
            DataA_DF.at[i,'Recamaras'] = New_Banos
        else:
            #if len(Banos) == 1:
            New_Banos = Banos[0]
            DataA_DF.at[i,'Recamaras'] = New_Banos
            #else:
             #   pass
    except:
        New_Banos = Banos
        DataA_DF.at[i,'Recamaras'] = New_Banos

# %%
for i, row in DataA_DF.iterrows():
    Banos = str(row["Medio_Bano"])
    #Columna Terreno
    try:
        if len(Banos) <= 1:
            New_Banos = Banos
            DataA_DF.at[i,'Medio_Bano'] = New_Banos
        else:
            #if len(Banos) == 1:
            New_Banos = Banos[0]
            DataA_DF.at[i,'Medio_Bano'] = New_Banos
            #else:
             #   pass
    except:
        New_Banos = Banos
        DataA_DF.at[i,'Medio_Bano'] = New_Banos

# %%
for i, row in DataA_DF.iterrows():
    Banos = str(row["Estacionamientos"])
    #Columna Terreno
    try:
        if len(Banos) <= 1:
            New_Banos = Banos
            DataA_DF.at[i,'Estacionamientos'] = New_Banos
        else:
            #if len(Banos) == 1:
            New_Banos = Banos[0]
            DataA_DF.at[i,'Estacionamientos'] = New_Banos
            #else:
             #   pass
    except:
        New_Banos = Banos
        DataA_DF.at[i,'Estacionamientos'] = New_Banos

# %%
DataA_DF['Banos'].unique()
# Out:
# array([2, 3, 4, 8, 1, 0, 5, 6, 7, 9])

# %%
DataA_DF['Recamaras'].unique()
# Out:
# array([2, 3, 4, 6, 0, 1, 5, 7, 8, 9])

# %%
DataA_DF['Medio_Bano'].unique()
# Out:
# array([0, 1, 3, 2, 5, 4, 6, 7, 8])

# %%
DataA_DF['Estacionamientos'].unique()
# Out:
# array([2, 3, 4, 1, 0, 6, 5, 8, 7, 9])

# %%
DataA_DF["area"] = np.where((DataA_DF["Superficie_Terreno"] > DataA_DF["Superficie_Construida"])
                     ,DataA_DF["Superficie_Terreno"], DataA_DF["Superficie_Construida"])

# %%
DataA_DF["Filtro"] = np.where((DataA_DF["Superficie_Terreno"] > DataA_DF["Superficie_Construida"])
                     ,"", DataA_DF["Superficie_Construida"])

# %%
Filtro = []
for i, row in DataA_DF.iterrows():
    Area = row["area"]
    #Columna Terreno
    try:
        if Area < 50:
            Filtro.append("NOK")
        else:    
            Filtro.append("OK")
    except:
        Filtro.append("NOK")

# %%
Filtro
# Out:
# ['OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'NOK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'NOK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'NOK',
#  'OK',
#  'NOK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'NOK',
#  'NOK',
#  'NOK',
#  'OK',
#  'OK',
#  'NOK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'NOK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'NOK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
#  'OK',
# ...

# %%
#DataBB = pd.DataFrame(Price_MXN,)
#DataBB = pd.DataFrame(Filtro,columns=['Filtro'])
DataA_DF.insert(0, 'Filtro', Filtro )
#DataAA_DF['Price MXN'] = Price_MXN 
DataA_DF
# Out:
#        Filtro  Unnamed: 0        Marca Clasificacion   Tipo          Estado  \
# 0          OK           0  Inmuebles24          Casa  Venta  Aguascalientes
# 1          OK           1  Inmuebles24          Casa  Venta  Aguascalientes
# 2          OK           2  Inmuebles24          Casa  Venta  Aguascalientes
# 3          OK           3  Inmuebles24          Casa  Venta  Aguascalientes
# 4          OK           4  Inmuebles24          Casa  Venta  Aguascalientes
# ...       ...         ...          ...           ...    ...             ...
# 100683    NOK      105321  Inmuebles24  Departamento  Venta         Yucatán
# 100684    NOK      105322  Inmuebles24  Departamento  Venta         Yucatán
# 100685     OK      105324  Inmuebles24  Departamento  Venta         Yucatán
# 100686     OK      105325  Inmuebles24  Departamento  Venta         Yucatán
# 100687     OK      105326  Inmuebles24  Departamento  Venta         Yucatán
#
# ...

# %%
Filtro = []
for i, row in DataA_DF.iterrows():
    area = int(row["area"])
    try:
        if Area > 50:
            New_Banos = Banos
            DataA_DF.at[i,'Estacionamientos'] = New_Banos
        else:
            #if len(Banos) == 1:
            New_Banos = Banos[0]
            DataA_DF.at[i,'Estacionamientos'] = New_Banos
            #else:
             #   pass
    except:
        New_Banos = Banos
        DataA_DF.at[i,'Estacionamientos'] = New_Banos

# %%
DataA_DF.insert(0, 'Filtro', Filtro )
DataA_DF

# %%
DataA_DF.to_csv(f'Final_House_data2.csv', index=False, encoding='utf-8-sig')

# %%
Price_MXN = []
USD = "USD"
for i, row in DataAA_DF.iterrows():
    Moneda = str(row["Moneda"])
    #Columna Terreno
    try:
        if search(USD, Moneda):
            A = int(DataAA_DF.at[i,'PriceClean'])
            Price_MXN.append(A*21.5)
        else:
            A = int(DataAA_DF.at[i,'PriceClean'])
            Price_MXN.append(A)
    except:
        A = 0
        Price_MXN.append(A)
