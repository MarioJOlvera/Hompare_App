# %%
# !python --version

# %%
# !pip install --upgrade chromedriver

# %%
# !pip install --upgrade splinter

# %%
#brew cask install chromedriver
#brew cask reinstall chromedriver
#Autorizar en preferenciasa de seguridad el chorme driver

# %%
# Dependencies
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
import requests
import lxml.html as lh
import pandas as pd
import re
import time
import json
import urllib
import urllib.request as urllib2

# %%
executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
browser = Browser("chrome",**executable_path, headless=False)

# %%
url = f"https://www.inmuebles24.com/inmuebles-en-venta-en-aguascalientes.html"
browser.visit(url)
time.sleep(2)  
html = browser.html

# %%
Estados1 = ["distrito-federal"]

# %%
Estados = ["aguascalientes-provincia","baja-california-norte","baja-california-sur","campeche-provincia","distrito-federal",
          "chiapas","chihuahua-provincia","coahuila","colima-provincia","durango-provincia",
          "edo.-de-mexico","guanajuato-provincia","guerrero-provincia","hidalgo-provincia","jalisco",
          "michoacan","morelos-provincia","nayarit","nuevo-leon","oaxaca",
          "puebla-provincia","queretaro-provincia","quintana-roo-provincia","san-luis-potosi-provincia","sinaloa-provincia",
          "sonora","tabasco-provincia","tamaulipas","tlaxcala-provincia","veracruz-provincia",
          "yucatan","zacatecas-provincia"]

# %%
url_All = "https://www.inmuebles24.com/inmuebles-en-venta-en-"
url_Depa = "https://www.inmuebles24.com/departamentos-en-venta-en-"#DEPÀRTAMENTOS
url_Casa = "https://www.inmuebles24.com/casas-en-venta-en-"#CASAS
url_CasaCond = "https://www.inmuebles24.com/casa-en-condominio-en-venta-en-"#CASAS EN CONDOMINIO
url_CasaSuelo = "https://www.inmuebles24.com/casa-uso-de-suelo-en-venta-en-"#CASAS CON USO DE SUELO
url_DepaComp = "https://www.inmuebles24.com/departamento-compartido-en-venta-en-"#DEPA "COMPARTIDO"
url_Duplex = "https://www.inmuebles24.com/duplex-en-venta-en-"#DUPLEX

# %%
Busqueda = url_Depa
print(Busqueda)
# Out:
# https://www.inmuebles24.com/departamentos-en-venta-en-

# %%
for c in Estados1:
    try:
        CasasList = []
        url = f"{Busqueda}{c}.html"
        
        #url = url_Depa
        print(f"el url es {url}")
               
        
        browser.visit(url)
        time.sleep(2)  
        html = browser.html
        soup = bs(html,"html.parser")
        print("OK1")
        TotalInmuebles = soup.findAll('h1', class_="list-result-title")
        print("OK2")
        TotalInmuebles = TotalInmuebles[0].getText().replace(',', '').strip()
        print("OK3")
        try:
            TotalInmuebles = int(TotalInmuebles[:5])
        except:
            try:
                TotalInmuebles = int(TotalInmuebles[:4])
            except:
                try:
                    TotalInmuebles = int(TotalInmuebles[:3])
                except:
                    try:
                        TotalInmuebles = int(TotalInmuebles[:2])
                    except:
                        try:
                            TotalInmuebles = int(TotalInmuebles[:1])
                        except:
                            print(f"Falla TotalInmuebles")
                            pass
            
        Paginas = round(TotalInmuebles/20)
        print(f'Para {c}')
        print(f'Tiene un total de {TotalInmuebles} Inmuebles')
        print(f'Significa un total de {Paginas} Paginas')
        for i in range(1,Paginas):
            try:
                url = f"{Busqueda}{c}-pagina-{i}.html"
                print(f"el url de Pagina es {url}")
                browser.visit(url)
                time.sleep(2)  
                html = browser.html
                soup = bs(html,"html.parser")
                Casas = soup.findAll('h2', class_="posting-title")
                TotalCasas = len(Casas)
                #print(TotalCasas)
        
                for X in range(TotalCasas):
                    CasasList.append(Casas[X].a["href"])
                    #print(f"Pagina {i} casa {X}")
                print(f"OK pagina {i} de {c}")
                    #break
        
            except:
                    print(f"NOK pagina {i}")
                    
        Propiedades_Inmuebles24 = pd.DataFrame(CasasList)
        Propiedades_Inmuebles24.to_csv(f'PropiedadesInmuebles Estados{c}.csv', index=False, encoding='utf-8-sig')

    except:
        print(f"Error {c}")
        pass
# Out:
# el url es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal.html
# OK1
# OK2
# OK3
# Para distrito-federal
# Tiene un total de 52447 Inmuebles
# Significa un total de 2622 Paginas
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-1.html
# OK pagina 1 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2.html
# OK pagina 2 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-3.html
# OK pagina 3 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-4.html
# OK pagina 4 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-5.html
# OK pagina 5 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-6.html
# OK pagina 6 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-7.html
# OK pagina 7 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-8.html
# OK pagina 8 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-9.html
# OK pagina 9 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-10.html
# OK pagina 10 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-11.html
# OK pagina 11 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-12.html
# OK pagina 12 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-13.html
# OK pagina 13 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-14.html
# OK pagina 14 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-15.html
# OK pagina 15 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-16.html
# OK pagina 16 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-17.html
# OK pagina 17 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-18.html
# OK pagina 18 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-19.html
# OK pagina 19 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-20.html
# OK pagina 20 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-21.html
# OK pagina 21 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-22.html
# OK pagina 22 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-23.html
# OK pagina 23 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-24.html
# OK pagina 24 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-25.html
# OK pagina 25 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-26.html
# OK pagina 26 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-27.html
# OK pagina 27 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-28.html
# OK pagina 28 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-29.html
# OK pagina 29 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-30.html
# OK pagina 30 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-31.html
# OK pagina 31 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-32.html
# OK pagina 32 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-33.html
# OK pagina 33 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-34.html
# OK pagina 34 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-35.html
# OK pagina 35 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-36.html
# OK pagina 36 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-37.html
# OK pagina 37 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-38.html
# OK pagina 38 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-39.html
# OK pagina 39 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-40.html
# OK pagina 40 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-41.html
# OK pagina 41 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-42.html
# OK pagina 42 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-43.html
# OK pagina 43 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-44.html
# OK pagina 44 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-45.html
# OK pagina 45 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-46.html
# OK pagina 46 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-47.html
# OK pagina 47 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-48.html
# OK pagina 48 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-49.html
# OK pagina 49 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-50.html
# OK pagina 50 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-51.html
# OK pagina 51 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-52.html
# OK pagina 52 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-53.html
# OK pagina 53 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-54.html
# OK pagina 54 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-55.html
# OK pagina 55 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-56.html
# OK pagina 56 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-57.html
# OK pagina 57 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-58.html
# OK pagina 58 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-59.html
# OK pagina 59 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-60.html
# OK pagina 60 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-61.html
# OK pagina 61 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-62.html
# OK pagina 62 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-63.html
# OK pagina 63 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-64.html
# OK pagina 64 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-65.html
# OK pagina 65 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-66.html
# OK pagina 66 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-67.html
# OK pagina 67 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-68.html
# OK pagina 68 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-69.html
# OK pagina 69 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-70.html
# OK pagina 70 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-71.html
# OK pagina 71 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-72.html
# OK pagina 72 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-73.html
# OK pagina 73 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-74.html
# OK pagina 74 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-75.html
# OK pagina 75 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-76.html
# OK pagina 76 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-77.html
# OK pagina 77 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-78.html
# OK pagina 78 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-79.html
# OK pagina 79 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-80.html
# OK pagina 80 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-81.html
# OK pagina 81 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-82.html
# OK pagina 82 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-83.html
# OK pagina 83 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-84.html
# OK pagina 84 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-85.html
# OK pagina 85 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-86.html
# OK pagina 86 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-87.html
# OK pagina 87 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-88.html
# OK pagina 88 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-89.html
# OK pagina 89 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-90.html
# OK pagina 90 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-91.html
# OK pagina 91 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-92.html
# OK pagina 92 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-93.html
# OK pagina 93 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-94.html
# OK pagina 94 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-95.html
# OK pagina 95 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-96.html
# OK pagina 96 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-97.html
# OK pagina 97 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-98.html
# OK pagina 98 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-99.html
# OK pagina 99 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-100.html
# OK pagina 100 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-101.html
# OK pagina 101 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-102.html
# OK pagina 102 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-103.html
# OK pagina 103 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-104.html
# OK pagina 104 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-105.html
# OK pagina 105 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-106.html
# OK pagina 106 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-107.html
# OK pagina 107 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-108.html
# OK pagina 108 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-109.html
# OK pagina 109 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-110.html
# OK pagina 110 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-111.html
# OK pagina 111 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-112.html
# OK pagina 112 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-113.html
# OK pagina 113 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-114.html
# OK pagina 114 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-115.html
# OK pagina 115 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-116.html
# OK pagina 116 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-117.html
# OK pagina 117 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-118.html
# OK pagina 118 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-119.html
# OK pagina 119 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-120.html
# OK pagina 120 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-121.html
# OK pagina 121 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-122.html
# OK pagina 122 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-123.html
# OK pagina 123 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-124.html
# OK pagina 124 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-125.html
# OK pagina 125 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-126.html
# OK pagina 126 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-127.html
# OK pagina 127 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-128.html
# OK pagina 128 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-129.html
# OK pagina 129 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-130.html
# OK pagina 130 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-131.html
# OK pagina 131 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-132.html
# OK pagina 132 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-133.html
# OK pagina 133 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-134.html
# OK pagina 134 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-135.html
# OK pagina 135 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-136.html
# OK pagina 136 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-137.html
# OK pagina 137 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-138.html
# OK pagina 138 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-139.html
# OK pagina 139 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-140.html
# OK pagina 140 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-141.html
# OK pagina 141 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-142.html
# OK pagina 142 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-143.html
# OK pagina 143 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-144.html
# OK pagina 144 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-145.html
# OK pagina 145 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-146.html
# OK pagina 146 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-147.html
# OK pagina 147 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-148.html
# OK pagina 148 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-149.html
# OK pagina 149 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-150.html
# OK pagina 150 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-151.html
# OK pagina 151 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-152.html
# OK pagina 152 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-153.html
# OK pagina 153 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-154.html
# OK pagina 154 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-155.html
# OK pagina 155 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-156.html
# OK pagina 156 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-157.html
# OK pagina 157 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-158.html
# OK pagina 158 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-159.html
# OK pagina 159 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-160.html
# OK pagina 160 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-161.html
# OK pagina 161 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-162.html
# OK pagina 162 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-163.html
# OK pagina 163 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-164.html
# OK pagina 164 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-165.html
# OK pagina 165 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-166.html
# OK pagina 166 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-167.html
# OK pagina 167 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-168.html
# OK pagina 168 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-169.html
# OK pagina 169 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-170.html
# OK pagina 170 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-171.html
# OK pagina 171 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-172.html
# OK pagina 172 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-173.html
# OK pagina 173 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-174.html
# OK pagina 174 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-175.html
# OK pagina 175 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-176.html
# OK pagina 176 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-177.html
# OK pagina 177 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-178.html
# OK pagina 178 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-179.html
# OK pagina 179 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-180.html
# OK pagina 180 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-181.html
# OK pagina 181 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-182.html
# OK pagina 182 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-183.html
# OK pagina 183 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-184.html
# OK pagina 184 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-185.html
# OK pagina 185 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-186.html
# OK pagina 186 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-187.html
# OK pagina 187 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-188.html
# OK pagina 188 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-189.html
# OK pagina 189 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-190.html
# OK pagina 190 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-191.html
# OK pagina 191 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-192.html
# OK pagina 192 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-193.html
# OK pagina 193 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-194.html
# OK pagina 194 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-195.html
# OK pagina 195 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-196.html
# OK pagina 196 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-197.html
# OK pagina 197 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-198.html
# OK pagina 198 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-199.html
# OK pagina 199 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-200.html
# OK pagina 200 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-201.html
# OK pagina 201 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-202.html
# OK pagina 202 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-203.html
# OK pagina 203 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-204.html
# OK pagina 204 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-205.html
# OK pagina 205 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-206.html
# OK pagina 206 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-207.html
# OK pagina 207 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-208.html
# OK pagina 208 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-209.html
# OK pagina 209 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-210.html
# OK pagina 210 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-211.html
# OK pagina 211 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-212.html
# OK pagina 212 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-213.html
# OK pagina 213 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-214.html
# OK pagina 214 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-215.html
# OK pagina 215 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-216.html
# OK pagina 216 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-217.html
# OK pagina 217 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-218.html
# OK pagina 218 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-219.html
# OK pagina 219 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-220.html
# OK pagina 220 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-221.html
# OK pagina 221 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-222.html
# OK pagina 222 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-223.html
# OK pagina 223 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-224.html
# OK pagina 224 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-225.html
# OK pagina 225 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-226.html
# OK pagina 226 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-227.html
# OK pagina 227 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-228.html
# OK pagina 228 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-229.html
# OK pagina 229 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-230.html
# OK pagina 230 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-231.html
# OK pagina 231 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-232.html
# OK pagina 232 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-233.html
# OK pagina 233 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-234.html
# OK pagina 234 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-235.html
# OK pagina 235 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-236.html
# OK pagina 236 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-237.html
# OK pagina 237 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-238.html
# OK pagina 238 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-239.html
# OK pagina 239 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-240.html
# OK pagina 240 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-241.html
# OK pagina 241 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-242.html
# OK pagina 242 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-243.html
# OK pagina 243 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-244.html
# OK pagina 244 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-245.html
# OK pagina 245 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-246.html
# OK pagina 246 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-247.html
# OK pagina 247 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-248.html
# OK pagina 248 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-249.html
# OK pagina 249 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-250.html
# OK pagina 250 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-251.html
# OK pagina 251 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-252.html
# OK pagina 252 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-253.html
# OK pagina 253 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-254.html
# OK pagina 254 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-255.html
# OK pagina 255 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-256.html
# OK pagina 256 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-257.html
# OK pagina 257 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-258.html
# OK pagina 258 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-259.html
# OK pagina 259 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-260.html
# OK pagina 260 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-261.html
# OK pagina 261 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-262.html
# OK pagina 262 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-263.html
# OK pagina 263 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-264.html
# OK pagina 264 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-265.html
# OK pagina 265 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-266.html
# OK pagina 266 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-267.html
# OK pagina 267 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-268.html
# OK pagina 268 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-269.html
# OK pagina 269 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-270.html
# OK pagina 270 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-271.html
# OK pagina 271 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-272.html
# OK pagina 272 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-273.html
# OK pagina 273 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-274.html
# OK pagina 274 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-275.html
# OK pagina 275 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-276.html
# OK pagina 276 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-277.html
# OK pagina 277 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-278.html
# OK pagina 278 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-279.html
# OK pagina 279 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-280.html
# OK pagina 280 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-281.html
# OK pagina 281 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-282.html
# OK pagina 282 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-283.html
# OK pagina 283 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-284.html
# OK pagina 284 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-285.html
# OK pagina 285 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-286.html
# OK pagina 286 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-287.html
# OK pagina 287 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-288.html
# OK pagina 288 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-289.html
# OK pagina 289 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-290.html
# OK pagina 290 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-291.html
# OK pagina 291 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-292.html
# OK pagina 292 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-293.html
# OK pagina 293 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-294.html
# OK pagina 294 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-295.html
# OK pagina 295 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-296.html
# OK pagina 296 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-297.html
# OK pagina 297 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-298.html
# OK pagina 298 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-299.html
# OK pagina 299 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-300.html
# OK pagina 300 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-301.html
# OK pagina 301 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-302.html
# OK pagina 302 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-303.html
# OK pagina 303 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-304.html
# OK pagina 304 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-305.html
# OK pagina 305 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-306.html
# OK pagina 306 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-307.html
# OK pagina 307 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-308.html
# OK pagina 308 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-309.html
# OK pagina 309 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-310.html
# OK pagina 310 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-311.html
# OK pagina 311 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-312.html
# OK pagina 312 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-313.html
# OK pagina 313 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-314.html
# OK pagina 314 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-315.html
# OK pagina 315 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-316.html
# OK pagina 316 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-317.html
# OK pagina 317 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-318.html
# OK pagina 318 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-319.html
# OK pagina 319 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-320.html
# OK pagina 320 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-321.html
# OK pagina 321 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-322.html
# OK pagina 322 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-323.html
# OK pagina 323 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-324.html
# OK pagina 324 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-325.html
# OK pagina 325 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-326.html
# OK pagina 326 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-327.html
# OK pagina 327 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-328.html
# OK pagina 328 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-329.html
# OK pagina 329 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-330.html
# OK pagina 330 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-331.html
# OK pagina 331 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-332.html
# OK pagina 332 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-333.html
# OK pagina 333 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-334.html
# OK pagina 334 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-335.html
# OK pagina 335 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-336.html
# OK pagina 336 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-337.html
# OK pagina 337 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-338.html
# OK pagina 338 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-339.html
# OK pagina 339 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-340.html
# OK pagina 340 de distrito-federal
# ...
# OK pagina 2510 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2511.html
# OK pagina 2511 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2512.html
# OK pagina 2512 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2513.html
# OK pagina 2513 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2514.html
# OK pagina 2514 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2515.html
# OK pagina 2515 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2516.html
# OK pagina 2516 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2517.html
# OK pagina 2517 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2518.html
# OK pagina 2518 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2519.html
# OK pagina 2519 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2520.html
# OK pagina 2520 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2521.html
# OK pagina 2521 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2522.html
# OK pagina 2522 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2523.html
# OK pagina 2523 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2524.html
# OK pagina 2524 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2525.html
# OK pagina 2525 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2526.html
# OK pagina 2526 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2527.html
# OK pagina 2527 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2528.html
# OK pagina 2528 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2529.html
# OK pagina 2529 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2530.html
# OK pagina 2530 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2531.html
# OK pagina 2531 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2532.html
# OK pagina 2532 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2533.html
# OK pagina 2533 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2534.html
# OK pagina 2534 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2535.html
# OK pagina 2535 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2536.html
# OK pagina 2536 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2537.html
# OK pagina 2537 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2538.html
# OK pagina 2538 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2539.html
# OK pagina 2539 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2540.html
# OK pagina 2540 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2541.html
# OK pagina 2541 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2542.html
# OK pagina 2542 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2543.html
# OK pagina 2543 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2544.html
# OK pagina 2544 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2545.html
# OK pagina 2545 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2546.html
# OK pagina 2546 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2547.html
# OK pagina 2547 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2548.html
# OK pagina 2548 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2549.html
# OK pagina 2549 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2550.html
# OK pagina 2550 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2551.html
# OK pagina 2551 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2552.html
# OK pagina 2552 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2553.html
# OK pagina 2553 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2554.html
# OK pagina 2554 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2555.html
# OK pagina 2555 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2556.html
# OK pagina 2556 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2557.html
# OK pagina 2557 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2558.html
# OK pagina 2558 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2559.html
# OK pagina 2559 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2560.html
# OK pagina 2560 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2561.html
# OK pagina 2561 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2562.html
# OK pagina 2562 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2563.html
# OK pagina 2563 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2564.html
# OK pagina 2564 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2565.html
# OK pagina 2565 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2566.html
# OK pagina 2566 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2567.html
# OK pagina 2567 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2568.html
# OK pagina 2568 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2569.html
# OK pagina 2569 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2570.html
# OK pagina 2570 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2571.html
# OK pagina 2571 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2572.html
# OK pagina 2572 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2573.html
# OK pagina 2573 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2574.html
# OK pagina 2574 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2575.html
# OK pagina 2575 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2576.html
# OK pagina 2576 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2577.html
# OK pagina 2577 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2578.html
# OK pagina 2578 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2579.html
# OK pagina 2579 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2580.html
# OK pagina 2580 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2581.html
# OK pagina 2581 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2582.html
# OK pagina 2582 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2583.html
# OK pagina 2583 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2584.html
# OK pagina 2584 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2585.html
# OK pagina 2585 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2586.html
# OK pagina 2586 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2587.html
# OK pagina 2587 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2588.html
# OK pagina 2588 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2589.html
# OK pagina 2589 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2590.html
# OK pagina 2590 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2591.html
# OK pagina 2591 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2592.html
# OK pagina 2592 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2593.html
# OK pagina 2593 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2594.html
# OK pagina 2594 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2595.html
# OK pagina 2595 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2596.html
# OK pagina 2596 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2597.html
# OK pagina 2597 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2598.html
# OK pagina 2598 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2599.html
# OK pagina 2599 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2600.html
# OK pagina 2600 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2601.html
# OK pagina 2601 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2602.html
# OK pagina 2602 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2603.html
# OK pagina 2603 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2604.html
# OK pagina 2604 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2605.html
# OK pagina 2605 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2606.html
# OK pagina 2606 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2607.html
# OK pagina 2607 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2608.html
# OK pagina 2608 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2609.html
# OK pagina 2609 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2610.html
# OK pagina 2610 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2611.html
# OK pagina 2611 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2612.html
# OK pagina 2612 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2613.html
# OK pagina 2613 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2614.html
# OK pagina 2614 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2615.html
# OK pagina 2615 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2616.html
# OK pagina 2616 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2617.html
# OK pagina 2617 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2618.html
# OK pagina 2618 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2619.html
# OK pagina 2619 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2620.html
# OK pagina 2620 de distrito-federal
# el url de Pagina es https://www.inmuebles24.com/departamentos-en-venta-en-distrito-federal-pagina-2621.html
# OK pagina 2621 de distrito-federal

# %%
Estado = Estados[28]
CasasListEDO = []
for i in range(1,23):
    try:
        url = f"https://www.inmuebles24.com/inmuebles-en-venta-en-{Estado}-pagina-{i}.html"
        #url = f"https://www.inmuebles24.com/inmuebles-en-venta-en-{Estado}.html"
        browser.visit(url)
        time.sleep(2)  
        html = browser.html
        soup = bs(html,"html.parser")
        Casas = soup.findAll('h2', class_="posting-title")
        TotalCasas = len(Casas)
        #print(TotalCasas)
        
        for X in range(TotalCasas):
            CasasListEDO.append(Casas[X].a["href"])
            #print(f"Pagina {i} casa {X}")
        print(f"OK pagina {i} de {Estado}")
        #break
            
    except:
        print(f"NOK pagina {i} de {Estado}")

Propiedades_Inmuebles24 = pd.DataFrame(CasasListEDO)
Propiedades_Inmuebles24.to_csv(f'PropiedadesInmuebles{Estado}2.csv', index=False, encoding='utf-8-sig')
Propiedades_Inmuebles24

# %%
Tipo = "Casa Condo"

# %%
#Cargar CSVs de Cada Estado Descargado

try:
    AGSCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[0]}.csv"
    AGS_df = pd.read_csv(AGSCPs)
except:
    print(f"No {Estados[0]}")

try:
    BCNCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[1]}.csv"
    BCN_df = pd.read_csv(BCNCPs)
except:
    print(f"No {Estados[1]}")
    
try:
    BCSCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[2]}.csv"
    BCS_df = pd.read_csv(BCSCPs)

except:
    print(f"No {Estados[2]}")

try:
    CAMCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[3]}.csv"
    CAM_df = pd.read_csv(CAMCPs)
except:
    print(f"No {Estados[3]}")
    
try:
    CDMXCPsA = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[4]}.csv"
    CDMX_dfA = pd.read_csv(CDMXCPsA)
except:
    print(f"No {Estados[4]}")
    
#CDMXCPsB = "URLs x Estado/PropiedadesInmueblesdistrito-federalB.csv"
#CDMXCPsC = "URLs x Estado/PropiedadesInmueblesdistrito-federalC.csv"
#CDMXCPsD = "URLs x Estado/PropiedadesInmueblesdistrito-federalD.csv"
#CDMXCPsE = "URLs x Estado/PropiedadesInmueblesdistrito-federalE.csv"
#CDMXCPsF = "URLs x Estado/PropiedadesInmueblesdistrito-federalF.csv"
#CDMXCPsG = "URLs x Estado/PropiedadesInmueblesdistrito-federalG.csv"
#CDMXCPsH = "URLs x Estado/PropiedadesInmueblesdistrito-federalH.csv"
#CDMXCPsI = "URLs x Estado/PropiedadesInmueblesdistrito-federalI.csv"
#CDMXCPsJ = "URLs x Estado/PropiedadesInmueblesdistrito-federalJ.csv"
#CDMXCPsK = "URLs x Estado/PropiedadesInmueblesdistrito-federalK.csv"
#CDMXCPsL = "URLs x Estado/PropiedadesInmueblesdistrito-federalL.csv"
#CDMXCPsM = "URLs x Estado/PropiedadesInmueblesdistrito-federalM.csv"
#CDMXCPsN = "URLs x Estado/PropiedadesInmueblesdistrito-federalN.csv"
#CDMXCPsO = "URLs x Estado/PropiedadesInmueblesdistrito-federalO.csv"
#CDMXCPsP = "URLs x Estado/PropiedadesInmueblesdistrito-federalP.csv"
#CDMX_dfB = pd.read_csv(CDMXCPsB)
#CDMX_dfC = pd.read_csv(CDMXCPsC)
#CDMX_dfD = pd.read_csv(CDMXCPsD)
#CDMX_dfE = pd.read_csv(CDMXCPsE)
#CDMX_dfF = pd.read_csv(CDMXCPsF)
#CDMX_dfG = pd.read_csv(CDMXCPsG)
#CDMX_dfH = pd.read_csv(CDMXCPsH)
#CDMX_dfI = pd.read_csv(CDMXCPsI)
#CDMX_dfJ = pd.read_csv(CDMXCPsJ)
#CDMX_dfK = pd.read_csv(CDMXCPsK)
#CDMX_dfL = pd.read_csv(CDMXCPsL)
#CDMX_dfM = pd.read_csv(CDMXCPsM)
#CDMX_dfN = pd.read_csv(CDMXCPsN)
#CDMX_dfO = pd.read_csv(CDMXCPsO)
#CDMX_dfP = pd.read_csv(CDMXCPsP)

try:
    CHPCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[5]}.csv"
    CHP_df = pd.read_csv(CHPCPs)
except:
    print(f"No {Estados[5]}")
    
try:    
    CHHCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[6]}.csv"
    CHH_df = pd.read_csv(CHHCPs)
except:
    print(f"No {Estados[6]}")
    
try:    
    COACPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[7]}.csv"
    COA_df = pd.read_csv(COACPs)
except:
    print(f"No {Estados[7]}")
    
try:    
    COLCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[8]}.csv"
    COL_df = pd.read_csv(COLCPs)
except:
    print(f"No {Estados[8]}")
    
try:    
    DURCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[9]}.csv"
    DUR_df = pd.read_csv(DURCPs)
except:
    print(f"No {Estados[9]}")
    
try:    
    EDOMEXCPsA = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[10]}.csv"
    EDOMEX_dfA = pd.read_csv(EDOMEXCPsA)
except:
    print(f"No {Estados[10]}")
    
    
#EDOMEXCPsB = "URLs x Estado/PropiedadesInmuebles Estadosedo.-de-mexicoB.csv"
#EDOMEXCPsC = "URLs x Estado/PropiedadesInmuebles Estadosedo.-de-mexicoC.csv"
#EDOMEXCPsD = "URLs x Estado/PropiedadesInmuebles Estadosedo.-de-mexicoD.csv"
#EDOMEX_dfB = pd.read_csv(EDOMEXCPsB)
#EDOMEX_dfC = pd.read_csv(EDOMEXCPsC)
#EDOMEX_dfD = pd.read_csv(EDOMEXCPsD)

try:
    GUACPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[11]}.csv"
    GUA_df = pd.read_csv(GUACPs)
except:
    print(f"No {Estados[11]}")
    
try:    
    GROCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[12]}.csv"
    GRO_df = pd.read_csv(GROCPs)
except:
    print(f"No {Estados[12]}")
    
try:    
    HIDCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[13]}.csv"
    HID_df = pd.read_csv(HIDCPs)
except:
    print(f"No {Estados[13]}")
    
try:    
    JALCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[14]}.csv"
    JAL_df = pd.read_csv(JALCPs)
except:
    print(f"No {Estados[14]}")
    
try:    
    MICCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[15]}.csv"
    MIC_df = pd.read_csv(MICCPs)
except:
    print(f"No {Estados[15]}")
    
try:    
    MORCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[16]}.csv"
    MOR_df = pd.read_csv(MORCPs)
except:
    print(f"No {Estados[16]}")
    
try:    
    NAYCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[17]}.csv"
    NAY_df = pd.read_csv(NAYCPs)
except:
    print(f"No {Estados[17]}")
    
try:    
    NLECPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[18]}.csv"
    NLE_df = pd.read_csv(NLECPs)
except:
    print(f"No {Estados[18]}")
    
try:    
    OAXCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[19]}.csv"
    OAX_df = pd.read_csv(OAXCPs)
except:
    print(f"No {Estados[19]}")
    
try:    
    PUECPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[20]}.csv"
    PUE_df = pd.read_csv(PUECPs)
except:
    print(f"No {Estados[20]}")
    
try:    
    QROCPsA = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[21]}.csv"
    QRO_dfA = pd.read_csv(QROCPsA)
except:
    print(f"No {Estados[21]}")
    
    
#QROCPsB = "URLs x Estado/PropiedadesInmuebles Estadosqueretaro-provinciaB.csv"
#QROCPsC = "URLs x Estado/PropiedadesInmuebles Estadosqueretaro-provinciaC.csv"
#QROCPsD = "URLs x Estado/PropiedadesInmuebles Estadosqueretaro-provinciaD.csv"
#QRO_dfB = pd.read_csv(QROCPsB)
#QRO_dfC = pd.read_csv(QROCPsC)
#QRO_dfD = pd.read_csv(QROCPsD)

try:
    ROOCPsA = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[22]}.csv"
    ROO_dfA = pd.read_csv(ROOCPsA)
except:
    print(f"No {Estados[22]}")
    
    
#ROOCPsB = "URLs x Estado/PropiedadesInmuebles Estadosquintana-roo-provinciaB.csv"
#ROOCPsC = "URLs x Estado/PropiedadesInmuebles Estadosquintana-roo-provinciaC.csv"
#ROOCPsD = "URLs x Estado/PropiedadesInmuebles Estadosquintana-roo-provinciaD.csv"
#ROO_dfB = pd.read_csv(ROOCPsB)
#ROO_dfC = pd.read_csv(ROOCPsC)
#ROO_dfD = pd.read_csv(ROOCPsD)


try:
    SLPCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[23]}.csv"
    SLP_df = pd.read_csv(SLPCPs)
except:
    print(f"No {Estados[23]}")
    
try:
    SINCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[24]}.csv"
    SIN_df = pd.read_csv(SINCPs)
except:
    print(f"No {Estados[24]}")
    
try:    
    SONCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[25]}.csv"
    SON_df = pd.read_csv(SONCPs)
except:
    print(f"No {Estados[25]}")
    
try:    
    TABCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[26]}.csv"
    TAB_df = pd.read_csv(TABCPs)
except:
    print(f"No {Estados[26]}")
    
try:    
    TAMCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[27]}.csv"
    TAM_df = pd.read_csv(TAMCPs)
except:
    print(f"No {Estados[27]}")
    
try:    
    TLACPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[28]}.csv"
    TLA_df = pd.read_csv(TLACPs)
except:
    print(f"No {Estados[28]}")
    
try:    
    VERCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[29]}.csv"
    VER_df = pd.read_csv(VERCPs)
except:
    print(f"No {Estados[29]}")
    
try:    
    YUCCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[30]}.csv"
    YUC_df = pd.read_csv(YUCCPs)
except:
    print(f"No {Estados[30]}")
    
try:    
    ZACCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[31]}.csv"
    ZAC_df = pd.read_csv(ZACCPs)
except:
    print(f"No {Estados[31]}")




#CSVList = [
#    AGS_df,
#    BCN_df,
#    BCS_df,
#    CAM_df,
#    CDMX_dfA,
#    CHP_df,
#    CHH_df,
#    COA_df,
#    COL_df,
#    DUR_df,
#    EDOMEX_dfA,
#    GUA_df,
#    GRO_df,
#    HID_df,
#    JAL_df,
#    MIC_df,
#    MOR_df,
#    NAY_df,
#    NLE_df,
#    OAX_df,
#    PUE_df,
#    QRO_dfA,
#    ROO_dfA,
#    SLP_df,
#    SIN_df,
#   SON_df,
#    TAB_df,
#    TAM_df,
#    TLA_df,
#    VER_df,
#    YUC_df,
#    ZAC_df,
#]

# %%
Estados1

# %%
CSVList = [
    AGS_df,
    BCN_df,
    BCS_df,
    CAM_df,
    CDMX_dfA,
    CHP_df,
    CHH_df,
    COA_df,
    COL_df,
    DUR_df,
    EDOMEX_dfA,
    GUA_df,
    GRO_df,
    HID_df,
    JAL_df,
    MIC_df,
    MOR_df,
    NAY_df,
    NLE_df,
    OAX_df,
    PUE_df,
    QRO_dfA,
    ROO_dfA,
    SLP_df,
    SIN_df,
    SON_df,
    TAB_df,
    TAM_df,
    TLA_df,
    VER_df,
    YUC_df,
    ZAC_df,
]

# %%
Estados1

# %%
CSVList = [PUE_df, QRO_dfA]

# %%
A = CSVList[0]
product = A['0'].values.tolist()
#print(len(product))
product

# %%
#Comenzar la extraccion
for a in range(0,len(CSVList)):
    print(f"Arranca {a}")
    Propiedades = {
        'Marca':[],#Marca
        'Clasificacion':[],#Clasificacion
        'Tipo':[],#Tipo
        'Estado':[],#Estado
        'Municipio':[],#Municipio
        'Colonia':[],#Colonia
        'Colonia2':[],#Colonia2
        'Street':[],#Street
        'Price':[],#Price
        'Moneda':[], #MonedaJ
        'PriceClean':[],#Price1
        'Superficie_Terreno':[],#Terreno
        'Superficie_Construida':[],#Construccion
        'Recamaras':[],#Recamaras
        'Banos':[],#Banos
        'Medio_Bano':[],#Medio_Bano
        'Estacionamientos':[],#Estacionamiento
        'CordA':[],#Coord
        'URL':[],#f'https://century21mexico.com{CasasList[x]}'
    }
    try:
        A = CSVList[a]
        #print("OK2")
        inmuebles = A['0'].values.tolist()
        #A = CSVList[0]
        #product = A['0'].values.tolist()
        #print("OK3")
        print(len(inmuebles))
        #print(f"Comienza {A}")
        for i in range(0,len(inmuebles)):
            #print("OK4")
            
            try:
                
                url = f"https://www.inmuebles24.com{inmuebles[i]}"#propiedades/ciudad-argentum-53621157.html"
                #print(url)
                #url = f"https://www.inmuebles24.com/inmuebles-en-venta-en-{Estado}.html"
                browser.visit(url)
                time.sleep(2)  
                html = browser.html
                soup = bs(html,"html.parser")
                
                Generales = soup.findAll('li', class_="bread-item")
                Marca = Generales[0].getText().replace('\n', '').strip()
                Clasificacion = Generales[1].getText().replace('\n', '').strip()
                Tipo = Generales[2].getText().replace('\n', '').strip()
                Estado = Generales[3].getText().replace('\n', '').strip()
                Municipio = Generales[4].getText().replace('\n', '').strip()
                Colonia = Generales[5].getText().replace('\n', '').strip()
                Colonia2 = Generales[6].getText().replace('\n', '').strip()
                #print("OK Generales")
                
                try:
                    #print("Probamos Opcion 1")
                    HouseDATA1 = soup.findAll('span', class_="data")
                    Terreno = HouseDATA1[4].getText()
                    Construccion = HouseDATA1[1].getText()
                    Banos = ""
                    Estacionamiento = HouseDATA1[5].getText()
                    Recamaras = HouseDATA1[3].getText()
                    Medio_Bano = ""
                      
                    
                    Price = soup.findAll('span', class_="data-price")
                    Price = Price[0].getText().replace('\n', '').strip()
                    Moneda = Price[:3]
                    Price1 = Price.replace('MN ', '').strip()
                    Price1 = Price1.replace(',', '').strip()
                    #print("Opcion 1 OK")
                    
                except:
                    #print("Opcion 1 FAIL")
                    pass
        
                try:
                    #print("Probamos Opcion 2")
                    HouseData2 = soup.findAll('li', class_="icon-feature")
                    Terreno = HouseData2[0].getText().replace('\n', '').strip()
                    Construccion = HouseData2[1].getText().replace('\n', '').strip()
                    Banos = HouseData2[2].getText().replace('\n', '').strip()
                    Estacionamiento = HouseData2[3].getText().replace('\n', '').strip()
                    Recamaras = HouseData2[4].getText().replace('\n', '').strip()
                    Medio_Bano = HouseData2[5].getText().replace('\n', '').strip()
                    
                    Price = soup.findAll('div', class_="price-items")
                    Price = Price[0].getText().replace('\n', '').strip()
                    Moneda = Price[:3]
                    Price1 = Price.replace('MN ', '').strip()
                    Price1 = Price1.replace(',', '').strip()
                    #print("Opcion 2 OK")
                
                except:
                    #print("Opcion 2 FAIL")
                    pass
                
                
                Street = soup.findAll('div', class_="section-location")
                Street = Street[0].getText().replace('\n', '').strip()
            
                Coord = soup.findAll('img', class_="static-map")
                Coord = Coord[0]['src']
                Coord = re.findall('center=(.+)&zoom', Coord)
                #print("ALL OK")
            
            except:
                #print(f"Error Inmueble {i} de {a}")
                pass
            
            #print(f"ALL Inmuebles {i}OK")

            Propiedades["Marca"].append(Marca)
            Propiedades["Clasificacion"].append(Clasificacion)
            Propiedades["Tipo"].append(Tipo)
            Propiedades["Estado"].append(Estado)
            Propiedades["Municipio"].append(Municipio)
            Propiedades["Colonia"].append(Colonia)
            Propiedades["Colonia2"].append(Colonia2)
            Propiedades["Street"].append(Street)
            Propiedades["Price"].append(Price)
            Propiedades["Moneda"].append(Moneda)
            Propiedades["PriceClean"].append(Price1)
            Propiedades["Superficie_Terreno"].append(Terreno)
            Propiedades["Superficie_Construida"].append(Construccion)
            Propiedades["Recamaras"].append(Recamaras)
            Propiedades["Banos"].append(Banos)
            Propiedades["Medio_Bano"].append(Medio_Bano)
            Propiedades["Estacionamientos"].append(Estacionamiento)
            Propiedades["CordA"].append(Coord)
            Propiedades["URL"].append(url)
        
            print(f"Edo {a} append {i} of {len(inmuebles)} OK")
        
        ###TO CSV###
        Name = a+20
        Propiedades_DF = pd.DataFrame(Propiedades)
        Propiedades_DF.to_csv(f'Propiedades {Tipo} {Estados[Name]}.csv', index=False, encoding='utf-8-sig')
        Propiedades_DF
        
    except:
        print(f"Error in {a}")
        pass
    
    
    print(f"ALL CSVs OK")

#"aguascalientes-provincia" 0 - "baja-california-norte" 1 -"baja-california-sur" 2 - "campeche-provincia" 3
#"distrito-federal" 4 - "chiapas" 5 - "chihuahua-provincia" 6 - "coahuila" 7 - "colima-provincia" 8- 
#"durango-provincia" 9 - "edo.-de-mexico" 10 - "guanajuato-provincia" 11 - "guerrero-provincia" 12 -
#"hidalgo-provincia" 13 - "jalisco" 14 - "michoacan" 15 - "morelos-provincia" 16 - "nayarit" 17 -
#"nuevo-leon" 18 - "oaxaca" 19 - "puebla-provincia" 20 - "queretaro-provincia" 21 - "quintana-roo-provincia" 22 -
#"san-luis-potosi-provincia" 23 - "sinaloa-provincia" 24 - "sonora" 25 - "tabasco-provincia" 26 - 
#"tamaulipas" 27 - "tlaxcala-provincia" 28 - "veracruz-provincia" 29 - "yucatan" 30 - "zacatecas-provincia" 31.

# %%
Propiedades

# %%
soup

# %%
url = f"https://www.inmuebles24.com/propiedades/ciudad-argentum-53621157.html"
#url = f"https://www.inmuebles24.com/propiedades/venta-de-casa-en-privada-san-roman-ciudad-del-carmen-58203306.html"
#url = f"https://www.inmuebles24.com/inmuebles-en-venta-en-{Estado}.html"
browser.visit(url)
time.sleep(2)  
html = browser.html
soup = bs(html,"html.parser")

# %%
#Ubicacion = soup.findAll('li', class_="bread-item")
#Ubicacion
Generales = soup.findAll('li', class_="bread-item")
Marca = Generales[0].getText().replace('\n', '').strip()
Clasificacion = Generales[1].getText().replace('\n', '').strip()
Tipo = Generales[2].getText().replace('\n', '').strip()
Estado = Generales[3].getText().replace('\n', '').strip()
Municipio = Generales[4].getText().replace('\n', '').strip()
Colonia = Generales[5].getText().replace('\n', '').strip()
Colonia2 = Generales[6].getText().replace('\n', '').strip()
#A = Ubicacion[0].getText().replace('\n', '').strip()
#B = Ubicacion[1].getText().replace('\n', '').strip()
#C = Ubicacion[2].getText().replace('\n', '').strip()
#D = Ubicacion[3].getText().replace('\n', '').strip()
#E = Ubicacion[4].getText().replace('\n', '').strip()
#F = Ubicacion[5].getText().replace('\n', '').strip()
#G = Ubicacion[6].getText().replace('\n', '').strip()

print(f"Pagina posicion 0 = {Marca}")
print(f"Construccion posicion 1 = {Clasificacion}")
print(f"Tipo posicion 2 = {Tipo}")
print(f"Estado posicion 3 = {Estado}")
print(f"Municipio posicion 4 = {Municipio}")
print(f"Colonia posicion 5 = {Colonia}")
print(f"Colonia2 posicion 6 = {Colonia2}")

# %%
Street = soup.findAll('div', class_="section-location")
Street[0].getText().replace('\n', '').strip()

# %%
#Opcion1
Price = soup.findAll('span', class_="data-price")
Price = Price[0].getText().replace('\n', '').strip()
Moneda = Price[:3]
Price1 = Price.replace('MN ', '').strip()
Price1 = Price1.replace(',', '').strip()

# %%
#Opcion2
Price = soup.findAll('div', class_="price-items")
Price = Price[0].getText().replace('\n', '').strip()
Moneda = Price[:3]
Price = Price.replace('MN ', '').strip()
Price = Price.replace(',', '').strip()
print(Moneda)
print(Price)

# %%
#Opcion1.1
HouseDATA1 = soup.findAll('span', class_="data")
M2_Const = HouseDATA1[1].getText()
Recamaras = HouseDATA1[3].getText()
M2_Terreno = HouseDATA1[4].getText()
Estacionamiento = HouseDATA1[5].getText()

print(f"M2 Construidos ={M2_Const}")
print(f"Recamaras posicion 3 ={Recamaras}")
print(f"M2 Terreno posicion 4 ={M2_Terreno}")
print(f"M2 Construidos posicion 5 ={Estacionamiento}")

# %%
#Opcion2.1
HouseData2 = soup.findAll('li', class_="icon-feature")
Terreno = HouseData2[0].getText().replace('\n', '').strip()
Construccion = HouseData2[1].getText().replace('\n', '').strip()
Banos = HouseData2[2].getText().replace('\n', '').strip()
Estacionamiento = HouseData2[3].getText().replace('\n', '').strip()
Recamaras = HouseData2[4].getText().replace('\n', '').strip()
Medio_Bano = HouseData2[5].getText().replace('\n', '').strip()
print(Terreno)
print(Construccion)
print(Banos)
print(Estacionamiento)
print(Recamaras)
print(Medio_Bano)

# %%
Coord = soup.findAll('img', class_="static-map")
Coord = Coord[0]['src']
Coord = re.findall('center=(.+)&zoom', Coord)
Coord
#Coord[0].getText().replace('\n', '').strip()

# %%
Propiedades = {
        'Tipo':[],#data3['@type'']
        #'Propiedad':[],#data3['address']['addressRegion']
        'Pais':[],#data3['address']['addressCountry']
        'Ciudad':[],#data3['address']['addressRegion']
        'Municipio':[],#data3['address']['addressLocality']
        'Calle':[],#data3['address']['streetAddress']
        'Codigo_Postal':[],#data3['address']['postalCode']
        'Precio':[],#data3['potentialAction']['priceSpecification']['price']
        'Moneda':[],#data3['potentialAction']['priceSpecification']['priceCurrency']
        #'Superficie_Total':[],#data3[]
        'Superficie_Construida':[],#data3['floorSize']
        'Recamaras':[],#data3['numberOfRooms']
        #'Estacionamientos':[],#data3[]
        'DataT':[],#DataT
        'Tipo2':[],#Tipo
        'Precio2':[],#Precio
        'Superficie_Total2':[],#Terreno
        'Superficie_Construida2':[],#Construccion
        'Recamaras2':[],#Recamaras
        'Banos2':[],#BanosC
        'MBanos':[],#MBanos
        'Estacionamientos2':[],#Estacionamientos
        'Niveles':[],#Niveles
        'CordA':[],#Coord4
        'URL':[],#f'https://century21mexico.com{CasasList[x]}'
    
    }

# %%
for x in range(0,len(CasasList)):
    try:
        url = f'https://century21mexico.com{CasasList[x]}'
        Century_request = requests.get(url)
        Century = bs(Century_request.text, "html.parser")
        #time.sleep(4)
        data2 = Century.find('script', type='application/ld+json')
        data2_1 = str(data2)
        data2_1 = data2_1.replace('<script type="application/ld+json">\n', '').strip()
        data2_1 = data2_1.replace('\n', '').strip()
        data2_1 = data2_1.replace('\t', '').strip()
        data2_1 = data2_1.replace('</script>', '').strip()
        data3 = json.loads(data2_1)
        try:
            Coord2 = Century.find('img', class_="img-static-map").get('onclick')
            Coord3 = Coord2.replace('myNavFunc(', '').strip()
            Coord4 = Coord3.replace(')', '').strip()
        except:
            Coord4 = Century.find('img', class_="img-static-map")
        DataT = Century.find('div', class_="col-lg-6").text
        DataT = DataT.replace('\n', '').strip()
        Tipo = re.findall('Tipo:(.+)Precio de venta:', DataT)
        Precio = re.findall('Precio de venta:(.+)Superficie de terreno:', DataT)
        Terreno = re.findall('Superficie de terreno:(.+)Superficie de construcción:', DataT)
        Construccion = re.findall('Superficie de construcción:(.+)Superficie de frente:', DataT)
        Recamaras = re.findall('Recámaras:(.+)Baños completos:', DataT)
        BanosC = re.findall('Baños completos:(.+)Medios Baños:', DataT)
        MBanos = re.findall('Medios Baños:(.+)Estacionamientos:', DataT)
        Estacionamientos = re.findall('Estacionamientos:(.+)Edad:', DataT)
        Niveles = re.findall('Niveles construidos:(.+)Cocina:', DataT)
        #print(f"OK {CasasList[x]} corresponde a {x}")
        #Propiedades["Categoria"].append(Valores[0].getText().replace('\n', '').strip())
        Propiedades["Tipo"].append(data3['@type'])
        #print("OK Tipo")
        #Propiedades["V o R"].append()
        Propiedades["Pais"].append(data3['address']['addressCountry'])
        #print("OK Pais")
        Propiedades["Ciudad"].append(data3['address']['addressRegion'])
        #print("OK Ciudad")
        Propiedades["Municipio"].append(data3['address']['addressLocality'])
        #print("OK Municipio")
        Propiedades["Calle"].append(data3['address']['streetAddress'])
        #print("OK Calle")
        Propiedades["Codigo_Postal"].append(data3['address']['postalCode'])
        #print("OK Codigo Postal")
        Propiedades["Precio"].append(data3['potentialAction']['priceSpecification']['price'])
        #print("OK Precio")
        Propiedades["Moneda"].append(data3['potentialAction']['priceSpecification']['priceCurrency'])
        #print("OK Moneda")
        #Propiedades["Superficie_Total"].append()
        Propiedades["Superficie_Construida"].append(data3['floorSize'])
        #print("OK Sup Construida")
        Propiedades["Recamaras"].append(data3['numberOfRooms'])
        #print("OK Recamaras 1")
        #Propiedades["Banos"].append()
        #Propiedades["Estacionamientos"].append()
        Propiedades["DataT"].append(DataT)
        #print("OK DataT")
        Propiedades["Tipo2"].append(Tipo)
        #print("OK Tipo2")
        Propiedades["Precio2"].append(Precio)
        #print("OK Precio2")
        Propiedades["Superficie_Total2"].append(Terreno)
        #print("OK Terreno")
        Propiedades["Superficie_Construida2"].append(Construccion)
        #print("OK Construccion")
        Propiedades["Recamaras2"].append(Recamaras)
        #print("OK Recamaras")
        Propiedades["Banos2"].append(BanosC)
        #print("OK BanosC")
        Propiedades["MBanos"].append(MBanos)
        #print("OK MBanos")
        Propiedades["Estacionamientos2"].append(Estacionamientos)
        #print("OK Estacionamientos2")
        Propiedades["Niveles"].append(Niveles)
        #print("OK Niveles")
        Propiedades["CordA"].append(Coord4)
        #print("OK CordA")
        Propiedades["URL"].append(f'https://century21mexico.com{CasasList[x]}')
        print(f"OK {x} de {len(CasasList)}")
        
    except:
        print(f"Error Pagina {x}")
        pass

Propiedades_DF = pd.DataFrame(Propiedades)
Propiedades_DF.to_csv('Propiedades_DF.csv', index=False, encoding='utf-8-sig')
Propiedades_DF

# %%
# URL of page to be scraped
url = 'https://www.inmuebles24.com/inmuebles-en-venta-pagina-14139.html'

# %%
browser.visit(url)
time.sleep(2)  
html = browser.html
soup = bs(html,"html.parser")

# %%
soup

# %%
Casas = soup.findAll('h2', class_="posting-title")
TotalCasas = len(Casas)
TotalCasas

# %%
Data4 = Century.findAll('div', class_="col blackTxt border-right")
X = Data4[0].text
X

# %%
print(Data4[0].text)
print(Data4[1].text)
print(Data4[2].text)
print(Data4[3].text)

# %%
Data5 = Century.findAll('div', class_="col blackTxt")
X = Data5[0].text
X
#X = Data4[0].text
#X

# %%
data2 = Century.find('script', type='application/ld+json')
data2

# %%
data2_1 = str(data2)
data2_1

# %%
data2_1 = data2_1.replace('<script type="application/ld+json">\n', '').strip()
data2_1 = data2_1.replace('\n', '').strip()
data2_1 = data2_1.replace('\t', '').strip()
data2_1 = data2_1.replace('</script>', '').strip()
data2_1

# %%
data3 = json.loads(data2_1)
data3

# %%
print(f"Tipo {data3['@type']}")
print(f" Pais {data3['address']['addressCountry']}")
print(f"Estado {data3['address']['addressRegion']}")
print(f" Municipio {data3['address']['addressLocality']}")
print(f" Calle {data3['address']['streetAddress']}")
print(f" CP {data3['address']['postalCode']}")
print(f" Precio {data3['potentialAction']['priceSpecification']['price']}")
print(f" Moneda {data3['potentialAction']['priceSpecification']['priceCurrency']}")
print(f" Construccion {data3['floorSize']}")
print(f" Cuartos {data3['numberOfRooms']}")

# %%
Coord = Century.find('div', id='map-static')#.get('img')#, onclick=True)
#Coord = Century.getElementById('map-static').onclick.toString()
Coord

# %%
Coord2 = Century.find('img', class_="img-static-map").get('onclick')#, onclick=True)
#Coord = Century.getElementById('map-static').onclick.toString()
Coord2

# %%
Coord3 = Coord2.replace('myNavFunc(', '').strip()
Coord4 = Coord3.replace(')', '').strip()
Coord4

# %%
url

# %%
DataT = Century.find('div', class_="col-lg-6").text
DataT = DataT.replace('\n', '').strip()
#DataT = Century.findAll('i', class_="fal fa-tags")
DataT

# %%
Tipo = re.findall('Tipo:(.+)Precio de venta:', DataT)
Precio = re.findall('Precio de venta:(.+)Superficie de terreno:', DataT)
Terreno = re.findall('Superficie de terreno:(.+)Superficie de construcción:', DataT)
Construccion = re.findall('Superficie de construcción:(.+)Superficie de frente:', DataT)
Recamaras = re.findall('Recámaras:(.+)Baños completos:', DataT)
BanosC = re.findall('Baños completos:(.+)Medios Baños:', DataT)
MBanos = re.findall('Medios Baños:(.+)Estacionamientos:', DataT)
Estacionamientos = re.findall('Estacionamientos:(.+)Edad:', DataT)
Niveles = re.findall('Niveles construidos:(.+)Cocina:', DataT)
print(Tipo)
print(Precio)
print(Terreno)
print(Construccion)
print(Recamaras)
print(BanosC)
print(MBanos)
print(Estacionamientos)
print(Niveles)

# %%
Propiedades_DF = pd.DataFrame(Propiedades)
Propiedades_DF.to_csv('Propiedades_DF.csv', index=False, encoding='utf-8-sig')
Propiedades_DF

# %%
Recamaras

# %%
Century_request = requests.get(TEST)
Century = bs(Century_request.text, "html.parser")
time.sleep(4)
data2 = Century.find('script', type='application/ld+json')
data2_1 = str(data2)
data2_1 = data2_1.replace('<script type="application/ld+json">\n', '').strip()
data2_1 = data2_1.replace('\n', '').strip()
data2_1 = data2_1.replace('\t', '').strip()
data2_1 = data2_1.replace('</script>', '').strip()
data3 = json.loads(data2_1)
Coord2 = Century.find('img', class_="img-static-map")#.get('onclick')
#Coord3 = Coord2.replace('myNavFunc(', '').strip()
#Coord4 = Coord3.replace(')', '').strip()
DataT = Century.find('div', class_="col-lg-6").text
DataT = DataT.replace('\n', '').strip()
Tipo = re.findall('Tipo:(.+)Precio de venta:', DataT)
Precio = re.findall('Precio de venta:(.+)Superficie de terreno:', DataT)
Terreno = re.findall('Superficie de terreno:(.+)Superficie de construcción:', DataT)
Construccion = re.findall('Superficie de construcción:(.+)Superficie de frente:', DataT)
Recamaras = re.findall('Recámaras:(.+)Baños completos:', DataT)
BanosC = re.findall('Baños completos:(.+)Medios Baños:', DataT)
MBanos = re.findall('Medios Baños:(.+)Estacionamientos:', DataT)
Estacionamientos = re.findall('Estacionamientos:(.+)Edad:', DataT)
Niveles = re.findall('Niveles construidos:(.+)Cocina:', DataT)
print(f"OK")#{CasasList[x]} corresponde a {x}")

# %%
Casas2 = Century2.findAll('div', class_="row propiedades")
Casas2_1 = bs(Casas2.text, "html.parser")
Casas2_1
#Casas3 = Casas3.findAll('div', class_="card rounded-0")
#Casas3

# %%
#for Casas = Century2.findAll('div', class_="card rounded-0")
for Inmuebles1 in Century2.find_all('div', attrs={'class': 'row propiedades'}):
    for Inmuebles2 in Inmuebles1.find_all('div', attrs={'class': 'card rounded-0'}):
        Casas = Century2.find_all("div", attrs={'class': 'card rounded-0'})
#    for a in bar.find('p'):
#        print(a)  
Casas

# %%
Ciudades = ["Puebla",
            "Morelos",
            "estado-de-mexico",
            "distrito-federal",
            "Hidalgo"
           ]
Ciudades

# %%
PMin1 = "1000000"
PMax1 = "1249999"
PMin2 = "1250000"
PMax2 = "1499999"
PMin3 = "1500000"
PMax3 = "1749999"
PMin4 = "1750000"
PMax4 = "2000000"
Pagina = 1

# %%
##All Cities 1
for i in Ciudades:
    ciudad = i
    print(f"Inicia {ciudad}")
    URL = f"https://inmuebles.mercadolibre.com.mx/casas/venta/{ciudad}/_Desde_{Pagina}_OrderId_PRICE*DESC_PriceRange_{PMin1}-{PMax1}"
    browser.visit(URL)
    time.sleep(4)  
    html = browser.html
    soup = bs(html,"html.parser")
    ##Paginas a visitar##
    Paginas= []
    Casas = []
    ### Diccionario MORELOS ###
    Propiedades = {
        'Categoria':[],
        'Tipo':[],
        'V o R':[],
        'Propiedad':[],
        'Ciudad':[],
        'Municipio':[],
        'Colonia':[],
        'Precio':[],
        'Superficie total':[],
        'Superficie construida':[],
        'Recámaras':[],
        'Baños':[],
        'Estacionamientos':[],
        'CordA':[],
        'CordB':[],
        'CordC':[],
        'CordD':[],
        'CordE':[],
        'CordF':[],
        'CordG':[],
        'CordH':[],
        'CordI':[],
        'CordJ':[],
        'CordK':[],
        'CordL':[],
        'CordM':[],
        'CordN':[],
        'CordO':[],
        'CordP':[],
        'CordQ':[],
        'CordR':[],
        'CordS':[],
        'url':[]
    }
    
    for a in soup.find_all('a', class_="andes-pagination__link"):
        Paginas.append(a['href'])
    
    for x in Paginas:
        try:
            browser.visit(x)
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            for a in soup.find_all('a', class_="item__info-link"):
                Casas.append(a['href'])
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
    
    TotalCasas = len(Casas)
    print(f"Total de casas {TotalCasas} en {ciudad} ")
    
    for y in range(0, TotalCasas):
        try:
            browser.visit(Casas[y])
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            Valores = soup.findAll('a', class_="breadcrumb")
          
            price = soup.find('span', class_="price-tag-fraction").getText()  
            Caracteristicas = soup.findAll('li', class_="specs-item")
          
            Location = soup.findAll('img')
            CordA = Location[15]['src']
            CordB = Location[16]['src']
            CordC = Location[17]['src']
            try:
                CordD = Location[18]['src']
            except:
                pass
            try:
                CordE = Location[19]['src']
            except:
                pass
            try:
                CordF = Location[20]['src']
            except:
                pass
            try:
                CordG = Location[21]['src']
            except:
                pass
            try:
                CordH = Location[22]['src']
            except:
                pass
            try:
                CordI = Location[23]['src']
            except:
                pass
            try:
                CordJ = Location[24]['src']
            except:
                pass
            try:
                CordK = Location[25]['src']
            except:
                pass
            try:
                CordL = Location[26]['src']
            except:
                pass
            try:
                CordM = Location[27]['src']
            except:
                pass
            try:
                CordN = Location[28]['src']
            except:
                pass
            try:
                CordO = Location[28]['src']
            except:
                pass
            try:
                CordP = Location[29]['src']
            except:
                pass
            try:
                CordQ = Location[30]['src']
            except:
                pass
            try:
                CordR = Location[31]['src']
            except:
                pass
            try:
                CordS = Location[32]['src']
            except:
                pass
          
        
        
            Propiedades["Categoria"].append(Valores[0].getText().replace('\n', '').strip())
            Propiedades["Tipo"].append(Valores[1].getText().replace('\n', '').strip())
            Propiedades["V o R"].append(Valores[2].getText().replace('\n', '').strip())
            Propiedades["Propiedad"].append(Valores[3].getText().replace('\n', '').strip())
            Propiedades["Ciudad"].append(Valores[4].getText().replace('\n', '').strip())
            Propiedades["Municipio"].append(Valores[5].getText().replace('\n', '').strip())
            Propiedades["Colonia"].append(Valores[6].getText().replace('\n', '').strip())
            Propiedades["Precio"].append(price)
            Propiedades["Superficie total"].append(Caracteristicas[0].getText().replace('\n', '').strip())
            Propiedades["Superficie construida"].append(Caracteristicas[1].getText().replace('\n', '').strip())
            Propiedades["Recámaras"].append(Caracteristicas[2].getText().replace('\n', '').strip())
            Propiedades["Baños"].append(Caracteristicas[3].getText().replace('\n', '').strip())
            Propiedades["Estacionamientos"].append(Caracteristicas[4].getText().replace('\n', '').strip())
            Propiedades["CordA"].append(CordA)
            Propiedades["CordB"].append(CordB)
            Propiedades["CordC"].append(CordC)
            Propiedades["CordD"].append(CordD)
            Propiedades["CordE"].append(CordE)
            Propiedades["CordF"].append(CordF)
            Propiedades["CordG"].append(CordG)
            Propiedades["CordH"].append(CordH)
            Propiedades["CordI"].append(CordI)
            Propiedades["CordJ"].append(CordJ)
            Propiedades["CordK"].append(CordK)
            Propiedades["CordL"].append(CordL)
            Propiedades["CordM"].append(CordM)
            Propiedades["CordN"].append(CordN)
            Propiedades["CordO"].append(CordO)
            Propiedades["CordP"].append(CordP)
            Propiedades["CordQ"].append(CordQ)
            Propiedades["CordR"].append(CordR)
            Propiedades["CordS"].append(CordS)
            Propiedades["url"].append(Casas[y])            
            print(f"{y} de {ciudad}")
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
        
    Data_DF = pd.DataFrame.from_dict(Propiedades, orient='index').T
    Data_DF.to_csv(f'Propiedades{ciudad}1.csv', index=False, encoding='utf-8-sig')
     
    print(f"***FINAL {ciudad}***")

# %%
##All Cities 2
for i in Ciudades:
    ciudad = i
    print(f"Inicia {ciudad}")
    URL = f"https://inmuebles.mercadolibre.com.mx/casas/venta/{ciudad}/_Desde_{Pagina}_OrderId_PRICE*DESC_PriceRange_{PMin2}-{PMax2}"
    browser.visit(URL)
    time.sleep(4)  
    html = browser.html
    soup = bs(html,"html.parser")
    ##Paginas a visitar##
    Paginas= []
    Casas = []
    ### Diccionario MORELOS ###
    Propiedades = {
        'Categoria':[],
        'Tipo':[],
        'V o R':[],
        'Propiedad':[],
        'Ciudad':[],
        'Municipio':[],
        'Colonia':[],
        'Precio':[],
        'Superficie total':[],
        'Superficie construida':[],
        'Recámaras':[],
        'Baños':[],
        'Estacionamientos':[],
        'CordA':[],
        'CordB':[],
        'CordC':[],
        'CordD':[],
        'CordE':[],
        'CordF':[],
        'CordG':[],
        'CordH':[],
        'CordI':[],
        'CordJ':[],
        'CordK':[],
        'CordL':[],
        'CordM':[],
        'CordN':[],
        'CordO':[],
        'CordP':[],
        'CordQ':[],
        'CordR':[],
        'CordS':[],
        'url':[]
    }
    
    for a in soup.find_all('a', class_="andes-pagination__link"):
        Paginas.append(a['href'])
    
    for x in Paginas:
        try:
            browser.visit(x)
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            for a in soup.find_all('a', class_="item__info-link"):
                Casas.append(a['href'])
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
    
    TotalCasas = len(Casas)
    print(f"Total de casas {TotalCasas} en {ciudad} ")
    
    for y in range(0, TotalCasas):
        try:
            browser.visit(Casas[y])
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            Valores = soup.findAll('a', class_="breadcrumb")
          
            price = soup.find('span', class_="price-tag-fraction").getText()  
            Caracteristicas = soup.findAll('li', class_="specs-item")
          
            Location = soup.findAll('img')
            CordA = Location[15]['src']
            CordB = Location[16]['src']
            CordC = Location[17]['src']
            try:
                CordD = Location[18]['src']
            except:
                pass
            try:
                CordE = Location[19]['src']
            except:
                pass
            try:
                CordF = Location[20]['src']
            except:
                pass
            try:
                CordG = Location[21]['src']
            except:
                pass
            try:
                CordH = Location[22]['src']
            except:
                pass
            try:
                CordI = Location[23]['src']
            except:
                pass
            try:
                CordJ = Location[24]['src']
            except:
                pass
            try:
                CordK = Location[25]['src']
            except:
                pass
            try:
                CordL = Location[26]['src']
            except:
                pass
            try:
                CordM = Location[27]['src']
            except:
                pass
            try:
                CordN = Location[28]['src']
            except:
                pass
            try:
                CordO = Location[28]['src']
            except:
                pass
            try:
                CordP = Location[29]['src']
            except:
                pass
            try:
                CordQ = Location[30]['src']
            except:
                pass
            try:
                CordR = Location[31]['src']
            except:
                pass
            try:
                CordS = Location[32]['src']
            except:
                pass
          
        
        
            Propiedades["Categoria"].append(Valores[0].getText().replace('\n', '').strip())
            Propiedades["Tipo"].append(Valores[1].getText().replace('\n', '').strip())
            Propiedades["V o R"].append(Valores[2].getText().replace('\n', '').strip())
            Propiedades["Propiedad"].append(Valores[3].getText().replace('\n', '').strip())
            Propiedades["Ciudad"].append(Valores[4].getText().replace('\n', '').strip())
            Propiedades["Municipio"].append(Valores[5].getText().replace('\n', '').strip())
            Propiedades["Colonia"].append(Valores[6].getText().replace('\n', '').strip())
            Propiedades["Precio"].append(price)
            Propiedades["Superficie total"].append(Caracteristicas[0].getText().replace('\n', '').strip())
            Propiedades["Superficie construida"].append(Caracteristicas[1].getText().replace('\n', '').strip())
            Propiedades["Recámaras"].append(Caracteristicas[2].getText().replace('\n', '').strip())
            Propiedades["Baños"].append(Caracteristicas[3].getText().replace('\n', '').strip())
            Propiedades["Estacionamientos"].append(Caracteristicas[4].getText().replace('\n', '').strip())
            Propiedades["CordA"].append(CordA)
            Propiedades["CordB"].append(CordB)
            Propiedades["CordC"].append(CordC)
            Propiedades["CordD"].append(CordD)
            Propiedades["CordE"].append(CordE)
            Propiedades["CordF"].append(CordF)
            Propiedades["CordG"].append(CordG)
            Propiedades["CordH"].append(CordH)
            Propiedades["CordI"].append(CordI)
            Propiedades["CordJ"].append(CordJ)
            Propiedades["CordK"].append(CordK)
            Propiedades["CordL"].append(CordL)
            Propiedades["CordM"].append(CordM)
            Propiedades["CordN"].append(CordN)
            Propiedades["CordO"].append(CordO)
            Propiedades["CordP"].append(CordP)
            Propiedades["CordQ"].append(CordQ)
            Propiedades["CordR"].append(CordR)
            Propiedades["CordS"].append(CordS)
            Propiedades["url"].append(Casas[y])            
            print(f"{y} de {ciudad}")
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
        
    Data_DF = pd.DataFrame.from_dict(Propiedades, orient='index').T
    Data_DF.to_csv(f'Propiedades{ciudad}2.csv', index=False, encoding='utf-8-sig')
     
    print(f"***FINAL {ciudad}***")

# %%
##All Cities 3
for i in Ciudades:
    ciudad = i
    print(f"Inicia {ciudad}")
    URL = f"https://inmuebles.mercadolibre.com.mx/casas/venta/{ciudad}/_Desde_{Pagina}_OrderId_PRICE*DESC_PriceRange_{PMin3}-{PMax3}"
    browser.visit(URL)
    time.sleep(4)  
    html = browser.html
    soup = bs(html,"html.parser")
    ##Paginas a visitar##
    Paginas= []
    Casas = []
    ### Diccionario MORELOS ###
    Propiedades = {
        'Categoria':[],
        'Tipo':[],
        'V o R':[],
        'Propiedad':[],
        'Ciudad':[],
        'Municipio':[],
        'Colonia':[],
        'Precio':[],
        'Superficie total':[],
        'Superficie construida':[],
        'Recámaras':[],
        'Baños':[],
        'Estacionamientos':[],
        'CordA':[],
        'CordB':[],
        'CordC':[],
        'CordD':[],
        'CordE':[],
        'CordF':[],
        'CordG':[],
        'CordH':[],
        'CordI':[],
        'CordJ':[],
        'CordK':[],
        'CordL':[],
        'CordM':[],
        'CordN':[],
        'CordO':[],
        'CordP':[],
        'CordQ':[],
        'CordR':[],
        'CordS':[],
        'url':[]
    }
    
    for a in soup.find_all('a', class_="andes-pagination__link"):
        Paginas.append(a['href'])
    
    for x in Paginas:
        try:
            browser.visit(x)
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            for a in soup.find_all('a', class_="item__info-link"):
                Casas.append(a['href'])
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
    
    TotalCasas = len(Casas)
    print(f"Total de casas {TotalCasas} en {ciudad} ")
    
    for y in range(0, TotalCasas):
        try:
            browser.visit(Casas[y])
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            Valores = soup.findAll('a', class_="breadcrumb")
          
            price = soup.find('span', class_="price-tag-fraction").getText()  
            Caracteristicas = soup.findAll('li', class_="specs-item")
          
            Location = soup.findAll('img')
            CordA = Location[15]['src']
            CordB = Location[16]['src']
            CordC = Location[17]['src']
            try:
                CordD = Location[18]['src']
            except:
                pass
            try:
                CordE = Location[19]['src']
            except:
                pass
            try:
                CordF = Location[20]['src']
            except:
                pass
            try:
                CordG = Location[21]['src']
            except:
                pass
            try:
                CordH = Location[22]['src']
            except:
                pass
            try:
                CordI = Location[23]['src']
            except:
                pass
            try:
                CordJ = Location[24]['src']
            except:
                pass
            try:
                CordK = Location[25]['src']
            except:
                pass
            try:
                CordL = Location[26]['src']
            except:
                pass
            try:
                CordM = Location[27]['src']
            except:
                pass
            try:
                CordN = Location[28]['src']
            except:
                pass
            try:
                CordO = Location[28]['src']
            except:
                pass
            try:
                CordP = Location[29]['src']
            except:
                pass
            try:
                CordQ = Location[30]['src']
            except:
                pass
            try:
                CordR = Location[31]['src']
            except:
                pass
            try:
                CordS = Location[32]['src']
            except:
                pass
          
        
        
            Propiedades["Categoria"].append(Valores[0].getText().replace('\n', '').strip())
            Propiedades["Tipo"].append(Valores[1].getText().replace('\n', '').strip())
            Propiedades["V o R"].append(Valores[2].getText().replace('\n', '').strip())
            Propiedades["Propiedad"].append(Valores[3].getText().replace('\n', '').strip())
            Propiedades["Ciudad"].append(Valores[4].getText().replace('\n', '').strip())
            Propiedades["Municipio"].append(Valores[5].getText().replace('\n', '').strip())
            Propiedades["Colonia"].append(Valores[6].getText().replace('\n', '').strip())
            Propiedades["Precio"].append(price)
            Propiedades["Superficie total"].append(Caracteristicas[0].getText().replace('\n', '').strip())
            Propiedades["Superficie construida"].append(Caracteristicas[1].getText().replace('\n', '').strip())
            Propiedades["Recámaras"].append(Caracteristicas[2].getText().replace('\n', '').strip())
            Propiedades["Baños"].append(Caracteristicas[3].getText().replace('\n', '').strip())
            Propiedades["Estacionamientos"].append(Caracteristicas[4].getText().replace('\n', '').strip())
            Propiedades["CordA"].append(CordA)
            Propiedades["CordB"].append(CordB)
            Propiedades["CordC"].append(CordC)
            Propiedades["CordD"].append(CordD)
            Propiedades["CordE"].append(CordE)
            Propiedades["CordF"].append(CordF)
            Propiedades["CordG"].append(CordG)
            Propiedades["CordH"].append(CordH)
            Propiedades["CordI"].append(CordI)
            Propiedades["CordJ"].append(CordJ)
            Propiedades["CordK"].append(CordK)
            Propiedades["CordL"].append(CordL)
            Propiedades["CordM"].append(CordM)
            Propiedades["CordN"].append(CordN)
            Propiedades["CordO"].append(CordO)
            Propiedades["CordP"].append(CordP)
            Propiedades["CordQ"].append(CordQ)
            Propiedades["CordR"].append(CordR)
            Propiedades["CordS"].append(CordS)
            Propiedades["url"].append(Casas[y])            
            print(f"{y} de {ciudad}")
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass

    Data_DF = pd.DataFrame.from_dict(Propiedades, orient='index').T
    Data_DF.to_csv(f'Propiedades{ciudad}3.csv', index=False, encoding='utf-8-sig')
     
    print(f"***FINAL {ciudad}***")

# %%
##All Cities 4
for i in Ciudades:
    ciudad = i
    print(f"Inicia {ciudad}")
    URL = f"https://inmuebles.mercadolibre.com.mx/casas/venta/{ciudad}/_Desde_{Pagina}_OrderId_PRICE*DESC_PriceRange_{PMin4}-{PMax4}"
    browser.visit(URL)
    time.sleep(4)  
    html = browser.html
    soup = bs(html,"html.parser")
    ##Paginas a visitar##
    Paginas= []
    Casas = []
    ### Diccionario MORELOS ###
    Propiedades = {
        'Categoria':[],
        'Tipo':[],
        'V o R':[],
        'Propiedad':[],
        'Ciudad':[],
        'Municipio':[],
        'Colonia':[],
        'Precio':[],
        'Superficie total':[],
        'Superficie construida':[],
        'Recámaras':[],
        'Baños':[],
        'Estacionamientos':[],
        'CordA':[],
        'CordB':[],
        'CordC':[],
        'CordD':[],
        'CordE':[],
        'CordF':[],
        'CordG':[],
        'CordH':[],
        'CordI':[],
        'CordJ':[],
        'CordK':[],
        'CordL':[],
        'CordM':[],
        'CordN':[],
        'CordO':[],
        'CordP':[],
        'CordQ':[],
        'CordR':[],
        'CordS':[],
        'url':[]
    }
    
    for a in soup.find_all('a', class_="andes-pagination__link"):
        Paginas.append(a['href'])
    
    for x in Paginas:
        try:
            browser.visit(x)
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            for a in soup.find_all('a', class_="item__info-link"):
                Casas.append(a['href'])
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
    
    TotalCasas = len(Casas)
    print(f"Total de casas {TotalCasas} en {ciudad} ")
    
    for y in range(0, TotalCasas):
        try:
            browser.visit(Casas[y])
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            Valores = soup.findAll('a', class_="breadcrumb")
          
            price = soup.find('span', class_="price-tag-fraction").getText()  
            Caracteristicas = soup.findAll('li', class_="specs-item")
          
            Location = soup.findAll('img')
            CordA = Location[15]['src']
            CordB = Location[16]['src']
            CordC = Location[17]['src']
            try:
                CordD = Location[18]['src']
            except:
                pass
            try:
                CordE = Location[19]['src']
            except:
                pass
            try:
                CordF = Location[20]['src']
            except:
                pass
            try:
                CordG = Location[21]['src']
            except:
                pass
            try:
                CordH = Location[22]['src']
            except:
                pass
            try:
                CordI = Location[23]['src']
            except:
                pass
            try:
                CordJ = Location[24]['src']
            except:
                pass
            try:
                CordK = Location[25]['src']
            except:
                pass
            try:
                CordL = Location[26]['src']
            except:
                pass
            try:
                CordM = Location[27]['src']
            except:
                pass
            try:
                CordN = Location[28]['src']
            except:
                pass
            try:
                CordO = Location[28]['src']
            except:
                pass
            try:
                CordP = Location[29]['src']
            except:
                pass
            try:
                CordQ = Location[30]['src']
            except:
                pass
            try:
                CordR = Location[31]['src']
            except:
                pass
            try:
                CordS = Location[32]['src']
            except:
                pass
          
        
        
            Propiedades["Categoria"].append(Valores[0].getText().replace('\n', '').strip())
            Propiedades["Tipo"].append(Valores[1].getText().replace('\n', '').strip())
            Propiedades["V o R"].append(Valores[2].getText().replace('\n', '').strip())
            Propiedades["Propiedad"].append(Valores[3].getText().replace('\n', '').strip())
            Propiedades["Ciudad"].append(Valores[4].getText().replace('\n', '').strip())
            Propiedades["Municipio"].append(Valores[5].getText().replace('\n', '').strip())
            Propiedades["Colonia"].append(Valores[6].getText().replace('\n', '').strip())
            Propiedades["Precio"].append(price)
            Propiedades["Superficie total"].append(Caracteristicas[0].getText().replace('\n', '').strip())
            Propiedades["Superficie construida"].append(Caracteristicas[1].getText().replace('\n', '').strip())
            Propiedades["Recámaras"].append(Caracteristicas[2].getText().replace('\n', '').strip())
            Propiedades["Baños"].append(Caracteristicas[3].getText().replace('\n', '').strip())
            Propiedades["Estacionamientos"].append(Caracteristicas[4].getText().replace('\n', '').strip())
            Propiedades["CordA"].append(CordA)
            Propiedades["CordB"].append(CordB)
            Propiedades["CordC"].append(CordC)
            Propiedades["CordD"].append(CordD)
            Propiedades["CordE"].append(CordE)
            Propiedades["CordF"].append(CordF)
            Propiedades["CordG"].append(CordG)
            Propiedades["CordH"].append(CordH)
            Propiedades["CordI"].append(CordI)
            Propiedades["CordJ"].append(CordJ)
            Propiedades["CordK"].append(CordK)
            Propiedades["CordL"].append(CordL)
            Propiedades["CordM"].append(CordM)
            Propiedades["CordN"].append(CordN)
            Propiedades["CordO"].append(CordO)
            Propiedades["CordP"].append(CordP)
            Propiedades["CordQ"].append(CordQ)
            Propiedades["CordR"].append(CordR)
            Propiedades["CordS"].append(CordS)
            Propiedades["url"].append(Casas[y])            
            print(f"{y} de {ciudad}")
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
    
    Data_DF = pd.DataFrame.from_dict(Propiedades, orient='index').T
    Data_DF.to_csv(f'Propiedades{ciudad}4.csv', index=False, encoding='utf-8-sig')
     
    print(f"***FINAL {ciudad}***")

# %%
##All Cities 4

ciudad = "tlaxcala"
print(f"Inicia {ciudad}")
URL = f"https://inmuebles.mercadolibre.com.mx/casas/venta/{ciudad}/_Desde_{Pagina}_OrderId_PRICE*DESC_PriceRange_{PMin1}-{PMax4}"
browser.visit(URL)
time.sleep(4)  
html = browser.html
soup = bs(html,"html.parser")
##Paginas a visitar##
Paginas= []
Casas = []
### Diccionario MORELOS ###
Propiedades = {
    'Categoria':[],
    'Tipo':[],
    'V o R':[],
    'Propiedad':[],
    'Ciudad':[],
    'Municipio':[],
    'Colonia':[],
    'Precio':[],
    'Superficie total':[],
    'Superficie construida':[],
    'Recámaras':[],
    'Baños':[],
    'Estacionamientos':[],
    'CordA':[],
    'CordB':[],
    'CordC':[],
    'CordD':[],
    'CordE':[],
    'CordF':[],
    'CordG':[],
    'CordH':[],
    'CordI':[],
    'CordJ':[],
    'CordK':[],
    'CordL':[],
    'CordM':[],
    'CordN':[],
    'CordO':[],
    'CordP':[],
    'CordQ':[],
    'CordR':[],
    'CordS':[],
    'url':[]
    }
    
for a in soup.find_all('a', class_="andes-pagination__link"):
    Paginas.append(a['href'])
    
for x in Paginas:
    try:
        browser.visit(x)
        time.sleep(4)  
        html = browser.html
        soup = bs(html,"html.parser")
        for a in soup.find_all('a', class_="item__info-link"):
            Casas.append(a['href'])
    except:
        print(f"Error Pagina {x} de {ciudad}")
        pass
    
TotalCasas = len(Casas)
print(f"Total de casas {TotalCasas} en {ciudad} ")
    
for y in range(0, TotalCasas):
    try:
        browser.visit(Casas[y])
        time.sleep(4)  
        html = browser.html
        soup = bs(html,"html.parser")
        Valores = soup.findAll('a', class_="breadcrumb")
          
        price = soup.find('span', class_="price-tag-fraction").getText()  
        Caracteristicas = soup.findAll('li', class_="specs-item")
          
        Location = soup.findAll('img')
        CordA = Location[15]['src']
        CordB = Location[16]['src']
        CordC = Location[17]['src']
        try:
            CordD = Location[18]['src']
        except:
            pass
        try:
            CordE = Location[19]['src']
        except:
            pass
        try:
            CordF = Location[20]['src']
        except:
            pass
        try:
            CordG = Location[21]['src']
        except:
            pass
        try:
            CordH = Location[22]['src']
        except:
            pass
        try:
            CordI = Location[23]['src']
        except:
            pass
        try:
            CordJ = Location[24]['src']
        except:
            pass
        try:
            CordK = Location[25]['src']
        except:
            pass
        try:
            CordL = Location[26]['src']
        except:
            pass
        try:
            CordM = Location[27]['src']
        except:
            pass
        try:
            CordN = Location[28]['src']
        except:
            pass
        try:
            CordO = Location[28]['src']
        except:
            pass
        try:
            CordP = Location[29]['src']
        except:
            pass
        try:
            CordQ = Location[30]['src']
        except:
            pass
        try:
            CordR = Location[31]['src']
        except:
            pass
        try:
            CordS = Location[32]['src']
        except:
            pass
          
        
        
        Propiedades["Categoria"].append(Valores[0].getText().replace('\n', '').strip())
        Propiedades["Tipo"].append(Valores[1].getText().replace('\n', '').strip())
        Propiedades["V o R"].append(Valores[2].getText().replace('\n', '').strip())
        Propiedades["Propiedad"].append(Valores[3].getText().replace('\n', '').strip())
        Propiedades["Ciudad"].append(Valores[4].getText().replace('\n', '').strip())
        Propiedades["Municipio"].append(Valores[5].getText().replace('\n', '').strip())
        Propiedades["Colonia"].append(Valores[6].getText().replace('\n', '').strip())
        Propiedades["Precio"].append(price)
        Propiedades["Superficie total"].append(Caracteristicas[0].getText().replace('\n', '').strip())
        Propiedades["Superficie construida"].append(Caracteristicas[1].getText().replace('\n', '').strip())
        Propiedades["Recámaras"].append(Caracteristicas[2].getText().replace('\n', '').strip())
        Propiedades["Baños"].append(Caracteristicas[3].getText().replace('\n', '').strip())
        Propiedades["Estacionamientos"].append(Caracteristicas[4].getText().replace('\n', '').strip())
        Propiedades["CordA"].append(CordA)
        Propiedades["CordB"].append(CordB)
        Propiedades["CordC"].append(CordC)
        Propiedades["CordD"].append(CordD)
        Propiedades["CordE"].append(CordE)
        Propiedades["CordF"].append(CordF)
        Propiedades["CordG"].append(CordG)
        Propiedades["CordH"].append(CordH)
        Propiedades["CordI"].append(CordI)
        Propiedades["CordJ"].append(CordJ)
        Propiedades["CordK"].append(CordK)
        Propiedades["CordL"].append(CordL)
        Propiedades["CordM"].append(CordM)
        Propiedades["CordN"].append(CordN)
        Propiedades["CordO"].append(CordO)
        Propiedades["CordP"].append(CordP)
        Propiedades["CordQ"].append(CordQ)
        Propiedades["CordR"].append(CordR)
        Propiedades["CordS"].append(CordS)
        Propiedades["url"].append(Casas[y])            
        print(f"{y} de {ciudad}")
    except:
        print(f"Error Pagina {x} de {ciudad}")
        pass
    
Data_DF = pd.DataFrame.from_dict(Propiedades, orient='index').T
Data_DF.to_csv(f'Propiedades{ciudad}4.csv', index=False, encoding='utf-8-sig')
     
print(f"***FINAL {ciudad}***")
