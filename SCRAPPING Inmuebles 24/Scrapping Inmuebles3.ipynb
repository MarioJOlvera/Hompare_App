# %%
# !python --version

# %%
# !pip install --upgrade chromedriver

# %%
# !pip install --upgrade splinter

# %%
#brew cask install chromedriver
#brew cask reinstall chromedriver
#Autorizar en preferenciasa de seguridad el chorme driver

# %%
# Dependencies
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
import requests
import lxml.html as lh
import pandas as pd
import re
import time
import json
import urllib
import urllib.request as urllib2

# %%
executable_path = {"executable_path": "/usr/local/bin/chromedriver"}
browser = Browser("chrome",**executable_path, headless=False)

# %%
url = f"https://www.inmuebles24.com/inmuebles-en-venta-en-aguascalientes.html"
browser.visit(url)
time.sleep(2)  
html = browser.html

# %%
Estados1 = ["puebla-provincia","queretaro-provincia","quintana-roo-provincia"]

# %%
Estados = ["aguascalientes-provincia","baja-california-norte","baja-california-sur","campeche-provincia","distrito-federal",
          "chiapas","chihuahua-provincia","coahuila","colima-provincia","durango-provincia",
          "edo.-de-mexico","guanajuato-provincia","guerrero-provincia","hidalgo-provincia","jalisco",
          "michoacan","morelos-provincia","nayarit","nuevo-leon","oaxaca",
          "puebla-provincia","queretaro-provincia","quintana-roo-provincia","san-luis-potosi-provincia","sinaloa-provincia",
          "sonora","tabasco-provincia","tamaulipas","tlaxcala-provincia","veracruz-provincia",
          "yucatan","zacatecas-provincia"]

# %%
url_All = "https://www.inmuebles24.com/inmuebles-en-venta-en-"
url_Depa = "https://www.inmuebles24.com/departamentos-en-venta-en-"#DEPÀRTAMENTOS
url_Casa = "https://www.inmuebles24.com/casas-en-venta-en-"#CASAS
url_CasaCond = "https://www.inmuebles24.com/casa-en-condominio-en-venta-en-"#CASAS EN CONDOMINIO
url_CasaSuelo = "https://www.inmuebles24.com/casa-uso-de-suelo-en-venta-en-"#CASAS CON USO DE SUELO
url_DepaComp = "https://www.inmuebles24.com/departamento-compartido-en-venta-en-"#DEPA "COMPARTIDO"
url_Duplex = "https://www.inmuebles24.com/duplex-en-venta-en-"#DUPLEX

# %%
Busqueda = url_Casa
print(Busqueda)
# Out:
# https://www.inmuebles24.com/casas-en-venta-en-

# %%
Tipo = "Departamento"

# %%
#Cargar CSVs de Cada Estado Descargado

try:
    AGSCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[0]}.csv"
    AGS_df = pd.read_csv(AGSCPs)
except:
    print(f"No {Estados[0]}")

try:
    BCNCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[1]}.csv"
    BCN_df = pd.read_csv(BCNCPs)
except:
    print(f"No {Estados[1]}")
    
try:
    BCSCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[2]}.csv"
    BCS_df = pd.read_csv(BCSCPs)

except:
    print(f"No {Estados[2]}")

try:
    CAMCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[3]}.csv"
    CAM_df = pd.read_csv(CAMCPs)
except:
    print(f"No {Estados[3]}")
    
try:
    CDMXCPsA = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[4]}.csv"
    CDMX_dfA = pd.read_csv(CDMXCPsA)
except:
    print(f"No {Estados[4]}")
    
#CDMXCPsB = "URLs x Estado/PropiedadesInmueblesdistrito-federalB.csv"
#CDMXCPsC = "URLs x Estado/PropiedadesInmueblesdistrito-federalC.csv"
#CDMXCPsD = "URLs x Estado/PropiedadesInmueblesdistrito-federalD.csv"
#CDMXCPsE = "URLs x Estado/PropiedadesInmueblesdistrito-federalE.csv"
#CDMXCPsF = "URLs x Estado/PropiedadesInmueblesdistrito-federalF.csv"
#CDMXCPsG = "URLs x Estado/PropiedadesInmueblesdistrito-federalG.csv"
#CDMXCPsH = "URLs x Estado/PropiedadesInmueblesdistrito-federalH.csv"
#CDMXCPsI = "URLs x Estado/PropiedadesInmueblesdistrito-federalI.csv"
#CDMXCPsJ = "URLs x Estado/PropiedadesInmueblesdistrito-federalJ.csv"
#CDMXCPsK = "URLs x Estado/PropiedadesInmueblesdistrito-federalK.csv"
#CDMXCPsL = "URLs x Estado/PropiedadesInmueblesdistrito-federalL.csv"
#CDMXCPsM = "URLs x Estado/PropiedadesInmueblesdistrito-federalM.csv"
#CDMXCPsN = "URLs x Estado/PropiedadesInmueblesdistrito-federalN.csv"
#CDMXCPsO = "URLs x Estado/PropiedadesInmueblesdistrito-federalO.csv"
#CDMXCPsP = "URLs x Estado/PropiedadesInmueblesdistrito-federalP.csv"
#CDMX_dfB = pd.read_csv(CDMXCPsB)
#CDMX_dfC = pd.read_csv(CDMXCPsC)
#CDMX_dfD = pd.read_csv(CDMXCPsD)
#CDMX_dfE = pd.read_csv(CDMXCPsE)
#CDMX_dfF = pd.read_csv(CDMXCPsF)
#CDMX_dfG = pd.read_csv(CDMXCPsG)
#CDMX_dfH = pd.read_csv(CDMXCPsH)
#CDMX_dfI = pd.read_csv(CDMXCPsI)
#CDMX_dfJ = pd.read_csv(CDMXCPsJ)
#CDMX_dfK = pd.read_csv(CDMXCPsK)
#CDMX_dfL = pd.read_csv(CDMXCPsL)
#CDMX_dfM = pd.read_csv(CDMXCPsM)
#CDMX_dfN = pd.read_csv(CDMXCPsN)
#CDMX_dfO = pd.read_csv(CDMXCPsO)
#CDMX_dfP = pd.read_csv(CDMXCPsP)

try:
    CHPCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[5]}.csv"
    CHP_df = pd.read_csv(CHPCPs)
except:
    print(f"No {Estados[5]}")
    
try:    
    CHHCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[6]}.csv"
    CHH_df = pd.read_csv(CHHCPs)
except:
    print(f"No {Estados[6]}")
    
try:    
    COACPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[7]}.csv"
    COA_df = pd.read_csv(COACPs)
except:
    print(f"No {Estados[7]}")
    
try:    
    COLCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[8]}.csv"
    COL_df = pd.read_csv(COLCPs)
except:
    print(f"No {Estados[8]}")
    
try:    
    DURCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[9]}.csv"
    DUR_df = pd.read_csv(DURCPs)
except:
    print(f"No {Estados[9]}")
    
try:    
    EDOMEXCPsA = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[10]}.csv"
    EDOMEX_dfA = pd.read_csv(EDOMEXCPsA)
except:
    print(f"No {Estados[10]}")
    
    
#EDOMEXCPsB = "URLs x Estado/PropiedadesInmuebles Estadosedo.-de-mexicoB.csv"
#EDOMEXCPsC = "URLs x Estado/PropiedadesInmuebles Estadosedo.-de-mexicoC.csv"
#EDOMEXCPsD = "URLs x Estado/PropiedadesInmuebles Estadosedo.-de-mexicoD.csv"
#EDOMEX_dfB = pd.read_csv(EDOMEXCPsB)
#EDOMEX_dfC = pd.read_csv(EDOMEXCPsC)
#EDOMEX_dfD = pd.read_csv(EDOMEXCPsD)

try:
    GUACPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[11]}.csv"
    GUA_df = pd.read_csv(GUACPs)
except:
    print(f"No {Estados[11]}")
    
try:    
    GROCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[12]}.csv"
    GRO_df = pd.read_csv(GROCPs)
except:
    print(f"No {Estados[12]}")
    
try:    
    HIDCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[13]}.csv"
    HID_df = pd.read_csv(HIDCPs)
except:
    print(f"No {Estados[13]}")
    
try:    
    JALCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[14]}.csv"
    JAL_df = pd.read_csv(JALCPs)
except:
    print(f"No {Estados[14]}")
    
try:    
    MICCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[15]}.csv"
    MIC_df = pd.read_csv(MICCPs)
except:
    print(f"No {Estados[15]}")
    
try:    
    MORCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[16]}.csv"
    MOR_df = pd.read_csv(MORCPs)
except:
    print(f"No {Estados[16]}")
    
try:    
    NAYCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[17]}.csv"
    NAY_df = pd.read_csv(NAYCPs)
except:
    print(f"No {Estados[17]}")
    
try:    
    NLECPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[18]}.csv"
    NLE_df = pd.read_csv(NLECPs)
except:
    print(f"No {Estados[18]}")
    
try:    
    OAXCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[19]}.csv"
    OAX_df = pd.read_csv(OAXCPs)
except:
    print(f"No {Estados[19]}")
    
try:    
    PUECPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[20]}.csv"
    PUE_df = pd.read_csv(PUECPs)
except:
    print(f"No {Estados[20]}")
    
try:    
    QROCPsA = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[21]}.csv"
    QRO_dfA = pd.read_csv(QROCPsA)
except:
    print(f"No {Estados[21]}")
    
    
#QROCPsB = "URLs x Estado/PropiedadesInmuebles Estadosqueretaro-provinciaB.csv"
#QROCPsC = "URLs x Estado/PropiedadesInmuebles Estadosqueretaro-provinciaC.csv"
#QROCPsD = "URLs x Estado/PropiedadesInmuebles Estadosqueretaro-provinciaD.csv"
#QRO_dfB = pd.read_csv(QROCPsB)
#QRO_dfC = pd.read_csv(QROCPsC)
#QRO_dfD = pd.read_csv(QROCPsD)

try:
    ROOCPsA = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[22]}.csv"
    ROO_dfA = pd.read_csv(ROOCPsA)
except:
    print(f"No {Estados[22]}")
    
    
#ROOCPsB = "URLs x Estado/PropiedadesInmuebles Estadosquintana-roo-provinciaB.csv"
#ROOCPsC = "URLs x Estado/PropiedadesInmuebles Estadosquintana-roo-provinciaC.csv"
#ROOCPsD = "URLs x Estado/PropiedadesInmuebles Estadosquintana-roo-provinciaD.csv"
#ROO_dfB = pd.read_csv(ROOCPsB)
#ROO_dfC = pd.read_csv(ROOCPsC)
#ROO_dfD = pd.read_csv(ROOCPsD)


try:
    SLPCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[23]}.csv"
    SLP_df = pd.read_csv(SLPCPs)
except:
    print(f"No {Estados[23]}")
    
try:
    SINCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[24]}.csv"
    SIN_df = pd.read_csv(SINCPs)
except:
    print(f"No {Estados[24]}")
    
try:    
    SONCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[25]}.csv"
    SON_df = pd.read_csv(SONCPs)
except:
    print(f"No {Estados[25]}")
    
try:    
    TABCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[26]}.csv"
    TAB_df = pd.read_csv(TABCPs)
except:
    print(f"No {Estados[26]}")
    
try:    
    TAMCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[27]}.csv"
    TAM_df = pd.read_csv(TAMCPs)
except:
    print(f"No {Estados[27]}")
    
try:    
    TLACPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[28]}.csv"
    TLA_df = pd.read_csv(TLACPs)
except:
    print(f"No {Estados[28]}")
    
try:    
    VERCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[29]}.csv"
    VER_df = pd.read_csv(VERCPs)
except:
    print(f"No {Estados[29]}")
    
try:    
    YUCCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[30]}.csv"
    YUC_df = pd.read_csv(YUCCPs)
except:
    print(f"No {Estados[30]}")
    
try:    
    ZACCPs = f"{Tipo}/{Tipo} URLs/PropiedadesInmuebles Estados{Estados[31]}.csv"
    ZAC_df = pd.read_csv(ZACCPs)
except:
    print(f"No {Estados[31]}")




#CSVList = [
#    AGS_df,
#    BCN_df,
#    BCS_df,
#    CAM_df,
#    CDMX_dfA,
#    CHP_df,
#    CHH_df,
#    COA_df,
#    COL_df,
#    DUR_df,
#    EDOMEX_dfA,
#    GUA_df,
#    GRO_df,
#    HID_df,
#    JAL_df,
#    MIC_df,
#    MOR_df,
#    NAY_df,
#    NLE_df,
#    OAX_df,
#    PUE_df,
#    QRO_dfA,
#    ROO_dfA,
#    SLP_df,
#    SIN_df,
#   SON_df,
#    TAB_df,
#    TAM_df,
#    TLA_df,
#    VER_df,
#    YUC_df,
#    ZAC_df,
#]
# Out:
# No campeche-provincia
# No tlaxcala-provincia
# No zacatecas-provincia

# %%
Estados1
# Out:
# ['puebla-provincia', 'queretaro-provincia', 'quintana-roo-provincia']

# %%
CSVList = [
    AGS_df,
    BCN_df,
    BCS_df,
    CAM_df,
    CDMX_dfA,
    CHP_df,
    CHH_df,
    COA_df,
    COL_df,
    DUR_df,
    EDOMEX_dfA,
    GUA_df,
    GRO_df,
    HID_df,
    JAL_df,
    MIC_df,
    MOR_df,
    NAY_df,
    NLE_df,
    OAX_df,
    PUE_df,
    QRO_dfA,
    ROO_dfA,
    SLP_df,
    SIN_df,
    SON_df,
    TAB_df,
    TAM_df,
    TLA_df,
    VER_df,
    YUC_df,
    ZAC_df,
]

# %%
Estados1
# Out:
# ['puebla-provincia', 'queretaro-provincia', 'quintana-roo-provincia']

# %%
#"aguascalientes-provincia" 0 - "baja-california-norte" 1 -"baja-california-sur" 2 - "campeche-provincia" 3
#"distrito-federal" 4 - "chiapas" 5 - "chihuahua-provincia" 6 - "coahuila" 7 - "colima-provincia" 8- 
#"durango-provincia" 9 - "edo.-de-mexico" 10 - "guanajuato-provincia" 11 - "guerrero-provincia" 12 -
#"hidalgo-provincia" 13 - "jalisco" 14 - "michoacan" 15 - "morelos-provincia" 16 - "nayarit" 17 -
#"nuevo-leon" 18 - "oaxaca" 19 - "puebla-provincia" 20 - "queretaro-provincia" 21 - "quintana-roo-provincia" 22 -
#"san-luis-potosi-provincia" 23 - "sinaloa-provincia" 24 - "sonora" 25 - "tabasco-provincia" 26 - 
#"tamaulipas" 27 - "tlaxcala-provincia" 28 - "veracruz-provincia" 29 - "yucatan" 30 - "zacatecas-provincia" 31.
b = 20
CSVList = [PUE_df,
    QRO_dfA,
    ROO_dfA]

# %%
A = CSVList[0]
product = A['0'].values.tolist()
#print(len(product))
product
# Out:
# ['/propiedades/desarrollo-camelinas-atlixco-59166383.html',
#  '/propiedades/departamentos-en-venta-en-zavaleta-torre-kupress-58407592.html',
#  '/propiedades/departamento-pentgarden-en-venta-lucerna-living-58287257.html',
#  '/propiedades/torres-uma-58781423.html',
#  '/propiedades/espectacular-desarrollo-en-puebla-58127986.html',
#  '/propiedades/hermoso-departamento-en-preventa-la-loma-grand-view-58075149.html',
#  '/propiedades/departamento-en-venta-la-vista-country-club-52386150.html',
#  '/propiedades/loft-industrial-meses-sin-interes-zerezotla-58934334.html',
#  '/propiedades/departamento-en-venta.-amueblado-58830224.html',
#  '/propiedades/departamento-en-lomas-de-angelopolis-park-view-en-59012713.html',
#  '/propiedades/departamento-en-venta-parque-del-arte-artema-59107241.html',
#  '/propiedades/departamentos-entrega-inmediata-torre-baori-en-la-58471020.html',
#  '/propiedades/ultimo-departamento-207-m-sup2--tipo-ph-con-3-recs-y-56961779.html',
#  '/propiedades/residencial-el-puente-mexico-58775420.html',
#  '/propiedades/vive-a-5-min-de-sonata.-excelentes-amenidades-56875312.html',
#  '/propiedades/departamento-en-venta-en-plazuela-del-fresno-la-58583592.html',
#  '/propiedades/-artema-torre-del-parque-58774941.html',
#  '/propiedades/departamentos-en-venta-en-puebla-a-25-minutos-de-san-56301283.html',
#  '/propiedades/departamento-en-venta-cholula-estilo-vintage-con-59053584.html',
#  '/propiedades/departamento-fraccionamiento-adamant-56587437.html',
#  '/propiedades/departamento-fraccionamiento-lomas-de-angelopolis-57567121.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-58725951.html',
#  '/propiedades/departamento-fraccionamiento-la-vista-contry-club-57849138.html',
#  '/propiedades/centro-zavaleta-58774942.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-58718839.html',
#  '/propiedades/-preventa!-departamentos-inteligentes-en-cholula-58297836.html',
#  '/propiedades/loft-preventa-cholula-12-meses-sin-intereses-58959003.html',
#  '/propiedades/departamentos-de-entrega-inmediata-en-punta-cascatta-58874852.html',
#  '/propiedades/torre-kupress-59047388.html',
#  '/propiedades/departamento-fraccionamiento-lomas-de-angelopolis-56495561.html',
#  '/propiedades/departamento-industrial-a-una-cuadra-de-plaza-san-59057180.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-53443658.html',
#  '/propiedades/la-vista-58638237.html',
#  '/propiedades/departamento-fraccionamiento-lomas-de-angelopolis-56395804.html',
#  '/propiedades/departamento-en-venta-en-conjunto-habitacional-floral-59087400.html',
#  '/propiedades/departamento-en-venta-en-atzala-58919355.html',
#  '/propiedades/departamentos-en-venta-en-col-la-paz-el-cerro-58583644.html',
#  '/propiedades/lomas-de-angelopolis-iii-58256150.html',
#  '/propiedades/departamento-en-la-vista-country-club-puebla-59052736.html',
#  '/propiedades/departamentos-en-venta-en-amani-resort-living-puebla-59168519.html',
#  '/propiedades/hermosa-casa-en-san-andres-cholula-58393210.html',
#  '/propiedades/hermoso-departamento-en-venta-en-high-towers-elite-58254927.html',
#  '/propiedades/-arbolada-belisario-dominguez-58774946.html',
#  '/propiedades/amplio-departamento-nuevo-3-recamaras-zona-atlixcayotl-59032480.html',
#  '/propiedades/departamento-loft-en-venta-en-ocoyucan-lomas-de-58704966.html',
#  '/propiedades/departamento-en-venta-torre-anzures-58631595.html',
#  '/propiedades/plazuela-del-fresno-58774939.html',
#  '/propiedades/departamento-fraccionamiento-la-vista-contry-club-56747673.html',
#  '/propiedades/departamento-fraccionamiento-lomas-de-angelopolis-56586440.html',
#  '/propiedades/departamento-en-venta-torres-nducha-58082454.html',
#  '/propiedades/oportunidad-departamento-parkview-sonata-puebla-3-rec-58574228.html',
#  '/propiedades/departamento-en-venta-en-cholula-59057822.html',
#  '/propiedades/departamento-venta-zona-de-angelopolis-san-andres-58103554.html',
#  '/propiedades/departamentos-en-san-pedro-cholula-inteligente-59152271.html',
#  '/propiedades/ultimos-departamentos-entrega-inmediata-59002946.html',
#  '/propiedades/amplio-departamento-nuevo-2-recamaras-zona-atlixcayotl-59032491.html',
#  '/propiedades/departamentos-en-venta-en-bugambilias-vista-laguna-58407587.html',
#  '/propiedades/departamento-en-cholula-2-recamaras-inteligente-59171995.html',
#  '/propiedades/departamento-loft-en-venta-en-lomas-de-angelopolis-57427672.html',
#  '/propiedades/venta-departamento-residencial-atras-de-cruz-del-sur-58574229.html',
#  '/propiedades/departamento-en-venta-en-angelopolis-puebla-pue.-58895680.html',
#  '/propiedades/departamento-en-venta-en-residencial-palmas-puebla.-57841191.html',
#  '/propiedades/selenite-58781998.html',
#  '/propiedades/departamentos-en-pre-venta-en-la-carcana-57485486.html',
#  '/propiedades/departamentos-en-venta-con-alberca-cerca-de-cholula-57499269.html',
#  '/propiedades/departamento-con-credito-infonavit-58558589.html',
#  '/propiedades/departamentos-en-cholula-con-alberca-y-excelentes-58308974.html',
#  '/propiedades/carcana-58216678.html',
#  '/propiedades/loft-industrial-zerezotla-lujo-12-meses-sin-intereses-58934589.html',
#  '/propiedades/departamento-reserva-territorial-atlixcayotl-56435144.html',
#  '/propiedades/-el-cerro-58774937.html',
#  '/propiedades/departamentos-en-venta-citium-lomas-de-angelopolis-52531140.html',
#  '/propiedades/oak-58-high-living-58926282.html',
#  '/propiedades/moderno-y-lujoso-departamento-en-preventa-en-la-loma-58075175.html',
#  '/propiedades/departamento-en-venta-excelente-ubicacion-con-acceso-59191328.html',
#  '/propiedades/departamento-fraccionamiento-lomas-de-angelopolis-56508434.html',
#  '/propiedades/preventa-departamentos-lomas-de-angelopolis-56390555.html',
#  '/propiedades/depto-en-venta-en-torre-v-col.-villa-encantada-58670522.html',
#  '/propiedades/departamentos-economicos-en-venta-cerca-de-la-buap-56694195.html',
#  '/propiedades/departamento-en-venta-en-nidum-mayorazgo-58230265.html',
#  '/propiedades/departamentos-en-preventa-toscana-lomas-de-58134371.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-58725600.html',
#  '/propiedades/la-carcana-58216776.html',
#  '/propiedades/departamento-304-en-venta-en-av-14-sur-torre-anzures-59107352.html',
#  '/propiedades/departamento-en-venta-zona-plaza-dorada-3-recamaras-1-58657380.html',
#  '/propiedades/venta-de-departamentos-cerca-de-cholula-57246666.html',
#  '/propiedades/torre-anzures-58774940.html',
#  '/propiedades/centro-zavaleta-58314571.html',
#  '/propiedades/departamento-fraccionamiento-la-vista-contry-club-58435244.html',
#  '/propiedades/venta-de-departamentos-de-3-recamaras-zona-sur-de-56955125.html',
#  '/propiedades/venta-departamento-pb-cuautlancingo-residencial-58574237.html',
#  '/propiedades/departamento-en-venta-en-angelopolis-con-elevador-y-55157268.html',
#  '/propiedades/precioso-departamento-en-venta-en-parque-victoria-57517447.html',
#  '/propiedades/departamentos-en-venta-en-blvd.-forjadores-el-puente-58559224.html',
#  '/propiedades/oportunidad-departamento-torre-arts-$3-900-000-58058613.html',
#  '/propiedades/departamentos-en-venta-en-torres-zavaleta-58407595.html',
#  '/propiedades/loft-industrial-en-zerezotla-12-meses-sin-interes-58934483.html',
#  '/propiedades/departamento-en-venta-1401-en-torre-uma-angelopolis-58583123.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-58567379.html',
#  '/propiedades/departamento-en-venta-en-puebla-en-col-la-paz-57157897.html',
#  '/propiedades/venta-de-departamento-torres-mossa-54246397.html',
#  '/propiedades/departamento-lujo-en-cholula-roofgarden-58949807.html',
#  '/propiedades/departamentos-amplios-3-recamaras-2-autos-a-5-min-58958889.html',
#  '/propiedades/venta-de-departamento-de-lujo-en-lomas-de-angelopolis-59034479.html',
#  '/propiedades/la-radial-58216674.html',
#  '/propiedades/venta-renta-depto.-en-torre-cipres-atras-de-centro-59126156.html',
#  '/propiedades/departamento-en-venta-o-renta-angelopolis-parque-del-59082930.html',
#  '/propiedades/depas-en-venta-y-preventa-valiara-high-living-lomas-58951492.html',
#  '/propiedades/marfil-24-departamentos-en-el-nuevo-zavaleta-52826901.html',
#  '/propiedades/departamentos-en-venta-en-torre-artema-frente-al-55211987.html',
#  '/propiedades/preventa-departamento-a-2-min-de-la-udlap-perfecto-57046833.html',
#  '/propiedades/departamentos-residencial-sta.-isabel-la-carcana-58948932.html',
#  '/propiedades/ultimo-departamento-3-habitaciones-en-udlap-57174451.html',
#  '/propiedades/venta-departamento-nuevo-zona-zavaleta-y-forjadores-56988083.html',
#  '/propiedades/departamento-ex-hacienda-la-carcana-59084158.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-59034481.html',
#  '/propiedades/loft-vista-volcanes-cholula-24-meses-sin-intereses-58953106.html',
#  '/propiedades/loft-industrial-en-san-pedro-cholula-3-recamaras-unico-59023482.html',
#  '/propiedades/departamento-en-venta-en-puebla-58758194.html',
#  '/propiedades/amplio-departamento-en-venta-colonia-vicente-58003248.html',
#  '/propiedades/ultimo!-pre-venta-departamento-san-jose-vista-hermosa-55815269.html',
#  '/propiedades/parque-del-arte-58324798.html',
#  '/propiedades/hermoso-departamento-en-venta-en-el-centro-historico-55450912.html',
#  '/propiedades/departamento-loma-encantada-57254918.html',
#  '/propiedades/departamento-en-venta-en-las-animas-58371351.html',
#  '/propiedades/departamento-en-venta-maestranza-lomas-de-angelopolis-58075163.html',
#  '/propiedades/firenze-tower-torre-1-lomas-de-angelopolis-2-53603283.html',
#  '/propiedades/lujo-calidad-y-espacio-cerca-de-sonata:-penthouse-55929820.html',
#  '/propiedades/high-towers.-amueblado-en-lomas-de-angelopolis.-58796459.html',
#  '/propiedades/departamento-de-lujo-con-amenidades-cholula-5-min-59022578.html',
#  '/propiedades/departamento-en-venta-en-torre-abric-57168464.html',
#  '/propiedades/departamento-en-venta-en-san-pedro-cholula-59035258.html',
#  '/propiedades/departamento-en-venta-o-renta-lomas-de-angelopolis-san-59082871.html',
#  '/propiedades/penthouse-de-dos-recamaras-en-venta-junto-a-sonata-en-58075225.html',
#  '/propiedades/departamentos-en-venta-junto-a-la-ibero-itesm-a-3-min-58217306.html',
#  '/propiedades/departamentos-cerca-c.-u-y-10-minutos-de-angelopolis-57850758.html',
#  '/propiedades/depa-en-venta-high-towers-1-rec-a-tratar!-59151372.html',
#  '/propiedades/departamento-en-venta-en-torre-punta-cascatta-lomas-de-58254935.html',
#  '/propiedades/departamento-3-recamaras-1-niv-a-2-min-zona-finsa-vw-58577646.html',
#  '/propiedades/anzures-58325571.html',
#  '/propiedades/abric-lifestyle-apartments-zona-angelopolis-52826386.html',
#  '/propiedades/venta-de-departamento-de-lujo-en-lomas-de-angelopolis-59034480.html',
#  '/propiedades/departamento-en-venta-planta-baja-zona-zavaleta-entre-57017673.html',
#  '/propiedades/oportunidad-de-inversion:-departamentos-nuevos-55980295.html',
#  '/propiedades/departamento-en-venta-en-san-pedro-cholula-58950362.html',
#  '/propiedades/departamento-de-lujo-en-venta-en-lomas-de-angelopolis-59034482.html',
#  '/propiedades/oportunidad-venta-hermosos-departamentos-la-radial-uvm-55966639.html',
#  '/propiedades/departamento-en-venta-en-zona-angelopolis-puebla-57568002.html',
#  '/propiedades/departamentos-a-estrenar.-zona-udla-y-la-carcana.-2-y-58956941.html',
#  '/propiedades/nuevo-departamento-en-venta-en-high-towers-elite-lomas-58254928.html',
#  '/propiedades/departamento-en-venta-en-atlixcayotl-59084162.html',
#  '/propiedades/departamento-a-la-venta-en-san-pedro-cholula-puebla-59035264.html',
#  '/propiedades/tu-departamento-en-huejotzingo-puebla-58618007.html',
#  '/propiedades/penth-garden-en-venta-edificio-punta-cascatta-lomas-de-58254938.html',
#  '/propiedades/departamento-en-renta-angelopolis-59084156.html',
#  '/propiedades/loft-industrial-de-lujo-cholula-cine-terraza-vista-a-58963031.html',
#  '/propiedades/departamento-en-venta-en-san-pedro-cholula.-gran-58934206.html',
#  '/propiedades/departamento-en-venta-en-el-centro-de-puebla-58985388.html',
#  '/propiedades/depto-torre-arts-57170555.html',
#  '/propiedades/departamento-en-atlaco-la-carcana-3-recamaras-59053432.html',
#  '/propiedades/departamento-en-venta-o-renta-en-parque-del-arte-59083096.html',
#  '/propiedades/departamento-en-venta-en-zona-zavaleta-puebla-57710272.html',
#  '/propiedades/departamentos-en-choula-alberca-area-verde-seguridad-58952662.html',
#  '/propiedades/departamento-en-venta-zona-zavaleta-recta-a-cholula-56371992.html',
#  '/propiedades/oportunidad-departamento-de-236-m-sup2--cerca-de-58664651.html',
#  '/propiedades/departamento-nuevo-en-puebla-cerca-de-la-universidad-58023574.html',
#  '/propiedades/atlixcayotl-58125944.html',
#  '/propiedades/excelente-oportunidad.-departamento-en-venta-58364529.html',
#  '/propiedades/departamentos-en-venta-en-zona-san-manuel-puebla-54844991.html',
#  '/propiedades/departamento-granjas-san-isidro-57047591.html',
#  '/propiedades/angelopolis-oportunidad-de-$2-650-000-a-$2-100-000-58663400.html',
#  '/propiedades/departamento-nuevo-en-venta-en-el-centro-de-puebla-58287638.html',
#  '/propiedades/departamento-en-venta-en-torre-ziete-puebla-58751626.html',
#  '/propiedades/increible-departamento-en-venta-en-san-pedro-cholula-58693826.html',
#  '/propiedades/departamento-en-venta-3-recamaras-de-lujo-con-vista-59172941.html',
#  '/propiedades/departamento-en-venta-en-la-vista-country-club-52524358.html',
#  '/propiedades/departamentos-nuevos-en-frac-zona-angelopolis-54347042.html',
#  '/propiedades/preventa-2020-penthgarden-en-la-loma-grand-view-lomas-58292705.html',
#  '/propiedades/loft-amueblado-atlixcayotl-y-las-torres-59126002.html',
#  '/propiedades/departamento-de-lujo-con-terrazas-cerca-de-calz.-59093770.html',
#  '/propiedades/departamento-en-venta-cholula-a-unos-pasos-de-la-58254957.html',
#  '/propiedades/departamentos-en-venta-58883455.html',
#  '/propiedades/ibero-58681841.html',
#  '/propiedades/departamento-amueblado-venta-edificio-nducha-52105500.html',
#  '/propiedades/departamento-3-recamaras-2niv-a-2-min-zona-finsa-vw-58577647.html',
#  '/propiedades/depas-en-venta-en-ex-hacienda-morillotla-56810268.html',
#  '/propiedades/departamentos-nuevos-en-lomas-del-marmol-58919483.html',
#  '/propiedades/depto-amueblado-junto-la-estrella-56953945.html',
#  '/propiedades/departamento-en-venta-o-renta-en-parque-victoria-lomas-59083132.html',
#  '/propiedades/departamento-en-venta-en-puebla-58679848.html',
#  '/propiedades/excelente-opcion-para-inversionistas.-departamento-a-3-58319604.html',
#  '/propiedades/departamento-en-venta-en-san-andres-cholula-cerca-de-59093822.html',
#  '/propiedades/departamento-tipo-cedro-en-venta-nidum-en-puebla-58254931.html',
#  '/propiedades/preventa-departamentos-lucerna-high-living-el-barreal-58951486.html',
#  '/propiedades/loft-desde-en-cholula-12-meses-sin-intereses-58959147.html',
#  '/propiedades/loft-2-recamaras-cerca-udla-diseno-industrial-58962494.html',
#  '/propiedades/departmento-en-venta-en-high-towers-cerca-de-sonata-58187877.html',
#  '/propiedades/departamento-en-venta-torre-tempo-vitale-residencial-58254959.html',
#  '/propiedades/departamento-en-venta-en-la-paz-59025037.html',
#  '/propiedades/departamento-villas-del-vergel-58225516.html',
#  '/propiedades/departamento-3-recamaras-a-2-min-zona-finsa-vw-58574238.html',
#  '/propiedades/departamento-en-venta-en-torres-cipres-a-una-calle-de-57706325.html',
#  '/propiedades/departamento-en-venta-zona-angelopolis-precio-de-59171856.html',
#  '/propiedades/depto-oferta-11-sur-58567297.html',
#  '/propiedades/departamentos-nuevos-en-pre-venta-puebla-58956234.html',
#  '/propiedades/venta-de-departamento-amueblado-entre-zavaleta-y-59060687.html',
#  '/propiedades/departamento-tipo-nogal-en-venta-nidum-puebla-58254930.html',
#  '/propiedades/venta-parque-veneto-3-recamaras.-lomas-angelopolis-58796455.html',
#  '/propiedades/departamento-en-zona-aeropuerto-puebla-59003857.html',
#  '/propiedades/departamento-en-venta-en-atlixcayotl-arts-luxury-57838398.html',
#  '/propiedades/renta-venta-de-departamento-en-torre-palmas-zona-59083308.html',
#  '/propiedades/venta-departamento-residencial-cuautlancingo-publa-59032965.html',
#  '/propiedades/departamento-de-lujo-en-san-andres-cholula-a-tres-57776230.html',
#  '/propiedades/departamentos-nuevos-excelente-ubicacion-59094708.html',
#  '/propiedades/departamento-en-renta-en-torres-de-mayorazgo-puebla-57706359.html',
#  '/propiedades/departamentos-muy-amplios-3-recamaras-en-fracc-zona-56627974.html',
#  '/propiedades/departamentos-en-venta-la-carcana-altazia-59084144.html',
#  '/propiedades/departamento-en-exhacienda-santa-teresa-59073814.html',
#  '/propiedades/precioso-depa-en-venta.-frente-a-parque-del-arte.-58796461.html',
#  '/propiedades/departamentos-en-venta-en-zavaleta-centro-zavaleta-58583376.html',
#  '/propiedades/venta-de-hermoso-departamento-en-lomas-de-angelopolis-58287782.html',
#  '/propiedades/radial-58216882.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-59034478.html',
#  '/propiedades/en-venta-departamento-cholula-puebla.-58726385.html',
#  '/propiedades/departamento-3-recamaras-en-morillotla-fraccionamiento-58945237.html',
#  '/propiedades/pre-venta-de-increibles-departamentos-a-1-minuto-del-56754555.html',
#  '/propiedades/habitaciones-con-bano-y-servicios-plaza-crystal-58425541.html',
#  '/propiedades/departamentos-en-residencial-zona-udlap-y-uvm-2-y-3-57070414.html',
#  '/propiedades/punto-horizonte.-lomas-angelopolis-17-amenidades!-58796457.html',
#  '/propiedades/departamentos-en-preventa-selenite-en-av-atlixcayotl-59107264.html',
#  '/propiedades/se-vende-departamento-en-las-torres-y-av-atlixcayotl-58364538.html',
#  '/propiedades/departamento-tipo-loft-industrial-en-cholula-vista-58935844.html',
#  '/propiedades/-oportunidad-departamento-en-vista-del-arte-excelente-58911657.html',
#  '/propiedades/loft-industrial-en-cholula-vista-alos-volcanes-58963097.html',
#  '/propiedades/departamento-en-firenze-toscana-lomas-de-angelopolis-57235918.html',
#  '/propiedades/plaza-san-diego-58079714.html',
#  '/propiedades/departamento-en-puebla-58312018.html',
#  '/propiedades/departamento-en-venta-en-torre-adamant-1-puebla-59060801.html',
#  '/propiedades/venta-de-hermoso-departamento-amueblado-en-la-paz-58956518.html',
#  '/propiedades/departamento-en-venta-en-torre-actipan-en-san-andres-57651083.html',
#  '/propiedades/departamento-en-venta-de-lujo-en-lomas-de-angelopolis-59169917.html',
#  '/propiedades/departamento-en-venta-torre-5-montesierra-57817157.html',
#  '/propiedades/departamento-en-venta-a-una-calle-de-la-prepa-benito-56196079.html',
#  '/propiedades/departamento-en-venta-en-high-towers-elite-58429623.html',
#  '/propiedades/departamento-loma-encantada-57778696.html',
#  '/propiedades/venta-de-hermoso-departamento-zona-atlixcayotl-puebla-59038292.html',
#  '/propiedades/departamentos-en-zona-galeria-serdan-53584972.html',
#  '/propiedades/departamento-en-cholula-con-amenidades-de-lujo-59173062.html',
#  '/propiedades/departamento-nuevo-en-primer-piso-en-venta-en-torre-57045991.html',
#  '/propiedades/lexum-departamentos-en-pre-venta-58841439.html',
#  '/propiedades/departamentos-nuevos-cerca-de-cu-59188436.html',
#  '/propiedades/departamento-nuevo-2-cuadras-de-blvd-forjadores-puebla-56173317.html',
#  '/propiedades/departamento-con-alberca-en-venta-en-firenze-lomas-de-57236058.html',
#  '/propiedades/departamento-en-col.-la-paz-58216889.html',
#  '/propiedades/depto-en-renta-high-towers-provincia-de-puebla-59084147.html',
#  '/propiedades/bellos-departamentos-en-venta-ubicado-en-zona-de-lomas-58706269.html',
#  '/propiedades/departamento-nuevo-5-piso-95-m-sup2--3-recamaras-55975240.html',
#  '/propiedades/vendo-departamento-en-zavaleta-54067049.html',
#  '/propiedades/departamento-puebla-de-zaragoza-58421213.html',
#  '/propiedades/departamento-en-pre-venta-de-2-recamaras-prados-55969655.html',
#  '/propiedades/venta-o-renta-departamento-en-torre-adamant-1-puebla-58736158.html',
#  '/propiedades/departamentos-de-entrega-inmediata-en-punta-cascatta-56275305.html',
#  '/propiedades/departamento-en-venta-recta-a-cholula-$1-57928640.html',
#  '/propiedades/departamento-en-venta-cholula-estilo-vintage-con-59054705.html',
#  '/propiedades/venta-de-departamento-de-lujo-en-puebla-59034475.html',
#  '/propiedades/torres-zavaleta.-depto-venta.-2-recamaras-con-bano-y-58833790.html',
#  '/propiedades/venta-de-departamento-en-la-radial-zapata-acabados-58958525.html',
#  '/propiedades/departamento-en-venta-atras-de-la-udla-puebla-58820753.html',
#  '/propiedades/departamento-de-lujo-en-venta-en-san-andres-cholula-59093611.html',
#  '/propiedades/preventa-departamento-torre-ziete-zavaleta-59084146.html',
#  '/propiedades/departamento-nuevo-de-2-recamaras-con-acabados-de-lujo-57262436.html',
#  '/propiedades/departamentos-en-venta-lomas-de-angelopolis-con-59173669.html',
#  '/propiedades/san-manuel-58649533.html',
#  '/propiedades/departamentos-en-venta-58657490.html',
#  '/propiedades/departamento-loma-encantada-57254882.html',
#  '/propiedades/hermosos-departamentos-en-venta-excelente-ubicacion-54803373.html',
#  '/propiedades/loft-1-recamara-vista-volcanes-24-meses-sin-intereses-58953045.html',
#  '/propiedades/venta-o-renta-de-departamento-tipo-loft-amueblado-en-55351732.html',
#  '/propiedades/departamento-en-venta-en-parque-lisboa-56210734.html',
#  '/propiedades/departamento-en-venta-lomas-de-angelopolis-precio-de-59185803.html',
#  '/propiedades/departamento-en-venta-zona-la-paz-con-vista-a-los-59055178.html',
#  '/propiedades/departamentos-nuevos-en-venta-en-valiara-en-lomas-de-58726834.html',
#  '/propiedades/departamento-en-venta-a-minutos-de-galerias-serdan-57706543.html',
#  '/propiedades/departamento-de-lujo-torre-abric-lomas-de-angelopolis-58574250.html',
#  '/propiedades/departamentos-en-venta-en-san-pedro-cholula.-58256476.html',
#  '/propiedades/departamentos-industrial-londinense-a-unas-calles-de-58962388.html',
#  '/propiedades/departamento-en-venta-en-la-zona-de-huexotitla-56809823.html',
#  '/propiedades/departamento-amueblado-en-high-towers-58782936.html',
#  '/propiedades/departamento-en-venta-san-andres-cholula-a-minutos-de-59093918.html',
#  '/propiedades/se-vende-hermoso-departamento-oportunidad-cholula-56073601.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-59034477.html',
#  '/propiedades/hermosos-y-amplios-departamentos-en-zona-exclusiva-de-58706286.html',
#  '/propiedades/departamento-en-venta-en-cube-barreal-muy-cerca-de-la-54317318.html',
#  '/propiedades/departamento-puebla-de-zaragoza-59084152.html',
#  '/propiedades/amplio-departamento-en-venta-punto-horizonte-58254940.html',
#  '/propiedades/departamento-en-venta-recta-a-cholula-58842919.html',
#  '/propiedades/ultimos!-5-departamentos-pre-venta-atlixcayotl-y-las-56404246.html',
#  '/propiedades/departamentos-en-venta-zona-mayorazgo-57490785.html',
#  '/propiedades/departamento-en-venta-en-priv.-25-poniente-arbolada-58583470.html',
#  '/propiedades/renta-o-venta.-acueducto-de-la-noria.-2-recamaras-58799453.html',
#  '/propiedades/san-manuel-58649533.html',
#  '/propiedades/departamento-en-venta-lomas-de-angelopolis-precio-de-59185803.html',
#  '/propiedades/parque-del-arte-58324798.html',
#  '/propiedades/departamento-en-venta-en-parque-lisboa-56210734.html',
#  '/propiedades/departamento-ex-hacienda-la-carcana-59084158.html',
#  '/propiedades/hermosos-y-amplios-departamentos-en-zona-exclusiva-de-58706286.html',
#  '/propiedades/departamentos-de-entrega-inmediata-en-punta-cascatta-56275305.html',
#  '/propiedades/lexum-departamentos-en-pre-venta-58841439.html',
#  '/propiedades/depto-en-renta-high-towers-provincia-de-puebla-59084147.html',
#  '/propiedades/vendo-departamento-en-zavaleta-54067049.html',
#  '/propiedades/departamento-en-venta-en-atlixcayotl-zona-de-55112732.html',
#  '/propiedades/departamento-nuevo-en-venta-zerezotla-san-pedro-58108629.html',
#  '/propiedades/departamento-en-renta-y-venta-en-tlaxcalancingo-ciudad-59082962.html',
#  '/propiedades/departamento-en-venta-en-atlixcayotl-55415287.html',
#  '/propiedades/departamento-en-preventa-en-lomas-de-angelopolis-58206070.html',
#  '/propiedades/departamento-venta-blue-towers-tlaxcalancingo-55574478.html',
#  '/propiedades/departamento-en-venta-renta-torre-altix-2-lomas-de-55875160.html',
#  '/propiedades/departamento-lomas-de-angelopolis-sonata-puebla-57027799.html',
#  '/propiedades/departamentos-en-venta-promocion-12-descuento-con-59115939.html',
#  '/propiedades/departamento-exclusivo-a-excelente-precio-en-el-mejor-58944744.html',
#  '/propiedades/venta-de-departamentos-en-cholula-puebla!-56986809.html',
#  '/propiedades/departamento-en-venta-en-momoxpan-san-andres-cholula-59083070.html',
#  '/propiedades/departamentos-en-venta-torre-el-cerro-en-la-paz-55637569.html',
#  '/propiedades/bonito-departamento-estilo-residencial-58098274.html',
#  '/propiedades/departamento-en-venta-58024805.html',
#  '/propiedades/venta-de-lofts-y-departamentos-lebo-39-la-paz-puebla-57555870.html',
#  '/propiedades/departamento-en-venta-53677604.html',
#  '/propiedades/departamento-en-desarrollo-nuevo-nidum-58232037.html',
#  '/propiedades/lofts-de-lujo-en-renta-dentro-de-san-pedro-cholula-58945811.html',
#  '/propiedades/departamento-en-venta-en-residencial-punta-alta-53171518.html',
#  '/propiedades/hermoso-departamento-en-lomas-de-angelopolis-59163017.html',
#  '/propiedades/lomas-de-angelopolis-puebla-departamento-proyecto-59075350.html',
#  '/propiedades/precioso-departamento-en-super-zona-de-puebla-57735874.html',
#  '/propiedades/departamento-en-venta-en-la-cima-residencial-58028284.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-58725683.html',
#  '/propiedades/departamentos-de-lujo-zona-zavaleta-puebla-56462862.html',
#  '/propiedades/departamento-en-preventa-en-lomas-de-angelopolis-58140480.html',
#  '/propiedades/venta-de-departamento-en-la-paz-puebla.-56313083.html',
#  '/propiedades/vendo-departamento-en-adamant-frente-a-la-vista-y-55189047.html',
#  '/propiedades/venta-de-edificio-duplex-ideal-para-inversionistas-en-58212132.html',
#  '/propiedades/depto-la-porta-renta-y-venta-56496066.html',
#  '/propiedades/lujoso-departamento-en-av-juarez-57235560.html',
#  '/propiedades/departamentos-en-venta-en-torres-arts-luxury-condos-56210708.html',
#  '/propiedades/departamento-en-venta-a-5-minutos-del-centro-historico-55516830.html',
#  '/propiedades/preventa-de-departamentos-en-la-carcana-entrega-en-57362611.html',
#  '/propiedades/penthouse-parque-victoria-lomas-de-angelopolis-59121020.html',
#  '/propiedades/loft-en-pre-venta-en-torre-valiara-en-parque-sinaloa-57594656.html',
#  '/propiedades/las-animas-58216875.html',
#  '/propiedades/la-paz-58314984.html',
#  '/propiedades/departamentos-en-venta-zona-centro-de-la-ciudad-58541308.html',
#  '/propiedades/excelente-departamento-en-puebla-57390906.html',
#  '/propiedades/departamento-en-venta-o-renta-en-high-towers-elite-58552992.html',
#  '/propiedades/eldepartamento-de-tus-suenos-en-puebla-58615046.html',
#  '/propiedades/oportunidad-departamentos-parque-veneto-a-unos-minutos-58574231.html',
#  '/propiedades/departamento-en-venta-park-view-e.-v-59088201.html',
#  '/propiedades/venta-de-departamento-en-torre-adamant-ii.-52820824.html',
#  '/propiedades/departamento-en-venta-nducha-angelopolis-sd-1612-57678391.html',
#  '/propiedades/venta-de-departamento-en-torre-atzala-condos-56896061.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-58554938.html',
#  '/propiedades/departamento-lexum-55569564.html',
#  '/propiedades/departamento-en-momoxpan-56590595.html',
#  '/propiedades/departamento-en-venta-cholula-57584807.html',
#  '/propiedades/venta-departamento-en-edificio-artea-puebla-58834466.html',
#  '/propiedades/lomas-de-angelopolis-ii-58216948.html',
#  '/propiedades/departamento-en-venta-zavaleta-vive-lo-natural-54449483.html',
#  '/propiedades/departamento-de-lujo-en-el-corazon-de-lomas-de-58227841.html',
#  '/propiedades/torre-adamant-ii-58521024.html',
#  '/propiedades/departamento-en-pre-venta-frente-a-parque-del-arte-57733166.html',
#  '/propiedades/departamentos-en-venta-calatea-54783862.html',
#  '/propiedades/casa-departamento-en-venta-en-san-matias.-56761563.html',
#  '/propiedades/tu-depa-en-huejotzingo-llamanos-56292704.html',
#  '/propiedades/departamento-en-venta-de-2-recamaras-en-lomas-de-57990913.html',
#  '/propiedades/lomas-de-angelopolis-l-58216667.html',
#  '/propiedades/departamento-en-venta-en-inspiralta-d-503-torre-a-58240273.html',
#  '/propiedades/departamento-en-venta-57344251.html',
#  '/propiedades/departamento-en-preventa-en-la-carcana-san-pedro-59082979.html',
#  '/propiedades/departamento-en-venta-en-la-juarez-la-paz-puebla-59082822.html',
#  '/propiedades/departamento-lomas-de-angelopolis-high-towers-elite-58714265.html',
#  '/propiedades/departamento-en-renta-o-venta-zona-lomas-de-59116042.html',
#  '/propiedades/toscana-lomas-de-angelopolis-59166042.html',
#  '/propiedades/departamento-en-venta-en-ciudad-judicial-san-andres-59082890.html',
#  '/propiedades/departamento-en-venta-en-centro-historico-58307773.html',
#  '/propiedades/departamentos-en-venta-en-blvd-las-torres-puebla.-57000432.html',
#  '/propiedades/departamento-en-pre-venta-parque-del-arte-sd-1753b-57721573.html',
#  '/propiedades/departamento-en-pre-venta-zavaleta-sd-1702-57681269.html',
#  '/propiedades/departamento-en-venta-en-calzada-zavaleta-55513660.html',
#  '/propiedades/-tu-nuevo-hogar-punto-horizonte-departamento-de-lujo-59040581.html',
#  '/propiedades/departamento-en-venta-en-parque-hidalgo-lomas-de-58657138.html',
#  '/propiedades/departamento-nuevo-en-high-towers-elite-el-mejor-58254923.html',
#  '/propiedades/espectacular-departamento-sonata-towers-lomas-de-56945030.html',
#  '/propiedades/torre-adamant-ii-58521036.html',
#  '/propiedades/departamento-en-venta-frente-a-plaza-dorada!-blvd.-5-58581316.html',
#  '/propiedades/departamento-en-pre-venta-en-torre-valiara-en-parque-57597905.html',
#  '/propiedades/departamento-atras-de-plaza-san-diego-amplias-areas-57047528.html',
#  '/propiedades/exclusivo-departamento-en-venta-en-punto-horizonte-58254939.html',
#  '/propiedades/departamento-en-venta-en-san-pedro-cholula-la-carcana-58243346.html',
#  '/propiedades/departamentos-en-venta-centro-historico-de-puebla-56839928.html',
#  '/propiedades/departamento-en-venta-torre-adamant-puebla-55980557.html',
#  '/propiedades/!estrena-departamentos-con-elevador-y-caseta-de-54739615.html',
#  '/propiedades/departamento-en-venta-a-unos-minutos-de-la-udlap-en-59083034.html',
#  '/propiedades/departamento-en-centro-puebla-gsi-724-de-56895613.html',
#  '/propiedades/departamento-en-venta-arboledas-de-zavaleta-58081847.html',
#  '/propiedades/departamento-en-venta-53234540.html',
#  '/propiedades/departamento-en-venta-en-santiago-momoxpan-san-pedro-57999973.html',
#  '/propiedades/departamento-en-venta-en-torre-enigma-san-martinito-58169480.html',
#  '/propiedades/departamento-en-venta-en-forjadores-cerca-de-55441488.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-58092719.html',
#  '/propiedades/estrena-departamento-en-puebla-vive-en-otro-nivel-56297141.html',
#  '/propiedades/venta-de-penthouse-de-227-m-sup2--en-torre-anzures-55779069.html',
#  '/propiedades/departamento-en-venta-amueblado-en-la-vista-country-59082820.html',
#  '/propiedades/se-vende-penthouse-58872642.html',
#  '/propiedades/departamento-en-venta-zona-nueva-cerca-de-udlap-y-vw-55227980.html',
#  '/propiedades/departamentos-en-preventa-la-paz-puebla-puebla.-55750960.html',
#  '/propiedades/el-barreal-59164667.html',
#  '/propiedades/departamento-en-venta-en-mazik-58333498.html',
#  '/propiedades/departamento-en-venta-en-zavaleta-y-forjadores-torre-58577670.html',
#  '/propiedades/departamentos-en-venta-en-blvd-atlixco-y-las-torres-57634234.html',
#  '/propiedades/hermosa-casa-en-venta-tipo-cedro-en-madeira-58251918.html',
#  '/propiedades/departamento-en-venta-punta-cascatta-lomas-de-57721538.html',
#  '/propiedades/venta-de-departamentos-economicos-en-huejotzingo-59101721.html',
#  '/propiedades/atlixcayotl-58216787.html',
#  '/propiedades/departamento-en-venta-angelopolis-59043068.html',
#  '/propiedades/camino-real-departamento-en-venta-59041505.html',
#  '/propiedades/departamento-en-venta-san-andres-cholula-58114196.html',
#  '/propiedades/departamento-en-venta-frente-a-parque-del-arte-puebla-55918309.html',
#  '/propiedades/inversionistas.-torre-de-departamentos-rodeado-de-56884781.html',
#  '/propiedades/venta-departamento-atras-de-zavaleta-58988255.html',
#  '/propiedades/departamento-en-venta-altix-lomas-de-angelopolis-sd-57678394.html',
#  '/propiedades/adamant-ii-58521044.html',
#  '/propiedades/departamento-en-venta-en-puebla-arbolada-el-56101506.html',
#  '/propiedades/departamento-en-venta-benito-juarez-puebla-puebla-58337456.html',
#  '/propiedades/departamento-con-alberca-en-venta-arts-luxury-condos-57846996.html',
#  '/propiedades/lofts-en-venta-camino-real-a-san-andres-cholula-57347206.html',
#  '/propiedades/oportunidad-de-inversion-en-haus-blvd-carmelitas-y-57313116.html',
#  '/propiedades/departamento-en-venta-parque-veneto-lomas-de-58967939.html',
#  '/propiedades/hermoso-departamento-en-venta-nidum-en-puebla-59192424.html',
#  '/propiedades/departamentos-en-venta-balcones-del-sur-puebla-58076549.html',
#  '/propiedades/departamento-en-venta-en-col.-huexotitla-sd-1915-57634212.html',
#  '/propiedades/excelentes-departamentos-en-venta-en-la-18-oriente-59150633.html',
#  '/propiedades/venta-de-loft-en-lomas-de-angelopolis-parque-sinaloa-58925130.html',
#  '/propiedades/penthouse-en-torre-adamant-55221495.html',
#  '/propiedades/se-vende-departamento-en-residencial-punta-alta-58234769.html',
#  '/propiedades/departamento-en-venta-en-fraccionamiento-privada-del-56398276.html',
#  '/propiedades/se-vende-departamento-nuevo-torre-santa-fe-zavaleta.-59044720.html',
#  '/propiedades/departamento-de-lujo-3-recamaras-plusvalia-en-58961665.html',
#  '/propiedades/aprovecha-y-compra-departamento-en-hujotzingo-59153511.html',
#  '/propiedades/departamento-en-venta-52076132.html',
#  '/propiedades/espectacular-departamento-en-la-vista-ideal!-58000113.html',
#  '/propiedades/departamentos-nuevos-en-venta-el-cerrito-puebla-58638936.html',
#  '/propiedades/departamentos-en-venta-colonia-centro-chulavista-55206775.html',
#  '/propiedades/oportunidad-de-departamento-en-planta-baja-a-solo-3-56330197.html',
#  '/propiedades/pent-house-en-venta-la-noria-puebla-57235859.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-57832056.html',
#  '/propiedades/atlixcayotl-angelopolis-59143925.html',
#  '/propiedades/departamento-en-venta-cerca-de-angelopolis-55819744.html',
#  '/propiedades/venta-departamento-excelente-ubicacion-torres-de-52305652.html',
#  '/propiedades/departamentos-en-venta-zona-angelopolis-torres-uma-58240292.html',
#  '/propiedades/estrena-dpto-en-angelopolis-con-todo-59145644.html',
#  '/propiedades/departamento-en-venta-colonia-san-manuel-59180724.html',
#  '/propiedades/departamentos-en-venta-zona-anzures-con-excelentes-57169232.html',
#  '/propiedades/opcion-para-inversionistas-2-habitaciones-con-bano-56582847.html',
#  '/propiedades/departamento-en-venta-en-la-zona-de-galerias-serdan.-57742965.html',
#  '/propiedades/angelopolis-58780820.html',
#  '/propiedades/departamento-con-3-habitaciones-a-calles-de-udlap-58118095.html',
#  '/propiedades/departamento-en-condominio-villas-del-vergel-ex-59175366.html',
#  '/propiedades/departamento-en-venta-cd-judicial-sd-1745-57721528.html',
#  '/propiedades/departamento-en-venta-inspiralta-torre-c-503-58240262.html',
#  '/propiedades/departamento-en-venta-en-la-zona-de-galerias-serdan-sd-57742968.html',
#  '/propiedades/loft-industrial-cholula-desde-credito-amplitud-vistas-57514425.html',
#  '/propiedades/departamento-nuevo-en-venta-en-el-corazon-de-san-pedro-57723314.html',
#  '/propiedades/departamento-en-venta-zavaleta-vive-lo-natural-54449489.html',
#  '/propiedades/departamento-en-venta-san-andres-cholula-58121100.html',
#  '/propiedades/departamento-en-venta-en-planta-baja-cerca-de-56699768.html',
#  '/propiedades/departamento-en-la-vista-san-andres-cholula-gsi-56895565.html',
#  '/propiedades/departamento-en-venta-en-sonata-57733215.html',
#  '/propiedades/departamento-san-jose-munive-59145753.html',
#  '/propiedades/departamentos-en-venta-en-la-de-zona-villa-encantada-57521971.html',
#  '/propiedades/departamento-en-torre-nducha-venta-y-renta-58250025.html',
#  '/propiedades/penthouse-en-torre-enigma-boulevard-de-las-torres-58115111.html',
#  '/propiedades/departamento-en-venta-en-puebla-puente-de-mexico-202-56127831.html',
#  '/propiedades/departamento-en-venta-col.-santa-cruz-buenavista-57549450.html',
#  '/propiedades/depto-junto-upaep-56953937.html',
#  '/propiedades/pent-garden-en-venta-en-high-towers-elite-de-dos-58254915.html',
#  '/propiedades/departamentos-de-lujo-en-preventa-en-exclusivo-56050857.html',
#  '/propiedades/departamento-en-venta-zavaleta-vive-lo-natural-54449491.html',
#  '/propiedades/departamento-a-3-minutos-de-carretera-cholula-puebla-58110425.html',
#  '/propiedades/departamento-en-venta-vista-marques-lomas-de-55575657.html',
#  '/propiedades/departamento-en-venta-en-torre-altazia-por-la-55606465.html',
#  '/propiedades/departamento-en-venta-en-col.-bugambilias-cerca-de-16-56324584.html',
#  '/propiedades/departamentos-en-venta-cruz-del-sur-blvd.-forjadores-58240287.html',
#  '/propiedades/venta-de-departamento-de-lujo-en-punta-alta-zona-53593559.html',
#  '/propiedades/venta-de-departamento-en-camino-real-a-momoxpan-la-59040274.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-57236072.html',
#  '/propiedades/departamentos-en-venta-en-colonia-la-paz-56210956.html',
#  '/propiedades/hermoso-penthgarden-en-preventa-2020-en-la-loma-grand-58316154.html',
#  '/propiedades/venta-de-departamentos-modernos-y-amplios-en-vitale-58227846.html',
#  '/propiedades/departamento-en-venta-gabriel-pastor-sd-1739-57721536.html',
#  '/propiedades/venta-departamentos-en-lomas-de-angelopolis-58551856.html',
#  '/propiedades/departamentos-economicos-en-zona-de-huejotizngo-55548316.html',
#  '/propiedades/departamento-en-venta-amueblado-de-oportunidad-con-57311880.html',
#  '/propiedades/las-animas-58323837.html',
#  '/propiedades/departamento-de-lujo-en-la-zona-mas-exclusiva-de-58577632.html',
#  '/propiedades/aprovecha-gran-oportunidad-a-7-min-del-aeropuerto-58277148.html',
#  '/propiedades/venta-departamento-centro-de-cholula-57360726.html',
#  '/propiedades/departamento-a-7-minutos-de-aeropuerto-de-puebla-58110086.html',
#  '/propiedades/pre-venta-de-departamento-nuevo-estilo-vintage-57236618.html',
#  '/propiedades/departamentos-en-venta-en-momoxpan-edificio-di-garda-56210938.html',
#  '/propiedades/departamento-en-anzures-puebla-gsi-957-de-57360652.html',
#  '/propiedades/departamento-en-venta-inspiralta-zona-atlixcayotl-56831381.html',
#  '/propiedades/nuevo-departamento-en-venta-en-colonia-bugambilias-57989702.html',
#  '/propiedades/departamento-nuevo-en-venta-en-la-noria-sd-1905c-57726534.html',
#  '/propiedades/loft-en-venta-cholula-para-bohemios-industrial-12-57398048.html',
#  '/propiedades/departamento-san-andres-cholula-estrellas-del-sur-58707766.html',
#  '/propiedades/punto-horizonte-58735675.html',
#  '/propiedades/zavaleta-58793663.html',
#  '/propiedades/departamento-en-venta-en-sonata-towers-57059296.html',
#  '/propiedades/departamento-en-venta-53677577.html',
#  '/propiedades/departamento-amplio-cerca-de-la-universidad-buap-57277639.html',
#  '/propiedades/se-venden-departamentos-en-bello-horizonte-57989865.html',
#  '/propiedades/departamento-en-venta-57823239.html',
#  '/propiedades/departamentos-en-venta-en-zavaleta-desde-$3-008-350-54584078.html',
#  '/propiedades/departamento-en-venta-ubicado-zona-udlap-recta-a-chol.-58733104.html',
#  '/propiedades/casa-en-venta-en-lomas-de-angelopolis-56205912.html',
#  '/propiedades/departamentos-en-venta-de-91-m-sup2--en-high-towers-58597738.html',
#  '/propiedades/pent-garden-en-venta-en-high-towers-elite-lomas-de-58254917.html',
#  '/propiedades/la-vista-residence-penthouse-nuevo-venta-vista-360-58663363.html',
#  '/propiedades/departamento-en-venta-frente-a-sonata-56353692.html',
#  '/propiedades/departamento-en-venta-en-condepcion-la-cruz-57597447.html',
#  '/propiedades/departamento-en-torre-palma-ii-54547702.html',
#  '/propiedades/exclusivo-penthouse-en-la-zona-de-galerias-serdan.-58216681.html',
#  '/propiedades/se-vende-departamento-en-colonia-el-vergel-57989930.html',
#  '/propiedades/departamento-en-pre-venta-parque-toscana-lomas-de-57721621.html',
#  '/propiedades/amplio-y-precioso-departamento-en-puebla-57280997.html',
#  '/propiedades/departamento-en-venta-de-2-recamaras-en-lomas-de-57990913.html',
#  '/propiedades/departamento-en-high-towers-junto-a-sonata-en-lomas-54418149.html',
#  '/propiedades/residencial-torre-palmas-58898132.html',
#  '/propiedades/hermoso-penthgarden-en-preventa-2020-en-la-loma-grand-58292707.html',
#  '/propiedades/departamento-en-venta-en-puebla-puente-de-mexico-202-56180455.html',
#  '/propiedades/departamento-en-venta-torre-tempo-vitale-residencial-58254961.html',
#  '/propiedades/departamento-a-calles-de-plaza-san-diego.-2-57398562.html',
#  '/propiedades/departamento-en-el-barreal-san-andres-cholula-gsi-56895636.html',
#  '/propiedades/departamento-en-preventa-muy-cerca-de-la-ibero-59083076.html',
#  '/propiedades/departamento-en-venta-en-torre-alegro-en-parque-57115960.html',
#  '/propiedades/departamento-en-venta-en-la-vista-country-club-san-55944261.html',
#  '/propiedades/residencia-en-venta-en-parque-la-gran-reserva-lomas-de-58389512.html',
#  '/propiedades/departamento-en-venta-57998250.html',
#  '/propiedades/departamento-en-venta-en-arboledas-de-loma-bella-57811138.html',
#  '/propiedades/departamentos-en-venta-en-frente-de-la-udla-puebla.-57790410.html',
#  '/propiedades/departamento-en-venta-en-calle-pomanski-a-1-minuto-de-56210699.html',
#  '/propiedades/departamento-a-solo-10-min-de-la-buap-2-y-3-56331434.html',
#  '/propiedades/penthouse-en-3-niveles-con-roof-garden-area-de-bar-y-55431718.html',
#  '/propiedades/hermosos-departamentos-en-venta-con-excelente-57000535.html',
#  '/propiedades/departamento-3-recamaras-en-venta-en-nidum-58237613.html',
#  '/propiedades/departamento-nuevo-en-venta-en-la-noria-sd-1905c-57726534.html',
#  '/propiedades/pent-house-en-venta-en-blvd.-forjadores-el-puente-58240356.html',
#  '/propiedades/lomas-de-angelopolis-ii-58237042.html',
#  '/propiedades/departamento-en-venta-ubicado-en-zavaleta-sd-2005-58177996.html',
#  '/propiedades/la-paz-58314984.html',
#  '/propiedades/zavaleta-58792937.html',
#  '/propiedades/departamento-en-venta-de-oportunidad-en-torre-adamant-59018674.html',
#  '/propiedades/torre-adamant-ii-58507349.html',
#  '/propiedades/departamento-en-venta-en-edificio-punta-alta-reserva-59082887.html',
#  '/propiedades/se-vende-departamento-de-lujo-en-residencial-el-angel-57989768.html',
#  '/propiedades/departamento-en-lomas-de-angelopolis-san-andres-57360660.html',
#  '/propiedades/venta-departamento-en-edificio-artea-puebla-58834395.html',
#  '/propiedades/departamento-en-venta-en-torre-adamant-ii-angelopolis-59082918.html',
#  '/propiedades/departamentos-en-preventa-via-atlixcayotl-lexum-56266641.html',
#  '/propiedades/departamento-en-venta-inspiralta-58240342.html',
#  '/propiedades/departamentos-en-venta-en-forjadores-cholula-58552617.html',
#  '/propiedades/departamento-en-venta-zavaleta-vive-lo-natural-57311164.html',
#  '/propiedades/venta-de-penthouse-231-m-sup2--en-torre-anzures-zona-55779090.html',
#  '/propiedades/departamento-en-pre-venta-en-torre-valiara-en-parque-57597972.html',
#  '/propiedades/departamentos-en-venta-cerca-de-plaza-explanada-en-59082897.html',
#  '/propiedades/departamento-en-venta-en-a-2-minutos-de-la-udla-57570633.html',
#  '/propiedades/departamento-en-venta-elipsis-towers-sd-1644-57681262.html',
#  '/propiedades/departamento-en-venta-en-la-colonia-la-paz-57215226.html',
#  '/propiedades/ex-hacienda-chapulco-58458607.html',
#  '/propiedades/loft-industrial-cholula-con-vista-a-los-volcanes-57859287.html',
#  '/propiedades/departamento-en-venta-cerca-de-uvm-53502066.html',
#  '/propiedades/departamentos-en-la-paz-a-solo-10-min-de-la-juarez-57174216.html',
#  '/propiedades/venta-departamento-en-torre-mazik-en-la-entrada-de-55385596.html',
#  '/propiedades/departamento-en-venta-51651283.html',
#  '/propiedades/departamento-en-venta-las-animas-sd-1519-57678376.html',
#  '/propiedades/renta-departamento-loft-en-plazuelas-del-fresno-305-58956353.html',
#  '/propiedades/departamento-en-venta-zona-sur-granjas-san-isidro-58993011.html',
#  '/propiedades/departamento-en-preventa-en-lomas-de-angelopolis-58183506.html',
#  '/propiedades/venta-de-departamento-en-colonia-arboledas-de-loma-58721263.html',
#  '/propiedades/departamento-popular-emiliano-zapata-58472211.html',
#  '/propiedades/departamento-en-venta-en-adamant-2-angelopolis-sd-57678412.html',
#  '/propiedades/venta-de-departamentos-sobre-atlixcayotl-en-torre-58931341.html',
#  '/propiedades/departamento-en-venta-torre-fogo-vitale-residencial-58292692.html',
#  '/propiedades/venta-departamento-en-torre-anzures-en-puebla-55775092.html',
#  '/propiedades/venta-de-departamento-nuevo-en-colonia-bugambilias-57989802.html',
#  '/propiedades/renta-de-departamento-por-periferico-59119774.html',
#  '/propiedades/departamento-en-venta-frente-a-parque-del-arte-puebla-55901268.html',
#  '/propiedades/penth-garden-en-venta-edificio-punta-cascatta-lomas-de-56231161.html',
#  '/propiedades/loft-udlap-58216706.html',
#  '/propiedades/se-vende-departamento-en-colonia-el-vergel-57989930.html',
#  '/propiedades/venta-de-departamentos-en-saint-peter-cerca-de-plaza-52820829.html',
#  '/propiedades/recta-a-cholula-58458591.html',
#  '/propiedades/venta-de-departamento-en-lomas-de-angelopolis-parque-58683044.html',
#  '/propiedades/pre-venta-de-departamentos-a-excelente-precio-55863006.html',
#  '/propiedades/terrazas-tadeo-en-puebla!-departamento-con-acabados-de-58583432.html',
#  '/propiedades/departamento-en-venta-cerca-de-angelopolis-55819745.html',
#  '/propiedades/venta-de-departamento-zavaleta-puebla-58430971.html',
#  '/propiedades/departamento-en-venta-en-la-colonia-la-paz-57215207.html',
#  '/propiedades/departamento-en-venta-en-inmejorable-ubicacion-dentro-58254925.html',
#  '/propiedades/espectacular-departamento-a-5-min-de-la-paz-y-av-57404395.html',
#  '/propiedades/departamento-en-venta-elipsis-towers-sd-1645-57681232.html',
#  '/propiedades/departamento-en-venta-en-la-zona-de-la-udlap-56881958.html',
#  '/propiedades/departamentos-en-preventa-torre-ennea-junto-al-parque-58356236.html',
#  '/propiedades/zavaleta-58792937.html',
#  '/propiedades/bello-departamento-en-venta-conj.-carmelita-cerca-del-59094234.html',
#  '/propiedades/departamentos-en-venta-torre-vista-turquesa.-53705415.html',
#  '/propiedades/departamento-en-venta-58192936.html',
#  '/propiedades/venta-de-departamento-en-cuautlancingo-puebla.-56328602.html',
#  '/propiedades/departamento-en-venta-en-planta-baja-en-atlixcayotl-59129679.html',
#  '/propiedades/departamento-de-lujo-en-lomas-de-angelopolis-2-torre-58216806.html',
#  '/propiedades/departamento-en-venta-en-el-barreal-52824854.html',
#  '/propiedades/preventa-deptos-cudad-de-puebla-oak-58-high-living-55449374.html',
#  '/propiedades/preventa-departamentos-lomas-angelopilis-56955408.html',
#  '/propiedades/departamentos-en-venta-o-renta-zavaleta-y-forjadores-59082852.html',
#  '/propiedades/departamentos-en-venta-parque-del-arte-artema-703-58240325.html',
#  '/propiedades/magnifico-departamento-moderno-con-roof-garden-comun-58544797.html',
#  '/propiedades/departamentos-con-excelente-ubicacion-a-15-min-de-la-54781442.html',
#  '/propiedades/departamento-en-pre-venta-parque-toscana-lomas-de-57721621.html',
#  '/propiedades/departamento-en-venta-en-la-zona-de-huexotitla-56809835.html',
#  '/propiedades/amplio-departamento-en-venta-en-high-towers-elite-58254922.html',
#  '/propiedades/penthouse-en-venta-en-zavaleta.-gran-oportunidad.-4-58765536.html',
#  '/propiedades/departamento-en-venta-en-zerezotla!-57556915.html',
#  '/propiedades/venta-de-penthouse-en-cholula-55736403.html',
#  '/propiedades/torre-adamant-ii-58516614.html',
#  '/propiedades/departamento-exclusivo-a-excelente-precio-en-el-mejor-58944744.html',
#  '/propiedades/venta-lofts-nuevos-en-la-paz-57582237.html',
#  '/propiedades/el-carmen-atlixco-58458603.html',
#  '/propiedades/departamento-en-venta-en-torre-abric-57168485.html',
#  '/propiedades/departamento-en-venta-en-la-carcana-52472946.html',
#  '/propiedades/departamentos-amplios-y-lujos-en-cholula-57304565.html',
#  '/propiedades/venta-de-deptos.-en-parque-toscana-lomas-de-51542896.html',
#  '/propiedades/excelentes-departamentos-en-puebla-58928582.html',
#  '/propiedades/departamento-en-venta-en-torre-blank-lomas-de-59082827.html',
# ...
#  '/propiedades/oportunidad-de-departamentos-nuevos-en-parque-veneto-58263477.html',
#  '/propiedades/departamento-en-pre-venta-zavaleta-sd-1703-57681218.html',
#  '/propiedades/departamentos-en-venta-en-xilotzingo-cerca-de-la-58321164.html',
#  '/propiedades/departamento-en-venta-arts-vertical-angelopolis-53663456.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-57236072.html',
#  '/propiedades/departamento-san-andres-cholula-56881542.html',
#  '/propiedades/penthouse-en-torre-adamant-55221495.html',
#  '/propiedades/2-habitaciones-vigilancia-elevador-roof-garden-a-7-56581680.html',
#  '/propiedades/departamento-en-venta-en-la-radial-cholula-en-san-59083130.html',
#  '/propiedades/vendo-depto-san-jose-del-puente-camino-del-rey-56714619.html',
#  '/propiedades/departamento-grande-en-venta-en-punto-horizonte-59076207.html',
#  '/propiedades/departamentos-en-venta-en-14-sur-torre-anzures-58240258.html',
#  '/propiedades/departamento-en-venta-lomas-de-angelopolis-sd-1436-57678417.html',
#  '/propiedades/lomas-de-angelopolis-iii-cascadia-58260958.html',
#  '/propiedades/angelopolis-59114705.html',
#  '/propiedades/precioso-pent-hause-en-excelente-ubicacion-en-puebla-57735888.html',
#  '/propiedades/departamento-en-park-view-59120222.html',
#  '/propiedades/departamentos-en-venta-de-lujo-de-98-m-sup2--en-58031660.html',
#  '/propiedades/excelentes-departamentos-en-puebla-58928582.html',
#  '/propiedades/departamento-cuautlancingo-59181807.html',
#  '/propiedades/departamento-en-venta-cerca-de-plaza-dorada-sd-58557410.html',
#  '/propiedades/departamento-en-venta-cholula-57591908.html',
#  '/propiedades/departamento-en-venta-lomas-de-angelopolis-sd-1435-57678366.html',
#  '/propiedades/venta-de-departamento-en-torre-baori-56747726.html',
#  '/propiedades/departamento-con-alberca-en-venta-arts-luxury-condos-57846996.html',
#  '/propiedades/departamento-en-venta-en-morillotla-59167336.html',
#  '/propiedades/venta-o-renta-departamento-en-cluster-fracc-lomas-de-59061933.html',
#  '/propiedades/departamento-en-preventa-en-lomas-de-angelopolis-58205983.html',
#  '/propiedades/departamentos-en-preventa-la-paz-puebla-puebla.-55750960.html',
#  '/propiedades/!-excelente-preventa-departamentos-a-5-min-de-la-paz-y-57437971.html',
#  '/propiedades/se-vende-departamento-en-san-andres-cholula-centro-58389515.html',
#  '/propiedades/departamento-venta-2-recamaras-hacienda-de-58447923.html',
#  '/propiedades/departamento-en-venta-zavaleta-vive-lo-natural-54449493.html',
#  '/propiedades/departamento-en-venta-en-gladiolas-bugambilias-57381592.html',
#  '/propiedades/venta-ph-espectacular-amueblado-en-nducha-58610644.html',
#  '/propiedades/ultimo-departamento-rodeado-de-universidades-54813276.html',
#  '/propiedades/departamento-con-3-habitaciones-amplia-terraza-cuarto-56328181.html',
#  '/propiedades/departamento-en-venta-en-loreta-lomas-de-angelopolis-54583850.html',
#  '/propiedades/hermoso-departamento-en-preventa-la-loma-grand-view-58316157.html',
#  '/propiedades/departamento-en-venta-en-la-zona-de-la-paz-en-torre-55213707.html',
#  '/propiedades/departamento-lomas-de-angelopolis-sonata-puebla-57027799.html',
#  '/propiedades/departamento-en-venta-en-la-paz-57720484.html',
#  '/propiedades/departamento-en-venta-alpha-residences-sonata-lomas-59087450.html',
#  '/propiedades/departamento-en-venta-atzala-udla-cholula-puebla-57401162.html',
#  '/propiedades/venta-de-departamentos-en-san-andres-cholula-cerca-de-55324837.html',
#  '/propiedades/economicos-departamentos-cerca-del-aeropuerto-puebla-58277147.html',
#  '/propiedades/departamento-amueblado-muy-cerca-de-sonata-54972821.html',
#  '/propiedades/departamentos-en-cholula-con-alberca-area-de-asadores-58309018.html',
#  '/propiedades/departamento-en-venta-en-cascatta-59024133.html',
#  '/propiedades/departamento-en-la-zona-de-bugambilias-3-habitaciones-56964915.html',
#  '/propiedades/udlap-58216755.html',
#  '/propiedades/pent-house-amueblado-en-elipsis-tower-zona-comercial-58579049.html',
#  '/propiedades/departamento-en-centro-zavaleta-sd-1814-57738736.html',
#  '/propiedades/departamentos-en-preventa-torre-quore-nuevo-zavaleta-54980823.html',
#  '/propiedades/departamento-en-venta-en-puebla-57126092.html',
#  '/propiedades/departamento-nuevo-en-venta-en-mayorazgo-puebla-59041334.html',
#  '/propiedades/venta-departamento-en-san-jose-mayorazgo-58144790.html',
#  '/propiedades/departamento-en-pre-venta-cerca-de-plaza-explanada-en-59082961.html',
#  '/propiedades/precioso-departamento-a-5-min-de-centro-comercial-cruz-58000102.html',
#  '/propiedades/departamentos-de-lujo-puebla-56419424.html',
#  '/propiedades/departamento-en-venta-en-toscana-lomas-de-angelopolis-59082931.html',
#  '/propiedades/departamento-en-venta-torre-calatea-37-zona-plaza-san-57083919.html',
#  '/propiedades/departamento-en-venta-sonata-towers-lomas-de-51312467.html',
#  '/propiedades/departamento-en-preventa-en-lomas-de-angelopolis-58206079.html',
#  '/propiedades/departamento-en-pre-venta-zavaleta-sd-1703-57681218.html',
#  '/propiedades/penthouse-de-lujo-cerca-planta-vw-58098524.html',
#  '/propiedades/loft-en-venta-enfocado-al-estilo-wellness-en-cholula-57502515.html',
#  '/propiedades/departamento-en-venta-en-el-ensueno-san-martinito-58604609.html',
#  '/propiedades/departamento-en-venta-ubicado-en-la-zona-de-la-paz-57017308.html',
#  '/propiedades/departamento-en-venta-en-arboledas-de-zavaleta-203b-58240408.html',
#  '/propiedades/departamento-en-venta-en-santiago-momoxpan-san-pedro-59082966.html',
#  '/propiedades/departamento-en-venta-en-la-loma-gran-reserva-lomas-58229282.html',
#  '/propiedades/departamento-en-venta-alpha-residences-sonata-lomas-58455901.html',
#  '/propiedades/excelente-loft-a-estrenar-en-la-zona-in-de-puebla!-57449750.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-58577540.html',
#  '/propiedades/departamentos-con-elevador-y-2-habitaciones-54634038.html',
#  '/propiedades/preventa-de-departamentos-por-plaza-san-pedro-58214041.html',
#  '/propiedades/departamento-en-venta-zona-forjadores-puebla.-59114131.html',
#  '/propiedades/venta-de-departamento-en-av-juarez-puebla.-57778991.html',
#  '/propiedades/departamento-en-venta-torre-nubola-57658566.html',
#  '/propiedades/departamentos-en-venta-nuevos-cholula-amplios-espacios-58068007.html',
#  '/propiedades/departamento-en-venta-en-torre-abric-57168608.html',
#  '/propiedades/departamento-tecamachalco-56413677.html',
#  '/propiedades/departamento-en-venta-en-fraccionamiento-camino-a-59082976.html',
#  '/propiedades/departamento-en-venta-puebla-57272003.html',
#  '/propiedades/departamentos-en-venta-economicos-norte-de-puebla-59099336.html',
#  '/propiedades/departamento-en-venta-en-la-udlap-estilo-industrial-57248621.html',
#  '/propiedades/departamento-en-venta-torre-inspiralta-zona-56534498.html',
#  '/propiedades/loft-momoxpan-cholula-puebla-plazuelas-del-fresno-58598064.html',
#  '/propiedades/departamento-nuevo-en-puebla-a-15-minutos-de-finsa-58516691.html',
#  '/propiedades/departamentos-en-venta-san-andres-cholula-muy-cerca-56199876.html',
#  '/propiedades/departamento-en-venta-zona-atlixcayotl-torre-perseo-57763054.html',
#  '/propiedades/departamento-en-venta-en-puebla-puente-de-mexico-202-56180446.html',
#  '/propiedades/departamento-en-venta-en-sonata-58466946.html',
#  '/propiedades/ultimos-3-departamentos-en-venta-en-tlaxcalancingo-san-56331421.html',
#  '/propiedades/preventa-de-departamentos-jardines-de-los-fuertes-55530468.html',
#  '/propiedades/departamento-de-dos-recamaras-atlaco-lujo-amplitud-y-59053357.html',
#  '/propiedades/departamento-puebla-de-zaragoza-58433632.html',
#  '/propiedades/departamento-excelente-ubicacion-col.-elcarmen-59145643.html',
#  '/propiedades/departamento-en-venta-en-zavaleta.-gran-oportunidad.-3-58765474.html',
#  '/propiedades/departamento-en-venta-59057188.html',
#  '/propiedades/departamento-en-pre-venta-en-torre-valiara-en-parque-57594815.html',
#  '/propiedades/bosques-santorum-cuautlancingo-57630256.html',
#  '/propiedades/penthouse-en-venta-en-san-jose-del-puente-puebla-58887064.html',
#  '/propiedades/departamento-en-venta-en-zavaleta-57733142.html',
#  '/propiedades/penthouse-en-venta-en-park-luxe-lomas-de-a-sd-1744-57721521.html',
#  '/propiedades/penthouse-de-lujo-con-1000-m-sup2--y-departamentos-58664714.html',
#  '/propiedades/departamentos-en-venta-en-exclusiva-torre-torre-53614552.html',
#  '/propiedades/departamento-en-venta-en-torre-tango-parque-veneto-58836627.html',
#  '/propiedades/zavaleta-forjadores-58315035.html',
#  '/propiedades/departamento-en-venta-en-la-zona-de-huexotitla-56809779.html',
#  '/propiedades/departamentos-en-san-jose-mayorazgo-54840654.html',
#  '/propiedades/departamentos-en-venta-de-132-m-sup2--de-dos-pisos-en-58597740.html',
#  '/propiedades/venta-de-departamento-en-la-carcana-55689497.html',
#  '/propiedades/venta-de-departamento-nuevo-a-5-minutos-de-ciudad-59190702.html',
#  '/propiedades/departamento-adamant-58920419.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-i-sd-58317647.html',
#  '/propiedades/departamento-nuevo-en-venta-momoxpan-puebla-58766573.html',
#  '/propiedades/departamentos-hacienda-santo-domingo-11-sur-y-135-55516433.html',
#  '/propiedades/departamento-en-venta-cerca-de-planta-vw-parque-finsa-58112870.html',
#  '/propiedades/departamento-en-moratilla-puebla-iti-1332-de-58366227.html',
#  '/propiedades/casa-loft-en-cholula-el-suspiro-a-5-min-periferico-56840388.html',
#  '/propiedades/venta-de-departamento-en-loreta-lomas-de-angelopolis-58154995.html',
#  '/propiedades/depto-en-puebla-nuevo-58558318.html',
#  '/propiedades/departamento-amueblado-en-venta-o-renta-en-acueducto-58737247.html',
#  '/propiedades/departamentos-en-venta-en-zavaleta-centro-zavaleta-58240313.html',
#  '/propiedades/departamentos-en-venta-de-lujo-de-98-m-sup2--en-58031660.html',
#  '/propiedades/departamento-en-venta-en-cholula-puebla-mandala-58734181.html',
#  '/propiedades/departamentos-en-venta-zona-centro-de-la-ciudad-58517584.html',
#  '/propiedades/hermoso-departamento-residencial-56395977.html',
#  '/propiedades/departamento-en-venta-puebla-fraccionamiento-el-58175145.html',
#  '/propiedades/pent-garden-entrega-inmediata-en-high-towers-elite-58227837.html',
#  '/propiedades/departamento-con-amenidades-de-lujo-en-venta-en-high-54744190.html',
#  '/propiedades/venta-de-departamento-en-abric-lomas-de-angelopolis-58602523.html',
#  '/propiedades/penthouse-en-venta-en-vista-marques-57271008.html',
#  '/propiedades/departamento-en-venta-o-renta-blue-towers-sd-1804-57742942.html',
#  '/propiedades/bonito-departamento-en-renta-venta-56087345.html',
#  '/propiedades/loft-en-venta-de-1-recamara-en-cholula-puebla-57350480.html',
#  '/propiedades/departamentos-en-venta-zona-2-sur-y-perferico-57458123.html',
#  '/propiedades/departamento-en-venta-punta-cascatta-lomas-de-57721576.html',
#  '/propiedades/departamento-en-renta-venta-torre-carrara-departamento-58240349.html',
#  '/propiedades/torre-de-departamento-a-5-min-de-sonata-excelentes-56279717.html',
#  '/propiedades/hermoso-departamento-en-venta-en-la-carcana-camino-de-57001741.html',
#  '/propiedades/venta-departamentos-a-2-minutos-de-la-udlap-recta-56339335.html',
#  '/propiedades/departamento-hacienda-santo-domingo-57123102.html',
#  '/propiedades/venta-de-pent-house-en-la-paz-puebla.-58053382.html',
#  '/propiedades/departamento-en-venta-en-mayorazgo-59042920.html',
#  '/propiedades/bonitos-departamentos-en-venta-nuevos-en-lomas-de-55662491.html',
#  '/propiedades/departamento-en-venta-56186920.html',
#  '/propiedades/departamento-en-venta-en-pueblo-san-andres-cholula-59129693.html',
#  '/propiedades/recta-a-cholula-departamento-amplio-renta-venta-57916890.html',
#  '/propiedades/departamento-en-venta-o-renta-en-la-vista-tower-58306480.html',
#  '/propiedades/departamento-desde-116-m-sup2--con-2-recamaras-2-57416858.html',
#  '/propiedades/departamento-2-recs-en-venta-blvd-carmelitas-puebla-58419549.html',
#  '/propiedades/departamento-en-venta-en-sonata-58466946.html',
#  '/propiedades/venta-de-departamento-en-san-ramon-por-la-11-sur-56401587.html',
#  '/propiedades/departamento-en-venta-zona-la-maria-sd-1912b-57634242.html',
#  '/propiedades/departamento-industrial-cholula-amplitud-diseno-unico-58972940.html',
#  '/propiedades/departamento-en-venta-lomas-de-angelopolis-57584816.html',
#  '/propiedades/departamento-en-la-noria-puebla-gsi-878-de-56895634.html',
#  '/propiedades/departamento-en-renta-y-venta-en-angelopolis-ciudad-59082809.html',
#  '/propiedades/departamento-nuevo-en-venta-momoxpan-puebla-58766573.html',
#  '/propiedades/departamento-a-3-minutos-de-carretera-cholula-puebla-58110425.html',
#  '/propiedades/departamento-en-venta-en-la-trinidad-56374109.html',
#  '/propiedades/venta-departamento-col.-patrimonio-puebla-58335426.html',
#  '/propiedades/departamentos-en-venta-o-renta-803-y-804-en-torre-uma-58711424.html',
#  '/propiedades/departamento-en-venta-en-cholula-sd-1635-57681257.html',
#  '/propiedades/departamento-en-venta-zona-zavaleta-y-la-recta-59115943.html',
#  '/propiedades/departamento-en-venta-angelopolis-59046411.html',
#  '/propiedades/departamento-en-venta-53677643.html',
#  '/propiedades/departamento-en-venta-parque-toscana-lomas-de-57264417.html',
#  '/propiedades/preciosos-departamentos-en-venta-con-roof-garden-58722774.html',
#  '/propiedades/departamento-en-venta-en-aureal-residencial-puebla-57421505.html',
#  '/propiedades/departamento-en-venta-edificio-punta-del-cielo-la-57420229.html',
#  '/propiedades/departamento-de-lujo-en-lomas-de-angelopolis-2-torre-58216806.html',
#  '/propiedades/departamento-en-venta-san-andres-cholula-56488179.html',
#  '/propiedades/venta-departamento-en-san-felipe-hueyotlipan-58448116.html',
#  '/propiedades/departamento-en-venta-lomas-de-angelopolis-san-53273045.html',
#  '/propiedades/amplio-departamento-en-venta-en-high-towers-elite-58254922.html',
#  '/propiedades/se-venden-hermosos-departamentos-en-torre-de-lomas-de-58120706.html',
#  '/propiedades/venta-departamentos-en-zona-sur-puebla.-59094690.html',
#  '/propiedades/pre-venta-de-departamentos-de-lujo-en-torre-sadro-55269560.html',
#  '/propiedades/departamento-en-venta-cerca-de-angelopolis-55819744.html',
#  '/propiedades/departamento-en-venta-zona-angelopolis-sd-1747-57721602.html',
#  '/propiedades/departamento-en-pre-venta-en-torre-valiara-en-parque-57603337.html',
#  '/propiedades/santiago-momoxpan-58531122.html',
#  '/propiedades/departamento-excelente-ubicacion-col.-elcarmen-59145643.html',
#  '/propiedades/departamento-en-pre-venta-parque-del-arte-sd-1753b-57721573.html',
#  '/propiedades/loft-industrial-en-venta-para-bohemios-en-el-corazon-55755320.html',
#  '/propiedades/departamentos-en-venta-en-torres-arts-luxury-condos-56210990.html',
#  '/propiedades/departamento-en-pre-venta-en-torre-valiara-en-parque-57594177.html',
#  '/propiedades/departamento-en-venta-en-puebla-en-torre-nducha-en-56617399.html',
#  '/propiedades/atlixcayotl-58216677.html',
#  '/propiedades/departamento-en-pre-venta-parque-del-arte-sd-1753g-57721642.html',
#  '/propiedades/venta-de-departamento-en-torre-di-garda-periferico-y-53427305.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-58576923.html',
#  '/propiedades/departamentos-en-venta-zona-anzures-con-excelentes-57169232.html',
#  '/propiedades/venta-departamento-en-estrellas-del-sur-59172911.html',
#  '/propiedades/ikuna-departamentos-cholula-momoxpan-59070322.html',
#  '/propiedades/lujoso-departamento-en-venta-torre-adamant-a-precio-de-58713430.html',
#  '/propiedades/oportunidad-departamento-en-venta-212-m-sup2--lomas-de-58663773.html',
#  '/propiedades/gran-oportunidad-de-departamento-a-14-min-de-58276966.html',
#  '/propiedades/departamento-en-venta-en-lomas-de-angelopolis-58656457.html',
#  '/propiedades/departamento-en-venta-58755107.html',
#  '/propiedades/departamentos-cholula-de-entrega-inmediata-ideal-para-58254958.html',
#  '/propiedades/departamento-en-venta-en-cholula-puebla-mandala-58734180.html',
#  '/propiedades/departamento-en-venta-en-la-paz-puebla-puebla-59083033.html',
#  '/propiedades/departamento-con-excelente-ubicacion-en-venta-san-58292718.html',
#  '/propiedades/departamento-lexum-55569564.html',
#  '/propiedades/precioso-loft-en-venta-57256923.html',
#  ...]

# %%
#Comenzar la extraccion
for a in range(0,len(CSVList)):
    print(f"Arranca {a}")
    Propiedades = {
        'Marca':[],#Marca
        'Clasificacion':[],#Clasificacion
        'Tipo':[],#Tipo
        'Estado':[],#Estado
        'Municipio':[],#Municipio
        'Colonia':[],#Colonia
        'Colonia2':[],#Colonia2
        'Street':[],#Street
        'Price':[],#Price
        'Moneda':[], #MonedaJ
        'PriceClean':[],#Price1
        'Superficie_Terreno':[],#Terreno
        'Superficie_Construida':[],#Construccion
        'Recamaras':[],#Recamaras
        'Banos':[],#Banos
        'Medio_Bano':[],#Medio_Bano
        'Estacionamientos':[],#Estacionamiento
        'CordA':[],#Coord
        'URL':[],#f'https://century21mexico.com{CasasList[x]}'
    }
    try:
        A = CSVList[a]
        #print("OK2")
        inmuebles = A['0'].values.tolist()
        #A = CSVList[0]
        #product = A['0'].values.tolist()
        #print("OK3")
        print(len(inmuebles))
        #print(f"Comienza {A}")
        for i in range(0,len(inmuebles)):
            #print("OK4")
            
            try:
                
                url = f"https://www.inmuebles24.com{inmuebles[i]}"#propiedades/ciudad-argentum-53621157.html"
                #print(url)
                #url = f"https://www.inmuebles24.com/inmuebles-en-venta-en-{Estado}.html"
                browser.visit(url)
                time.sleep(2)  
                html = browser.html
                soup = bs(html,"html.parser")
                
                Generales = soup.findAll('li', class_="bread-item")
                Marca = Generales[0].getText().replace('\n', '').strip()
                Clasificacion = Generales[1].getText().replace('\n', '').strip()
                Tipo = Generales[2].getText().replace('\n', '').strip()
                Estado = Generales[3].getText().replace('\n', '').strip()
                Municipio = Generales[4].getText().replace('\n', '').strip()
                Colonia = Generales[5].getText().replace('\n', '').strip()
                Colonia2 = Generales[6].getText().replace('\n', '').strip()
                #print("OK Generales")
                
                try:
                    #print("Probamos Opcion 1")
                    HouseDATA1 = soup.findAll('span', class_="data")
                    Terreno = HouseDATA1[4].getText()
                    Construccion = HouseDATA1[1].getText()
                    Banos = ""
                    Estacionamiento = HouseDATA1[5].getText()
                    Recamaras = HouseDATA1[3].getText()
                    Medio_Bano = ""
                      
                    
                    Price = soup.findAll('span', class_="data-price")
                    Price = Price[0].getText().replace('\n', '').strip()
                    Moneda = Price[:3]
                    Price1 = Price.replace('MN ', '').strip()
                    Price1 = Price1.replace(',', '').strip()
                    #print("Opcion 1 OK")
                    
                except:
                    #print("Opcion 1 FAIL")
                    pass
        
                try:
                    #print("Probamos Opcion 2")
                    HouseData2 = soup.findAll('li', class_="icon-feature")
                    Terreno = HouseData2[0].getText().replace('\n', '').strip()
                    Construccion = HouseData2[1].getText().replace('\n', '').strip()
                    Banos = HouseData2[2].getText().replace('\n', '').strip()
                    Estacionamiento = HouseData2[3].getText().replace('\n', '').strip()
                    Recamaras = HouseData2[4].getText().replace('\n', '').strip()
                    Medio_Bano = HouseData2[5].getText().replace('\n', '').strip()
                    
                    Price = soup.findAll('div', class_="price-items")
                    Price = Price[0].getText().replace('\n', '').strip()
                    Moneda = Price[:3]
                    Price1 = Price.replace('MN ', '').strip()
                    Price1 = Price1.replace(',', '').strip()
                    #print("Opcion 2 OK")
                
                except:
                    #print("Opcion 2 FAIL")
                    pass
                
                
                Street = soup.findAll('div', class_="section-location")
                Street = Street[0].getText().replace('\n', '').strip()
            
                Coord = soup.findAll('img', class_="static-map")
                Coord = Coord[0]['src']
                Coord = re.findall('center=(.+)&zoom', Coord)
                #print("ALL OK")
            
            except:
                #print(f"Error Inmueble {i} de {a}")
                pass
            
            #print(f"ALL Inmuebles {i}OK")

            Propiedades["Marca"].append(Marca)
            Propiedades["Clasificacion"].append(Clasificacion)
            Propiedades["Tipo"].append(Tipo)
            Propiedades["Estado"].append(Estado)
            Propiedades["Municipio"].append(Municipio)
            Propiedades["Colonia"].append(Colonia)
            Propiedades["Colonia2"].append(Colonia2)
            Propiedades["Street"].append(Street)
            Propiedades["Price"].append(Price)
            Propiedades["Moneda"].append(Moneda)
            Propiedades["PriceClean"].append(Price1)
            Propiedades["Superficie_Terreno"].append(Terreno)
            Propiedades["Superficie_Construida"].append(Construccion)
            Propiedades["Recamaras"].append(Recamaras)
            Propiedades["Banos"].append(Banos)
            Propiedades["Medio_Bano"].append(Medio_Bano)
            Propiedades["Estacionamientos"].append(Estacionamiento)
            Propiedades["CordA"].append(Coord)
            Propiedades["URL"].append(url)
        
            print(f"Edo {a} append {i} of {len(inmuebles)} OK")
        
        ###TO CSV###
        Name = a+b
        Propiedades_DF = pd.DataFrame(Propiedades)
        Propiedades_DF.to_csv(f'Propiedades Depa {Estados[Name]}.csv', index=False, encoding='utf-8-sig')
        Propiedades_DF
        
    except:
        print(f"Error in {a}")
        pass
    
    
    print(f"ALL CSVs OK")

#"aguascalientes-provincia" 0 - "baja-california-norte" 1 -"baja-california-sur" 2 - "campeche-provincia" 3
#"distrito-federal" 4 - "chiapas" 5 - "chihuahua-provincia" 6 - "coahuila" 7 - "colima-provincia" 8- 
#"durango-provincia" 9 - "edo.-de-mexico" 10 - "guanajuato-provincia" 11 - "guerrero-provincia" 12 -
#"hidalgo-provincia" 13 - "jalisco" 14 - "michoacan" 15 - "morelos-provincia" 16 - "nayarit" 17 -
#"nuevo-leon" 18 - "oaxaca" 19 - "puebla-provincia" 20 - "queretaro-provincia" 21 - "quintana-roo-provincia" 22 -
#"san-luis-potosi-provincia" 23 - "sinaloa-provincia" 24 - "sonora" 25 - "tabasco-provincia" 26 - 
#"tamaulipas" 27 - "tlaxcala-provincia" 28 - "veracruz-provincia" 29 - "yucatan" 30 - "zacatecas-provincia" 31.
# Out:
# Arranca 0
# 2500
# Edo 0 append 0 of 2500 OK
# Edo 0 append 1 of 2500 OK
# Edo 0 append 2 of 2500 OK
# Edo 0 append 3 of 2500 OK
# Edo 0 append 4 of 2500 OK
# Edo 0 append 5 of 2500 OK
# Edo 0 append 6 of 2500 OK
# Edo 0 append 7 of 2500 OK
# Edo 0 append 8 of 2500 OK
# Edo 0 append 9 of 2500 OK
# Edo 0 append 10 of 2500 OK
# Edo 0 append 11 of 2500 OK
# Edo 0 append 12 of 2500 OK
# Edo 0 append 13 of 2500 OK
# Edo 0 append 14 of 2500 OK
# Edo 0 append 15 of 2500 OK
# Edo 0 append 16 of 2500 OK
# Edo 0 append 17 of 2500 OK
# Edo 0 append 18 of 2500 OK
# Edo 0 append 19 of 2500 OK
# Edo 0 append 20 of 2500 OK
# Edo 0 append 21 of 2500 OK
# Edo 0 append 22 of 2500 OK
# Edo 0 append 23 of 2500 OK
# Edo 0 append 24 of 2500 OK
# Edo 0 append 25 of 2500 OK
# Edo 0 append 26 of 2500 OK
# Edo 0 append 27 of 2500 OK
# Edo 0 append 28 of 2500 OK
# Edo 0 append 29 of 2500 OK
# Edo 0 append 30 of 2500 OK
# Edo 0 append 31 of 2500 OK
# Edo 0 append 32 of 2500 OK
# Edo 0 append 33 of 2500 OK
# Edo 0 append 34 of 2500 OK
# Edo 0 append 35 of 2500 OK
# Edo 0 append 36 of 2500 OK
# Edo 0 append 37 of 2500 OK
# Edo 0 append 38 of 2500 OK
# Edo 0 append 39 of 2500 OK
# Edo 0 append 40 of 2500 OK
# Edo 0 append 41 of 2500 OK
# Edo 0 append 42 of 2500 OK
# Edo 0 append 43 of 2500 OK
# Edo 0 append 44 of 2500 OK
# Edo 0 append 45 of 2500 OK
# Edo 0 append 46 of 2500 OK
# Edo 0 append 47 of 2500 OK
# Edo 0 append 48 of 2500 OK
# Edo 0 append 49 of 2500 OK
# Edo 0 append 50 of 2500 OK
# Edo 0 append 51 of 2500 OK
# Edo 0 append 52 of 2500 OK
# Edo 0 append 53 of 2500 OK
# Edo 0 append 54 of 2500 OK
# Edo 0 append 55 of 2500 OK
# Edo 0 append 56 of 2500 OK
# Edo 0 append 57 of 2500 OK
# Edo 0 append 58 of 2500 OK
# Edo 0 append 59 of 2500 OK
# Edo 0 append 60 of 2500 OK
# Edo 0 append 61 of 2500 OK
# Edo 0 append 62 of 2500 OK
# Edo 0 append 63 of 2500 OK
# Edo 0 append 64 of 2500 OK
# Edo 0 append 65 of 2500 OK
# Edo 0 append 66 of 2500 OK
# Edo 0 append 67 of 2500 OK
# Edo 0 append 68 of 2500 OK
# Edo 0 append 69 of 2500 OK
# Edo 0 append 70 of 2500 OK
# Edo 0 append 71 of 2500 OK
# Edo 0 append 72 of 2500 OK
# Edo 0 append 73 of 2500 OK
# Edo 0 append 74 of 2500 OK
# Edo 0 append 75 of 2500 OK
# Edo 0 append 76 of 2500 OK
# Edo 0 append 77 of 2500 OK
# Edo 0 append 78 of 2500 OK
# Edo 0 append 79 of 2500 OK
# Edo 0 append 80 of 2500 OK
# Edo 0 append 81 of 2500 OK
# Edo 0 append 82 of 2500 OK
# Edo 0 append 83 of 2500 OK
# Edo 0 append 84 of 2500 OK
# Edo 0 append 85 of 2500 OK
# Edo 0 append 86 of 2500 OK
# Edo 0 append 87 of 2500 OK
# Edo 0 append 88 of 2500 OK
# Edo 0 append 89 of 2500 OK
# Edo 0 append 90 of 2500 OK
# Edo 0 append 91 of 2500 OK
# Edo 0 append 92 of 2500 OK
# Edo 0 append 93 of 2500 OK
# Edo 0 append 94 of 2500 OK
# Edo 0 append 95 of 2500 OK
# Edo 0 append 96 of 2500 OK
# Edo 0 append 97 of 2500 OK
# Edo 0 append 98 of 2500 OK
# Edo 0 append 99 of 2500 OK
# Edo 0 append 100 of 2500 OK
# Edo 0 append 101 of 2500 OK
# Edo 0 append 102 of 2500 OK
# Edo 0 append 103 of 2500 OK
# Edo 0 append 104 of 2500 OK
# Edo 0 append 105 of 2500 OK
# Edo 0 append 106 of 2500 OK
# Edo 0 append 107 of 2500 OK
# Edo 0 append 108 of 2500 OK
# Edo 0 append 109 of 2500 OK
# Edo 0 append 110 of 2500 OK
# Edo 0 append 111 of 2500 OK
# Edo 0 append 112 of 2500 OK
# Edo 0 append 113 of 2500 OK
# Edo 0 append 114 of 2500 OK
# Edo 0 append 115 of 2500 OK
# Edo 0 append 116 of 2500 OK
# Edo 0 append 117 of 2500 OK
# Edo 0 append 118 of 2500 OK
# Edo 0 append 119 of 2500 OK
# Edo 0 append 120 of 2500 OK
# Edo 0 append 121 of 2500 OK
# Edo 0 append 122 of 2500 OK
# Edo 0 append 123 of 2500 OK
# Edo 0 append 124 of 2500 OK
# Edo 0 append 125 of 2500 OK
# Edo 0 append 126 of 2500 OK
# Edo 0 append 127 of 2500 OK
# Edo 0 append 128 of 2500 OK
# Edo 0 append 129 of 2500 OK
# Edo 0 append 130 of 2500 OK
# Edo 0 append 131 of 2500 OK
# Edo 0 append 132 of 2500 OK
# Edo 0 append 133 of 2500 OK
# Edo 0 append 134 of 2500 OK
# Edo 0 append 135 of 2500 OK
# Edo 0 append 136 of 2500 OK
# Edo 0 append 137 of 2500 OK
# Edo 0 append 138 of 2500 OK
# Edo 0 append 139 of 2500 OK
# Edo 0 append 140 of 2500 OK
# Edo 0 append 141 of 2500 OK
# Edo 0 append 142 of 2500 OK
# Edo 0 append 143 of 2500 OK
# Edo 0 append 144 of 2500 OK
# Edo 0 append 145 of 2500 OK
# Edo 0 append 146 of 2500 OK
# Edo 0 append 147 of 2500 OK
# Edo 0 append 148 of 2500 OK
# Edo 0 append 149 of 2500 OK
# Edo 0 append 150 of 2500 OK
# Edo 0 append 151 of 2500 OK
# Edo 0 append 152 of 2500 OK
# Edo 0 append 153 of 2500 OK
# Edo 0 append 154 of 2500 OK
# Edo 0 append 155 of 2500 OK
# Edo 0 append 156 of 2500 OK
# Edo 0 append 157 of 2500 OK
# Edo 0 append 158 of 2500 OK
# Edo 0 append 159 of 2500 OK
# Edo 0 append 160 of 2500 OK
# Edo 0 append 161 of 2500 OK
# Edo 0 append 162 of 2500 OK
# Edo 0 append 163 of 2500 OK
# Edo 0 append 164 of 2500 OK
# Edo 0 append 165 of 2500 OK
# Edo 0 append 166 of 2500 OK
# Edo 0 append 167 of 2500 OK
# Edo 0 append 168 of 2500 OK
# Edo 0 append 169 of 2500 OK
# Edo 0 append 170 of 2500 OK
# Edo 0 append 171 of 2500 OK
# Edo 0 append 172 of 2500 OK
# Edo 0 append 173 of 2500 OK
# Edo 0 append 174 of 2500 OK
# Edo 0 append 175 of 2500 OK
# Edo 0 append 176 of 2500 OK
# Edo 0 append 177 of 2500 OK
# Edo 0 append 178 of 2500 OK
# Edo 0 append 179 of 2500 OK
# Edo 0 append 180 of 2500 OK
# Edo 0 append 181 of 2500 OK
# Edo 0 append 182 of 2500 OK
# Edo 0 append 183 of 2500 OK
# Edo 0 append 184 of 2500 OK
# Edo 0 append 185 of 2500 OK
# Edo 0 append 186 of 2500 OK
# Edo 0 append 187 of 2500 OK
# Edo 0 append 188 of 2500 OK
# Edo 0 append 189 of 2500 OK
# Edo 0 append 190 of 2500 OK
# Edo 0 append 191 of 2500 OK
# Edo 0 append 192 of 2500 OK
# Edo 0 append 193 of 2500 OK
# Edo 0 append 194 of 2500 OK
# Edo 0 append 195 of 2500 OK
# Edo 0 append 196 of 2500 OK
# Edo 0 append 197 of 2500 OK
# Edo 0 append 198 of 2500 OK
# Edo 0 append 199 of 2500 OK
# Edo 0 append 200 of 2500 OK
# Edo 0 append 201 of 2500 OK
# Edo 0 append 202 of 2500 OK
# Edo 0 append 203 of 2500 OK
# Edo 0 append 204 of 2500 OK
# Edo 0 append 205 of 2500 OK
# Edo 0 append 206 of 2500 OK
# Edo 0 append 207 of 2500 OK
# Edo 0 append 208 of 2500 OK
# Edo 0 append 209 of 2500 OK
# Edo 0 append 210 of 2500 OK
# Edo 0 append 211 of 2500 OK
# Edo 0 append 212 of 2500 OK
# Edo 0 append 213 of 2500 OK
# Edo 0 append 214 of 2500 OK
# Edo 0 append 215 of 2500 OK
# Edo 0 append 216 of 2500 OK
# Edo 0 append 217 of 2500 OK
# Edo 0 append 218 of 2500 OK
# Edo 0 append 219 of 2500 OK
# Edo 0 append 220 of 2500 OK
# Edo 0 append 221 of 2500 OK
# Edo 0 append 222 of 2500 OK
# Edo 0 append 223 of 2500 OK
# Edo 0 append 224 of 2500 OK
# Edo 0 append 225 of 2500 OK
# Edo 0 append 226 of 2500 OK
# Edo 0 append 227 of 2500 OK
# Edo 0 append 228 of 2500 OK
# Edo 0 append 229 of 2500 OK
# Edo 0 append 230 of 2500 OK
# Edo 0 append 231 of 2500 OK
# Edo 0 append 232 of 2500 OK
# Edo 0 append 233 of 2500 OK
# Edo 0 append 234 of 2500 OK
# Edo 0 append 235 of 2500 OK
# Edo 0 append 236 of 2500 OK
# Edo 0 append 237 of 2500 OK
# Edo 0 append 238 of 2500 OK
# Edo 0 append 239 of 2500 OK
# Edo 0 append 240 of 2500 OK
# Edo 0 append 241 of 2500 OK
# Edo 0 append 242 of 2500 OK
# Edo 0 append 243 of 2500 OK
# Edo 0 append 244 of 2500 OK
# Edo 0 append 245 of 2500 OK
# Edo 0 append 246 of 2500 OK
# Edo 0 append 247 of 2500 OK
# Edo 0 append 248 of 2500 OK
# Edo 0 append 249 of 2500 OK
# Edo 0 append 250 of 2500 OK
# Edo 0 append 251 of 2500 OK
# Edo 0 append 252 of 2500 OK
# Edo 0 append 253 of 2500 OK
# Edo 0 append 254 of 2500 OK
# Edo 0 append 255 of 2500 OK
# Edo 0 append 256 of 2500 OK
# Edo 0 append 257 of 2500 OK
# Edo 0 append 258 of 2500 OK
# Edo 0 append 259 of 2500 OK
# Edo 0 append 260 of 2500 OK
# Edo 0 append 261 of 2500 OK
# Edo 0 append 262 of 2500 OK
# Edo 0 append 263 of 2500 OK
# Edo 0 append 264 of 2500 OK
# Edo 0 append 265 of 2500 OK
# Edo 0 append 266 of 2500 OK
# Edo 0 append 267 of 2500 OK
# Edo 0 append 268 of 2500 OK
# Edo 0 append 269 of 2500 OK
# Edo 0 append 270 of 2500 OK
# Edo 0 append 271 of 2500 OK
# Edo 0 append 272 of 2500 OK
# Edo 0 append 273 of 2500 OK
# Edo 0 append 274 of 2500 OK
# Edo 0 append 275 of 2500 OK
# Edo 0 append 276 of 2500 OK
# Edo 0 append 277 of 2500 OK
# Edo 0 append 278 of 2500 OK
# Edo 0 append 279 of 2500 OK
# Edo 0 append 280 of 2500 OK
# Edo 0 append 281 of 2500 OK
# Edo 0 append 282 of 2500 OK
# Edo 0 append 283 of 2500 OK
# Edo 0 append 284 of 2500 OK
# Edo 0 append 285 of 2500 OK
# Edo 0 append 286 of 2500 OK
# Edo 0 append 287 of 2500 OK
# Edo 0 append 288 of 2500 OK
# Edo 0 append 289 of 2500 OK
# Edo 0 append 290 of 2500 OK
# Edo 0 append 291 of 2500 OK
# Edo 0 append 292 of 2500 OK
# Edo 0 append 293 of 2500 OK
# Edo 0 append 294 of 2500 OK
# Edo 0 append 295 of 2500 OK
# Edo 0 append 296 of 2500 OK
# Edo 0 append 297 of 2500 OK
# Edo 0 append 298 of 2500 OK
# Edo 0 append 299 of 2500 OK
# Edo 0 append 300 of 2500 OK
# Edo 0 append 301 of 2500 OK
# Edo 0 append 302 of 2500 OK
# Edo 0 append 303 of 2500 OK
# Edo 0 append 304 of 2500 OK
# Edo 0 append 305 of 2500 OK
# Edo 0 append 306 of 2500 OK
# Edo 0 append 307 of 2500 OK
# Edo 0 append 308 of 2500 OK
# Edo 0 append 309 of 2500 OK
# Edo 0 append 310 of 2500 OK
# Edo 0 append 311 of 2500 OK
# Edo 0 append 312 of 2500 OK
# Edo 0 append 313 of 2500 OK
# Edo 0 append 314 of 2500 OK
# Edo 0 append 315 of 2500 OK
# Edo 0 append 316 of 2500 OK
# Edo 0 append 317 of 2500 OK
# Edo 0 append 318 of 2500 OK
# Edo 0 append 319 of 2500 OK
# Edo 0 append 320 of 2500 OK
# Edo 0 append 321 of 2500 OK
# Edo 0 append 322 of 2500 OK
# Edo 0 append 323 of 2500 OK
# Edo 0 append 324 of 2500 OK
# Edo 0 append 325 of 2500 OK
# Edo 0 append 326 of 2500 OK
# Edo 0 append 327 of 2500 OK
# Edo 0 append 328 of 2500 OK
# Edo 0 append 329 of 2500 OK
# Edo 0 append 330 of 2500 OK
# Edo 0 append 331 of 2500 OK
# Edo 0 append 332 of 2500 OK
# Edo 0 append 333 of 2500 OK
# Edo 0 append 334 of 2500 OK
# Edo 0 append 335 of 2500 OK
# Edo 0 append 336 of 2500 OK
# Edo 0 append 337 of 2500 OK
# Edo 0 append 338 of 2500 OK
# Edo 0 append 339 of 2500 OK
# Edo 0 append 340 of 2500 OK
# Edo 0 append 341 of 2500 OK
# Edo 0 append 342 of 2500 OK
# Edo 0 append 343 of 2500 OK
# Edo 0 append 344 of 2500 OK
# Edo 0 append 345 of 2500 OK
# Edo 0 append 346 of 2500 OK
# Edo 0 append 347 of 2500 OK
# Edo 0 append 348 of 2500 OK
# Edo 0 append 349 of 2500 OK
# Edo 0 append 350 of 2500 OK
# Edo 0 append 351 of 2500 OK
# Edo 0 append 352 of 2500 OK
# Edo 0 append 353 of 2500 OK
# Edo 0 append 354 of 2500 OK
# Edo 0 append 355 of 2500 OK
# Edo 0 append 356 of 2500 OK
# Edo 0 append 357 of 2500 OK
# Edo 0 append 358 of 2500 OK
# Edo 0 append 359 of 2500 OK
# Edo 0 append 360 of 2500 OK
# Edo 0 append 361 of 2500 OK
# Edo 0 append 362 of 2500 OK
# Edo 0 append 363 of 2500 OK
# Edo 0 append 364 of 2500 OK
# Edo 0 append 365 of 2500 OK
# Edo 0 append 366 of 2500 OK
# Edo 0 append 367 of 2500 OK
# Edo 0 append 368 of 2500 OK
# Edo 0 append 369 of 2500 OK
# Edo 0 append 370 of 2500 OK
# Edo 0 append 371 of 2500 OK
# Edo 0 append 372 of 2500 OK
# Edo 0 append 373 of 2500 OK
# Edo 0 append 374 of 2500 OK
# Edo 0 append 375 of 2500 OK
# Edo 0 append 376 of 2500 OK
# Edo 0 append 377 of 2500 OK
# Edo 0 append 378 of 2500 OK
# Edo 0 append 379 of 2500 OK
# Edo 0 append 380 of 2500 OK
# Edo 0 append 381 of 2500 OK
# Edo 0 append 382 of 2500 OK
# Edo 0 append 383 of 2500 OK
# Edo 0 append 384 of 2500 OK
# Edo 0 append 385 of 2500 OK
# Edo 0 append 386 of 2500 OK
# Edo 0 append 387 of 2500 OK
# Edo 0 append 388 of 2500 OK
# Edo 0 append 389 of 2500 OK
# Edo 0 append 390 of 2500 OK
# Edo 0 append 391 of 2500 OK
# Edo 0 append 392 of 2500 OK
# Edo 0 append 393 of 2500 OK
# Edo 0 append 394 of 2500 OK
# Edo 0 append 395 of 2500 OK
# Edo 0 append 396 of 2500 OK
# Edo 0 append 397 of 2500 OK
# Edo 0 append 398 of 2500 OK
# Edo 0 append 399 of 2500 OK
# Edo 0 append 400 of 2500 OK
# Edo 0 append 401 of 2500 OK
# Edo 0 append 402 of 2500 OK
# Edo 0 append 403 of 2500 OK
# Edo 0 append 404 of 2500 OK
# Edo 0 append 405 of 2500 OK
# Edo 0 append 406 of 2500 OK
# Edo 0 append 407 of 2500 OK
# Edo 0 append 408 of 2500 OK
# Edo 0 append 409 of 2500 OK
# Edo 0 append 410 of 2500 OK
# Edo 0 append 411 of 2500 OK
# Edo 0 append 412 of 2500 OK
# Edo 0 append 413 of 2500 OK
# Edo 0 append 414 of 2500 OK
# Edo 0 append 415 of 2500 OK
# Edo 0 append 416 of 2500 OK
# Edo 0 append 417 of 2500 OK
# Edo 0 append 418 of 2500 OK
# Edo 0 append 419 of 2500 OK
# Edo 0 append 420 of 2500 OK
# Edo 0 append 421 of 2500 OK
# Edo 0 append 422 of 2500 OK
# Edo 0 append 423 of 2500 OK
# Edo 0 append 424 of 2500 OK
# Edo 0 append 425 of 2500 OK
# Edo 0 append 426 of 2500 OK
# Edo 0 append 427 of 2500 OK
# Edo 0 append 428 of 2500 OK
# Edo 0 append 429 of 2500 OK
# Edo 0 append 430 of 2500 OK
# Edo 0 append 431 of 2500 OK
# Edo 0 append 432 of 2500 OK
# Edo 0 append 433 of 2500 OK
# Edo 0 append 434 of 2500 OK
# Edo 0 append 435 of 2500 OK
# Edo 0 append 436 of 2500 OK
# Edo 0 append 437 of 2500 OK
# Edo 0 append 438 of 2500 OK
# Edo 0 append 439 of 2500 OK
# Edo 0 append 440 of 2500 OK
# Edo 0 append 441 of 2500 OK
# Edo 0 append 442 of 2500 OK
# Edo 0 append 443 of 2500 OK
# Edo 0 append 444 of 2500 OK
# Edo 0 append 445 of 2500 OK
# Edo 0 append 446 of 2500 OK
# Edo 0 append 447 of 2500 OK
# Edo 0 append 448 of 2500 OK
# Edo 0 append 449 of 2500 OK
# Edo 0 append 450 of 2500 OK
# Edo 0 append 451 of 2500 OK
# Edo 0 append 452 of 2500 OK
# Edo 0 append 453 of 2500 OK
# Edo 0 append 454 of 2500 OK
# Edo 0 append 455 of 2500 OK
# Edo 0 append 456 of 2500 OK
# Edo 0 append 457 of 2500 OK
# Edo 0 append 458 of 2500 OK
# Edo 0 append 459 of 2500 OK
# Edo 0 append 460 of 2500 OK
# Edo 0 append 461 of 2500 OK
# Edo 0 append 462 of 2500 OK
# Edo 0 append 463 of 2500 OK
# Edo 0 append 464 of 2500 OK
# Edo 0 append 465 of 2500 OK
# Edo 0 append 466 of 2500 OK
# Edo 0 append 467 of 2500 OK
# Edo 0 append 468 of 2500 OK
# Edo 0 append 469 of 2500 OK
# Edo 0 append 470 of 2500 OK
# Edo 0 append 471 of 2500 OK
# Edo 0 append 472 of 2500 OK
# Edo 0 append 473 of 2500 OK
# Edo 0 append 474 of 2500 OK
# Edo 0 append 475 of 2500 OK
# Edo 0 append 476 of 2500 OK
# Edo 0 append 477 of 2500 OK
# Edo 0 append 478 of 2500 OK
# Edo 0 append 479 of 2500 OK
# Edo 0 append 480 of 2500 OK
# Edo 0 append 481 of 2500 OK
# Edo 0 append 482 of 2500 OK
# Edo 0 append 483 of 2500 OK
# Edo 0 append 484 of 2500 OK
# Edo 0 append 485 of 2500 OK
# Edo 0 append 486 of 2500 OK
# Edo 0 append 487 of 2500 OK
# Edo 0 append 488 of 2500 OK
# Edo 0 append 489 of 2500 OK
# Edo 0 append 490 of 2500 OK
# Edo 0 append 491 of 2500 OK
# Edo 0 append 492 of 2500 OK
# Edo 0 append 493 of 2500 OK
# Edo 0 append 494 of 2500 OK
# Edo 0 append 495 of 2500 OK
# Edo 0 append 496 of 2500 OK
# Edo 0 append 497 of 2500 OK
# Edo 0 append 498 of 2500 OK
# Edo 0 append 499 of 2500 OK
# Edo 0 append 500 of 2500 OK
# Edo 0 append 501 of 2500 OK
# Edo 0 append 502 of 2500 OK
# Edo 0 append 503 of 2500 OK
# Edo 0 append 504 of 2500 OK
# Edo 0 append 505 of 2500 OK
# Edo 0 append 506 of 2500 OK
# Edo 0 append 507 of 2500 OK
# Edo 0 append 508 of 2500 OK
# Edo 0 append 509 of 2500 OK
# Edo 0 append 510 of 2500 OK
# Edo 0 append 511 of 2500 OK
# Edo 0 append 512 of 2500 OK
# Edo 0 append 513 of 2500 OK
# Edo 0 append 514 of 2500 OK
# Edo 0 append 515 of 2500 OK
# Edo 0 append 516 of 2500 OK
# Edo 0 append 517 of 2500 OK
# Edo 0 append 518 of 2500 OK
# Edo 0 append 519 of 2500 OK
# Edo 0 append 520 of 2500 OK
# Edo 0 append 521 of 2500 OK
# Edo 0 append 522 of 2500 OK
# Edo 0 append 523 of 2500 OK
# Edo 0 append 524 of 2500 OK
# Edo 0 append 525 of 2500 OK
# Edo 0 append 526 of 2500 OK
# Edo 0 append 527 of 2500 OK
# Edo 0 append 528 of 2500 OK
# Edo 0 append 529 of 2500 OK
# Edo 0 append 530 of 2500 OK
# Edo 0 append 531 of 2500 OK
# Edo 0 append 532 of 2500 OK
# Edo 0 append 533 of 2500 OK
# Edo 0 append 534 of 2500 OK
# Edo 0 append 535 of 2500 OK
# Edo 0 append 536 of 2500 OK
# Edo 0 append 537 of 2500 OK
# Edo 0 append 538 of 2500 OK
# Edo 0 append 539 of 2500 OK
# Edo 0 append 540 of 2500 OK
# Edo 0 append 541 of 2500 OK
# Edo 0 append 542 of 2500 OK
# Edo 0 append 543 of 2500 OK
# Edo 0 append 544 of 2500 OK
# Edo 0 append 545 of 2500 OK
# Edo 0 append 546 of 2500 OK
# Edo 0 append 547 of 2500 OK
# Edo 0 append 548 of 2500 OK
# Edo 0 append 549 of 2500 OK
# Edo 0 append 550 of 2500 OK
# Edo 0 append 551 of 2500 OK
# Edo 0 append 552 of 2500 OK
# Edo 0 append 553 of 2500 OK
# Edo 0 append 554 of 2500 OK
# Edo 0 append 555 of 2500 OK
# Edo 0 append 556 of 2500 OK
# Edo 0 append 557 of 2500 OK
# Edo 0 append 558 of 2500 OK
# Edo 0 append 559 of 2500 OK
# Edo 0 append 560 of 2500 OK
# Edo 0 append 561 of 2500 OK
# Edo 0 append 562 of 2500 OK
# Edo 0 append 563 of 2500 OK
# Edo 0 append 564 of 2500 OK
# Edo 0 append 565 of 2500 OK
# Edo 0 append 566 of 2500 OK
# Edo 0 append 567 of 2500 OK
# Edo 0 append 568 of 2500 OK
# Edo 0 append 569 of 2500 OK
# Edo 0 append 570 of 2500 OK
# Edo 0 append 571 of 2500 OK
# Edo 0 append 572 of 2500 OK
# Edo 0 append 573 of 2500 OK
# Edo 0 append 574 of 2500 OK
# Edo 0 append 575 of 2500 OK
# Edo 0 append 576 of 2500 OK
# Edo 0 append 577 of 2500 OK
# Edo 0 append 578 of 2500 OK
# Edo 0 append 579 of 2500 OK
# Edo 0 append 580 of 2500 OK
# Edo 0 append 581 of 2500 OK
# Edo 0 append 582 of 2500 OK
# Edo 0 append 583 of 2500 OK
# Edo 0 append 584 of 2500 OK
# Edo 0 append 585 of 2500 OK
# Edo 0 append 586 of 2500 OK
# Edo 0 append 587 of 2500 OK
# Edo 0 append 588 of 2500 OK
# Edo 0 append 589 of 2500 OK
# Edo 0 append 590 of 2500 OK
# Edo 0 append 591 of 2500 OK
# Edo 0 append 592 of 2500 OK
# Edo 0 append 593 of 2500 OK
# Edo 0 append 594 of 2500 OK
# Edo 0 append 595 of 2500 OK
# Edo 0 append 596 of 2500 OK
# Edo 0 append 597 of 2500 OK
# Edo 0 append 598 of 2500 OK
# Edo 0 append 599 of 2500 OK
# Edo 0 append 600 of 2500 OK
# Edo 0 append 601 of 2500 OK
# Edo 0 append 602 of 2500 OK
# Edo 0 append 603 of 2500 OK
# Edo 0 append 604 of 2500 OK
# Edo 0 append 605 of 2500 OK
# Edo 0 append 606 of 2500 OK
# Edo 0 append 607 of 2500 OK
# Edo 0 append 608 of 2500 OK
# Edo 0 append 609 of 2500 OK
# Edo 0 append 610 of 2500 OK
# Edo 0 append 611 of 2500 OK
# Edo 0 append 612 of 2500 OK
# Edo 0 append 613 of 2500 OK
# Edo 0 append 614 of 2500 OK
# Edo 0 append 615 of 2500 OK
# Edo 0 append 616 of 2500 OK
# Edo 0 append 617 of 2500 OK
# Edo 0 append 618 of 2500 OK
# Edo 0 append 619 of 2500 OK
# Edo 0 append 620 of 2500 OK
# Edo 0 append 621 of 2500 OK
# Edo 0 append 622 of 2500 OK
# Edo 0 append 623 of 2500 OK
# Edo 0 append 624 of 2500 OK
# Edo 0 append 625 of 2500 OK
# Edo 0 append 626 of 2500 OK
# Edo 0 append 627 of 2500 OK
# Edo 0 append 628 of 2500 OK
# Edo 0 append 629 of 2500 OK
# Edo 0 append 630 of 2500 OK
# Edo 0 append 631 of 2500 OK
# Edo 0 append 632 of 2500 OK
# Edo 0 append 633 of 2500 OK
# Edo 0 append 634 of 2500 OK
# Edo 0 append 635 of 2500 OK
# Edo 0 append 636 of 2500 OK
# Edo 0 append 637 of 2500 OK
# Edo 0 append 638 of 2500 OK
# Edo 0 append 639 of 2500 OK
# Edo 0 append 640 of 2500 OK
# Edo 0 append 641 of 2500 OK
# Edo 0 append 642 of 2500 OK
# Edo 0 append 643 of 2500 OK
# Edo 0 append 644 of 2500 OK
# Edo 0 append 645 of 2500 OK
# Edo 0 append 646 of 2500 OK
# Edo 0 append 647 of 2500 OK
# Edo 0 append 648 of 2500 OK
# Edo 0 append 649 of 2500 OK
# Edo 0 append 650 of 2500 OK
# Edo 0 append 651 of 2500 OK
# Edo 0 append 652 of 2500 OK
# Edo 0 append 653 of 2500 OK
# Edo 0 append 654 of 2500 OK
# Edo 0 append 655 of 2500 OK
# Edo 0 append 656 of 2500 OK
# Edo 0 append 657 of 2500 OK
# Edo 0 append 658 of 2500 OK
# Edo 0 append 659 of 2500 OK
# Edo 0 append 660 of 2500 OK
# Edo 0 append 661 of 2500 OK
# Edo 0 append 662 of 2500 OK
# Edo 0 append 663 of 2500 OK
# Edo 0 append 664 of 2500 OK
# Edo 0 append 665 of 2500 OK
# Edo 0 append 666 of 2500 OK
# Edo 0 append 667 of 2500 OK
# Edo 0 append 668 of 2500 OK
# Edo 0 append 669 of 2500 OK
# Edo 0 append 670 of 2500 OK
# Edo 0 append 671 of 2500 OK
# Edo 0 append 672 of 2500 OK
# Edo 0 append 673 of 2500 OK
# Edo 0 append 674 of 2500 OK
# Edo 0 append 675 of 2500 OK
# Edo 0 append 676 of 2500 OK
# Edo 0 append 677 of 2500 OK
# Edo 0 append 678 of 2500 OK
# Edo 0 append 679 of 2500 OK
# Edo 0 append 680 of 2500 OK
# Edo 0 append 681 of 2500 OK
# Edo 0 append 682 of 2500 OK
# Edo 0 append 683 of 2500 OK
# Edo 0 append 684 of 2500 OK
# Edo 0 append 685 of 2500 OK
# Edo 0 append 686 of 2500 OK
# Edo 0 append 687 of 2500 OK
# Edo 0 append 688 of 2500 OK
# Edo 0 append 689 of 2500 OK
# Edo 0 append 690 of 2500 OK
# Edo 0 append 691 of 2500 OK
# Edo 0 append 692 of 2500 OK
# Edo 0 append 693 of 2500 OK
# Edo 0 append 694 of 2500 OK
# Edo 0 append 695 of 2500 OK
# Edo 0 append 696 of 2500 OK
# Edo 0 append 697 of 2500 OK
# Edo 0 append 698 of 2500 OK
# Edo 0 append 699 of 2500 OK
# Edo 0 append 700 of 2500 OK
# Edo 0 append 701 of 2500 OK
# Edo 0 append 702 of 2500 OK
# Edo 0 append 703 of 2500 OK
# Edo 0 append 704 of 2500 OK
# Edo 0 append 705 of 2500 OK
# Edo 0 append 706 of 2500 OK
# Edo 0 append 707 of 2500 OK
# Edo 0 append 708 of 2500 OK
# Edo 0 append 709 of 2500 OK
# Edo 0 append 710 of 2500 OK
# Edo 0 append 711 of 2500 OK
# Edo 0 append 712 of 2500 OK
# Edo 0 append 713 of 2500 OK
# Edo 0 append 714 of 2500 OK
# Edo 0 append 715 of 2500 OK
# Edo 0 append 716 of 2500 OK
# Edo 0 append 717 of 2500 OK
# Edo 0 append 718 of 2500 OK
# Edo 0 append 719 of 2500 OK
# Edo 0 append 720 of 2500 OK
# Edo 0 append 721 of 2500 OK
# Edo 0 append 722 of 2500 OK
# Edo 0 append 723 of 2500 OK
# Edo 0 append 724 of 2500 OK
# Edo 0 append 725 of 2500 OK
# Edo 0 append 726 of 2500 OK
# Edo 0 append 727 of 2500 OK
# Edo 0 append 728 of 2500 OK
# Edo 0 append 729 of 2500 OK
# Edo 0 append 730 of 2500 OK
# Edo 0 append 731 of 2500 OK
# Edo 0 append 732 of 2500 OK
# Edo 0 append 733 of 2500 OK
# Edo 0 append 734 of 2500 OK
# Edo 0 append 735 of 2500 OK
# Edo 0 append 736 of 2500 OK
# Edo 0 append 737 of 2500 OK
# Edo 0 append 738 of 2500 OK
# Edo 0 append 739 of 2500 OK
# Edo 0 append 740 of 2500 OK
# Edo 0 append 741 of 2500 OK
# Edo 0 append 742 of 2500 OK
# Edo 0 append 743 of 2500 OK
# Edo 0 append 744 of 2500 OK
# Edo 0 append 745 of 2500 OK
# Edo 0 append 746 of 2500 OK
# Edo 0 append 747 of 2500 OK
# Edo 0 append 748 of 2500 OK
# Edo 0 append 749 of 2500 OK
# Edo 0 append 750 of 2500 OK
# Edo 0 append 751 of 2500 OK
# Edo 0 append 752 of 2500 OK
# Edo 0 append 753 of 2500 OK
# Edo 0 append 754 of 2500 OK
# Edo 0 append 755 of 2500 OK
# Edo 0 append 756 of 2500 OK
# Edo 0 append 757 of 2500 OK
# Edo 0 append 758 of 2500 OK
# Edo 0 append 759 of 2500 OK
# Edo 0 append 760 of 2500 OK
# Edo 0 append 761 of 2500 OK
# Edo 0 append 762 of 2500 OK
# Edo 0 append 763 of 2500 OK
# Edo 0 append 764 of 2500 OK
# Edo 0 append 765 of 2500 OK
# Edo 0 append 766 of 2500 OK
# Edo 0 append 767 of 2500 OK
# Edo 0 append 768 of 2500 OK
# Edo 0 append 769 of 2500 OK
# Edo 0 append 770 of 2500 OK
# Edo 0 append 771 of 2500 OK
# Edo 0 append 772 of 2500 OK
# Edo 0 append 773 of 2500 OK
# Edo 0 append 774 of 2500 OK
# Edo 0 append 775 of 2500 OK
# Edo 0 append 776 of 2500 OK
# Edo 0 append 777 of 2500 OK
# Edo 0 append 778 of 2500 OK
# Edo 0 append 779 of 2500 OK
# Edo 0 append 780 of 2500 OK
# Edo 0 append 781 of 2500 OK
# Edo 0 append 782 of 2500 OK
# Edo 0 append 783 of 2500 OK
# Edo 0 append 784 of 2500 OK
# Edo 0 append 785 of 2500 OK
# Edo 0 append 786 of 2500 OK
# Edo 0 append 787 of 2500 OK
# Edo 0 append 788 of 2500 OK
# Edo 0 append 789 of 2500 OK
# Edo 0 append 790 of 2500 OK
# Edo 0 append 791 of 2500 OK
# Edo 0 append 792 of 2500 OK
# Edo 0 append 793 of 2500 OK
# Edo 0 append 794 of 2500 OK
# Edo 0 append 795 of 2500 OK
# Edo 0 append 796 of 2500 OK
# Edo 0 append 797 of 2500 OK
# Edo 0 append 798 of 2500 OK
# Edo 0 append 799 of 2500 OK
# Edo 0 append 800 of 2500 OK
# Edo 0 append 801 of 2500 OK
# Edo 0 append 802 of 2500 OK
# Edo 0 append 803 of 2500 OK
# Edo 0 append 804 of 2500 OK
# Edo 0 append 805 of 2500 OK
# Edo 0 append 806 of 2500 OK
# Edo 0 append 807 of 2500 OK
# Edo 0 append 808 of 2500 OK
# Edo 0 append 809 of 2500 OK
# Edo 0 append 810 of 2500 OK
# Edo 0 append 811 of 2500 OK
# Edo 0 append 812 of 2500 OK
# Edo 0 append 813 of 2500 OK
# Edo 0 append 814 of 2500 OK
# Edo 0 append 815 of 2500 OK
# Edo 0 append 816 of 2500 OK
# Edo 0 append 817 of 2500 OK
# Edo 0 append 818 of 2500 OK
# Edo 0 append 819 of 2500 OK
# Edo 0 append 820 of 2500 OK
# Edo 0 append 821 of 2500 OK
# Edo 0 append 822 of 2500 OK
# Edo 0 append 823 of 2500 OK
# Edo 0 append 824 of 2500 OK
# Edo 0 append 825 of 2500 OK
# Edo 0 append 826 of 2500 OK
# Edo 0 append 827 of 2500 OK
# Edo 0 append 828 of 2500 OK
# Edo 0 append 829 of 2500 OK
# Edo 0 append 830 of 2500 OK
# Edo 0 append 831 of 2500 OK
# Edo 0 append 832 of 2500 OK
# Edo 0 append 833 of 2500 OK
# Edo 0 append 834 of 2500 OK
# Edo 0 append 835 of 2500 OK
# Edo 0 append 836 of 2500 OK
# Edo 0 append 837 of 2500 OK
# Edo 0 append 838 of 2500 OK
# Edo 0 append 839 of 2500 OK
# Edo 0 append 840 of 2500 OK
# Edo 0 append 841 of 2500 OK
# Edo 0 append 842 of 2500 OK
# Edo 0 append 843 of 2500 OK
# Edo 0 append 844 of 2500 OK
# Edo 0 append 845 of 2500 OK
# Edo 0 append 846 of 2500 OK
# Edo 0 append 847 of 2500 OK
# Edo 0 append 848 of 2500 OK
# Edo 0 append 849 of 2500 OK
# Edo 0 append 850 of 2500 OK
# Edo 0 append 851 of 2500 OK
# Edo 0 append 852 of 2500 OK
# Edo 0 append 853 of 2500 OK
# Edo 0 append 854 of 2500 OK
# Edo 0 append 855 of 2500 OK
# Edo 0 append 856 of 2500 OK
# Edo 0 append 857 of 2500 OK
# Edo 0 append 858 of 2500 OK
# Edo 0 append 859 of 2500 OK
# Edo 0 append 860 of 2500 OK
# Edo 0 append 861 of 2500 OK
# Edo 0 append 862 of 2500 OK
# Edo 0 append 863 of 2500 OK
# Edo 0 append 864 of 2500 OK
# Edo 0 append 865 of 2500 OK
# Edo 0 append 866 of 2500 OK
# Edo 0 append 867 of 2500 OK
# Edo 0 append 868 of 2500 OK
# Edo 0 append 869 of 2500 OK
# Edo 0 append 870 of 2500 OK
# Edo 0 append 871 of 2500 OK
# Edo 0 append 872 of 2500 OK
# Edo 0 append 873 of 2500 OK
# Edo 0 append 874 of 2500 OK
# Edo 0 append 875 of 2500 OK
# Edo 0 append 876 of 2500 OK
# Edo 0 append 877 of 2500 OK
# Edo 0 append 878 of 2500 OK
# Edo 0 append 879 of 2500 OK
# Edo 0 append 880 of 2500 OK
# Edo 0 append 881 of 2500 OK
# Edo 0 append 882 of 2500 OK
# Edo 0 append 883 of 2500 OK
# Edo 0 append 884 of 2500 OK
# Edo 0 append 885 of 2500 OK
# Edo 0 append 886 of 2500 OK
# Edo 0 append 887 of 2500 OK
# Edo 0 append 888 of 2500 OK
# Edo 0 append 889 of 2500 OK
# Edo 0 append 890 of 2500 OK
# Edo 0 append 891 of 2500 OK
# Edo 0 append 892 of 2500 OK
# Edo 0 append 893 of 2500 OK
# Edo 0 append 894 of 2500 OK
# Edo 0 append 895 of 2500 OK
# Edo 0 append 896 of 2500 OK
# Edo 0 append 897 of 2500 OK
# Edo 0 append 898 of 2500 OK
# Edo 0 append 899 of 2500 OK
# Edo 0 append 900 of 2500 OK
# Edo 0 append 901 of 2500 OK
# Edo 0 append 902 of 2500 OK
# Edo 0 append 903 of 2500 OK
# Edo 0 append 904 of 2500 OK
# Edo 0 append 905 of 2500 OK
# Edo 0 append 906 of 2500 OK
# Edo 0 append 907 of 2500 OK
# Edo 0 append 908 of 2500 OK
# Edo 0 append 909 of 2500 OK
# Edo 0 append 910 of 2500 OK
# Edo 0 append 911 of 2500 OK
# Edo 0 append 912 of 2500 OK
# Edo 0 append 913 of 2500 OK
# Edo 0 append 914 of 2500 OK
# Edo 0 append 915 of 2500 OK
# Edo 0 append 916 of 2500 OK
# Edo 0 append 917 of 2500 OK
# Edo 0 append 918 of 2500 OK
# Edo 0 append 919 of 2500 OK
# Edo 0 append 920 of 2500 OK
# Edo 0 append 921 of 2500 OK
# Edo 0 append 922 of 2500 OK
# Edo 0 append 923 of 2500 OK
# Edo 0 append 924 of 2500 OK
# Edo 0 append 925 of 2500 OK
# Edo 0 append 926 of 2500 OK
# Edo 0 append 927 of 2500 OK
# Edo 0 append 928 of 2500 OK
# Edo 0 append 929 of 2500 OK
# Edo 0 append 930 of 2500 OK
# Edo 0 append 931 of 2500 OK
# Edo 0 append 932 of 2500 OK
# Edo 0 append 933 of 2500 OK
# Edo 0 append 934 of 2500 OK
# Edo 0 append 935 of 2500 OK
# Edo 0 append 936 of 2500 OK
# Edo 0 append 937 of 2500 OK
# Edo 0 append 938 of 2500 OK
# Edo 0 append 939 of 2500 OK
# Edo 0 append 940 of 2500 OK
# Edo 0 append 941 of 2500 OK
# Edo 0 append 942 of 2500 OK
# Edo 0 append 943 of 2500 OK
# Edo 0 append 944 of 2500 OK
# Edo 0 append 945 of 2500 OK
# Edo 0 append 946 of 2500 OK
# Edo 0 append 947 of 2500 OK
# Edo 0 append 948 of 2500 OK
# Edo 0 append 949 of 2500 OK
# Edo 0 append 950 of 2500 OK
# Edo 0 append 951 of 2500 OK
# Edo 0 append 952 of 2500 OK
# Edo 0 append 953 of 2500 OK
# Edo 0 append 954 of 2500 OK
# Edo 0 append 955 of 2500 OK
# Edo 0 append 956 of 2500 OK
# Edo 0 append 957 of 2500 OK
# Edo 0 append 958 of 2500 OK
# Edo 0 append 959 of 2500 OK
# Edo 0 append 960 of 2500 OK
# Edo 0 append 961 of 2500 OK
# Edo 0 append 962 of 2500 OK
# Edo 0 append 963 of 2500 OK
# Edo 0 append 964 of 2500 OK
# Edo 0 append 965 of 2500 OK
# Edo 0 append 966 of 2500 OK
# Edo 0 append 967 of 2500 OK
# Edo 0 append 968 of 2500 OK
# Edo 0 append 969 of 2500 OK
# Edo 0 append 970 of 2500 OK
# Edo 0 append 971 of 2500 OK
# Edo 0 append 972 of 2500 OK
# Edo 0 append 973 of 2500 OK
# Edo 0 append 974 of 2500 OK
# Edo 0 append 975 of 2500 OK
# Edo 0 append 976 of 2500 OK
# Edo 0 append 977 of 2500 OK
# Edo 0 append 978 of 2500 OK
# Edo 0 append 979 of 2500 OK
# Edo 0 append 980 of 2500 OK
# Edo 0 append 981 of 2500 OK
# Edo 0 append 982 of 2500 OK
# Edo 0 append 983 of 2500 OK
# Edo 0 append 984 of 2500 OK
# Edo 0 append 985 of 2500 OK
# Edo 0 append 986 of 2500 OK
# Edo 0 append 987 of 2500 OK
# Edo 0 append 988 of 2500 OK
# Edo 0 append 989 of 2500 OK
# Edo 0 append 990 of 2500 OK
# Edo 0 append 991 of 2500 OK
# Edo 0 append 992 of 2500 OK
# Edo 0 append 993 of 2500 OK
# Edo 0 append 994 of 2500 OK
# Edo 0 append 995 of 2500 OK
# Edo 0 append 996 of 2500 OK
# Edo 0 append 997 of 2500 OK
# Edo 0 append 998 of 2500 OK
# Edo 0 append 999 of 2500 OK
# Edo 0 append 1000 of 2500 OK
# Edo 0 append 1001 of 2500 OK
# Edo 0 append 1002 of 2500 OK
# Edo 0 append 1003 of 2500 OK
# Edo 0 append 1004 of 2500 OK
# Edo 0 append 1005 of 2500 OK
# Edo 0 append 1006 of 2500 OK
# Edo 0 append 1007 of 2500 OK
# Edo 0 append 1008 of 2500 OK
# Edo 0 append 1009 of 2500 OK
# Edo 0 append 1010 of 2500 OK
# Edo 0 append 1011 of 2500 OK
# Edo 0 append 1012 of 2500 OK
# Edo 0 append 1013 of 2500 OK
# Edo 0 append 1014 of 2500 OK
# Edo 0 append 1015 of 2500 OK
# Edo 0 append 1016 of 2500 OK
# Edo 0 append 1017 of 2500 OK
# Edo 0 append 1018 of 2500 OK
# Edo 0 append 1019 of 2500 OK
# Edo 0 append 1020 of 2500 OK
# Edo 0 append 1021 of 2500 OK
# Edo 0 append 1022 of 2500 OK
# Edo 0 append 1023 of 2500 OK
# Edo 0 append 1024 of 2500 OK
# Edo 0 append 1025 of 2500 OK
# Edo 0 append 1026 of 2500 OK
# Edo 0 append 1027 of 2500 OK
# Edo 0 append 1028 of 2500 OK
# Edo 0 append 1029 of 2500 OK
# Edo 0 append 1030 of 2500 OK
# Edo 0 append 1031 of 2500 OK
# Edo 0 append 1032 of 2500 OK
# Edo 0 append 1033 of 2500 OK
# Edo 0 append 1034 of 2500 OK
# Edo 0 append 1035 of 2500 OK
# Edo 0 append 1036 of 2500 OK
# Edo 0 append 1037 of 2500 OK
# Edo 0 append 1038 of 2500 OK
# Edo 0 append 1039 of 2500 OK
# Edo 0 append 1040 of 2500 OK
# Edo 0 append 1041 of 2500 OK
# Edo 0 append 1042 of 2500 OK
# Edo 0 append 1043 of 2500 OK
# Edo 0 append 1044 of 2500 OK
# Edo 0 append 1045 of 2500 OK
# Edo 0 append 1046 of 2500 OK
# Edo 0 append 1047 of 2500 OK
# Edo 0 append 1048 of 2500 OK
# Edo 0 append 1049 of 2500 OK
# Edo 0 append 1050 of 2500 OK
# Edo 0 append 1051 of 2500 OK
# Edo 0 append 1052 of 2500 OK
# Edo 0 append 1053 of 2500 OK
# Edo 0 append 1054 of 2500 OK
# Edo 0 append 1055 of 2500 OK
# Edo 0 append 1056 of 2500 OK
# Edo 0 append 1057 of 2500 OK
# Edo 0 append 1058 of 2500 OK
# Edo 0 append 1059 of 2500 OK
# Edo 0 append 1060 of 2500 OK
# Edo 0 append 1061 of 2500 OK
# Edo 0 append 1062 of 2500 OK
# Edo 0 append 1063 of 2500 OK
# Edo 0 append 1064 of 2500 OK
# Edo 0 append 1065 of 2500 OK
# Edo 0 append 1066 of 2500 OK
# Edo 0 append 1067 of 2500 OK
# Edo 0 append 1068 of 2500 OK
# Edo 0 append 1069 of 2500 OK
# Edo 0 append 1070 of 2500 OK
# Edo 0 append 1071 of 2500 OK
# Edo 0 append 1072 of 2500 OK
# Edo 0 append 1073 of 2500 OK
# Edo 0 append 1074 of 2500 OK
# Edo 0 append 1075 of 2500 OK
# Edo 0 append 1076 of 2500 OK
# Edo 0 append 1077 of 2500 OK
# Edo 0 append 1078 of 2500 OK
# Edo 0 append 1079 of 2500 OK
# Edo 0 append 1080 of 2500 OK
# Edo 0 append 1081 of 2500 OK
# Edo 0 append 1082 of 2500 OK
# Edo 0 append 1083 of 2500 OK
# Edo 0 append 1084 of 2500 OK
# Edo 0 append 1085 of 2500 OK
# Edo 0 append 1086 of 2500 OK
# Edo 0 append 1087 of 2500 OK
# Edo 0 append 1088 of 2500 OK
# Edo 0 append 1089 of 2500 OK
# Edo 0 append 1090 of 2500 OK
# Edo 0 append 1091 of 2500 OK
# Edo 0 append 1092 of 2500 OK
# Edo 0 append 1093 of 2500 OK
# Edo 0 append 1094 of 2500 OK
# Edo 0 append 1095 of 2500 OK
# Edo 0 append 1096 of 2500 OK
# Edo 0 append 1097 of 2500 OK
# Edo 0 append 1098 of 2500 OK
# Edo 0 append 1099 of 2500 OK
# Edo 0 append 1100 of 2500 OK
# Edo 0 append 1101 of 2500 OK
# Edo 0 append 1102 of 2500 OK
# Edo 0 append 1103 of 2500 OK
# Edo 0 append 1104 of 2500 OK
# Edo 0 append 1105 of 2500 OK
# Edo 0 append 1106 of 2500 OK
# Edo 0 append 1107 of 2500 OK
# Edo 0 append 1108 of 2500 OK
# Edo 0 append 1109 of 2500 OK
# Edo 0 append 1110 of 2500 OK
# Edo 0 append 1111 of 2500 OK
# Edo 0 append 1112 of 2500 OK
# Edo 0 append 1113 of 2500 OK
# Edo 0 append 1114 of 2500 OK
# Edo 0 append 1115 of 2500 OK
# Edo 0 append 1116 of 2500 OK
# Edo 0 append 1117 of 2500 OK
# Edo 0 append 1118 of 2500 OK
# Edo 0 append 1119 of 2500 OK
# Edo 0 append 1120 of 2500 OK
# Edo 0 append 1121 of 2500 OK
# Edo 0 append 1122 of 2500 OK
# Edo 0 append 1123 of 2500 OK
# Edo 0 append 1124 of 2500 OK
# Edo 0 append 1125 of 2500 OK
# Edo 0 append 1126 of 2500 OK
# Edo 0 append 1127 of 2500 OK
# Edo 0 append 1128 of 2500 OK
# Edo 0 append 1129 of 2500 OK
# Edo 0 append 1130 of 2500 OK
# Edo 0 append 1131 of 2500 OK
# Edo 0 append 1132 of 2500 OK
# Edo 0 append 1133 of 2500 OK
# Edo 0 append 1134 of 2500 OK
# Edo 0 append 1135 of 2500 OK
# Edo 0 append 1136 of 2500 OK
# Edo 0 append 1137 of 2500 OK
# Edo 0 append 1138 of 2500 OK
# Edo 0 append 1139 of 2500 OK
# Edo 0 append 1140 of 2500 OK
# Edo 0 append 1141 of 2500 OK
# Edo 0 append 1142 of 2500 OK
# Edo 0 append 1143 of 2500 OK
# Edo 0 append 1144 of 2500 OK
# Edo 0 append 1145 of 2500 OK
# Edo 0 append 1146 of 2500 OK
# Edo 0 append 1147 of 2500 OK
# Edo 0 append 1148 of 2500 OK
# Edo 0 append 1149 of 2500 OK
# Edo 0 append 1150 of 2500 OK
# Edo 0 append 1151 of 2500 OK
# Edo 0 append 1152 of 2500 OK
# Edo 0 append 1153 of 2500 OK
# Edo 0 append 1154 of 2500 OK
# Edo 0 append 1155 of 2500 OK
# Edo 0 append 1156 of 2500 OK
# Edo 0 append 1157 of 2500 OK
# Edo 0 append 1158 of 2500 OK
# Edo 0 append 1159 of 2500 OK
# Edo 0 append 1160 of 2500 OK
# Edo 0 append 1161 of 2500 OK
# Edo 0 append 1162 of 2500 OK
# Edo 0 append 1163 of 2500 OK
# Edo 0 append 1164 of 2500 OK
# Edo 0 append 1165 of 2500 OK
# Edo 0 append 1166 of 2500 OK
# Edo 0 append 1167 of 2500 OK
# Edo 0 append 1168 of 2500 OK
# Edo 0 append 1169 of 2500 OK
# Edo 0 append 1170 of 2500 OK
# Edo 0 append 1171 of 2500 OK
# Edo 0 append 1172 of 2500 OK
# Edo 0 append 1173 of 2500 OK
# Edo 0 append 1174 of 2500 OK
# Edo 0 append 1175 of 2500 OK
# Edo 0 append 1176 of 2500 OK
# Edo 0 append 1177 of 2500 OK
# Edo 0 append 1178 of 2500 OK
# Edo 0 append 1179 of 2500 OK
# Edo 0 append 1180 of 2500 OK
# Edo 0 append 1181 of 2500 OK
# Edo 0 append 1182 of 2500 OK
# Edo 0 append 1183 of 2500 OK
# Edo 0 append 1184 of 2500 OK
# Edo 0 append 1185 of 2500 OK
# Edo 0 append 1186 of 2500 OK
# Edo 0 append 1187 of 2500 OK
# Edo 0 append 1188 of 2500 OK
# Edo 0 append 1189 of 2500 OK
# Edo 0 append 1190 of 2500 OK
# Edo 0 append 1191 of 2500 OK
# Edo 0 append 1192 of 2500 OK
# Edo 0 append 1193 of 2500 OK
# Edo 0 append 1194 of 2500 OK
# Edo 0 append 1195 of 2500 OK
# Edo 0 append 1196 of 2500 OK
# Edo 0 append 1197 of 2500 OK
# Edo 0 append 1198 of 2500 OK
# Edo 0 append 1199 of 2500 OK
# Edo 0 append 1200 of 2500 OK
# Edo 0 append 1201 of 2500 OK
# Edo 0 append 1202 of 2500 OK
# Edo 0 append 1203 of 2500 OK
# Edo 0 append 1204 of 2500 OK
# Edo 0 append 1205 of 2500 OK
# Edo 0 append 1206 of 2500 OK
# Edo 0 append 1207 of 2500 OK
# Edo 0 append 1208 of 2500 OK
# Edo 0 append 1209 of 2500 OK
# Edo 0 append 1210 of 2500 OK
# Edo 0 append 1211 of 2500 OK
# Edo 0 append 1212 of 2500 OK
# Edo 0 append 1213 of 2500 OK
# Edo 0 append 1214 of 2500 OK
# Edo 0 append 1215 of 2500 OK
# Edo 0 append 1216 of 2500 OK
# Edo 0 append 1217 of 2500 OK
# Edo 0 append 1218 of 2500 OK
# Edo 0 append 1219 of 2500 OK
# Edo 0 append 1220 of 2500 OK
# Edo 0 append 1221 of 2500 OK
# Edo 0 append 1222 of 2500 OK
# Edo 0 append 1223 of 2500 OK
# Edo 0 append 1224 of 2500 OK
# Edo 0 append 1225 of 2500 OK
# Edo 0 append 1226 of 2500 OK
# Edo 0 append 1227 of 2500 OK
# Edo 0 append 1228 of 2500 OK
# Edo 0 append 1229 of 2500 OK
# Edo 0 append 1230 of 2500 OK
# Edo 0 append 1231 of 2500 OK
# Edo 0 append 1232 of 2500 OK
# Edo 0 append 1233 of 2500 OK
# Edo 0 append 1234 of 2500 OK
# Edo 0 append 1235 of 2500 OK
# Edo 0 append 1236 of 2500 OK
# Edo 0 append 1237 of 2500 OK
# Edo 0 append 1238 of 2500 OK
# Edo 0 append 1239 of 2500 OK
# Edo 0 append 1240 of 2500 OK
# Edo 0 append 1241 of 2500 OK
# Edo 0 append 1242 of 2500 OK
# Edo 0 append 1243 of 2500 OK
# Edo 0 append 1244 of 2500 OK
# Edo 0 append 1245 of 2500 OK
# Edo 0 append 1246 of 2500 OK
# Edo 0 append 1247 of 2500 OK
# Edo 0 append 1248 of 2500 OK
# Edo 0 append 1249 of 2500 OK
# Edo 0 append 1250 of 2500 OK
# Edo 0 append 1251 of 2500 OK
# Edo 0 append 1252 of 2500 OK
# Edo 0 append 1253 of 2500 OK
# Edo 0 append 1254 of 2500 OK
# Edo 0 append 1255 of 2500 OK
# Edo 0 append 1256 of 2500 OK
# Edo 0 append 1257 of 2500 OK
# Edo 0 append 1258 of 2500 OK
# Edo 0 append 1259 of 2500 OK
# Edo 0 append 1260 of 2500 OK
# Edo 0 append 1261 of 2500 OK
# Edo 0 append 1262 of 2500 OK
# Edo 0 append 1263 of 2500 OK
# Edo 0 append 1264 of 2500 OK
# Edo 0 append 1265 of 2500 OK
# Edo 0 append 1266 of 2500 OK
# Edo 0 append 1267 of 2500 OK
# Edo 0 append 1268 of 2500 OK
# Edo 0 append 1269 of 2500 OK
# Edo 0 append 1270 of 2500 OK
# Edo 0 append 1271 of 2500 OK
# Edo 0 append 1272 of 2500 OK
# Edo 0 append 1273 of 2500 OK
# Edo 0 append 1274 of 2500 OK
# Edo 0 append 1275 of 2500 OK
# Edo 0 append 1276 of 2500 OK
# Edo 0 append 1277 of 2500 OK
# Edo 0 append 1278 of 2500 OK
# Edo 0 append 1279 of 2500 OK
# Edo 0 append 1280 of 2500 OK
# Edo 0 append 1281 of 2500 OK
# Edo 0 append 1282 of 2500 OK
# Edo 0 append 1283 of 2500 OK
# Edo 0 append 1284 of 2500 OK
# Edo 0 append 1285 of 2500 OK
# Edo 0 append 1286 of 2500 OK
# Edo 0 append 1287 of 2500 OK
# Edo 0 append 1288 of 2500 OK
# Edo 0 append 1289 of 2500 OK
# Edo 0 append 1290 of 2500 OK
# Edo 0 append 1291 of 2500 OK
# Edo 0 append 1292 of 2500 OK
# Edo 0 append 1293 of 2500 OK
# Edo 0 append 1294 of 2500 OK
# Edo 0 append 1295 of 2500 OK
# Edo 0 append 1296 of 2500 OK
# Edo 0 append 1297 of 2500 OK
# Edo 0 append 1298 of 2500 OK
# Edo 0 append 1299 of 2500 OK
# Edo 0 append 1300 of 2500 OK
# Edo 0 append 1301 of 2500 OK
# Edo 0 append 1302 of 2500 OK
# Edo 0 append 1303 of 2500 OK
# Edo 0 append 1304 of 2500 OK
# Edo 0 append 1305 of 2500 OK
# Edo 0 append 1306 of 2500 OK
# Edo 0 append 1307 of 2500 OK
# Edo 0 append 1308 of 2500 OK
# Edo 0 append 1309 of 2500 OK
# Edo 0 append 1310 of 2500 OK
# Edo 0 append 1311 of 2500 OK
# Edo 0 append 1312 of 2500 OK
# Edo 0 append 1313 of 2500 OK
# Edo 0 append 1314 of 2500 OK
# Edo 0 append 1315 of 2500 OK
# Edo 0 append 1316 of 2500 OK
# Edo 0 append 1317 of 2500 OK
# Edo 0 append 1318 of 2500 OK
# Edo 0 append 1319 of 2500 OK
# Edo 0 append 1320 of 2500 OK
# Edo 0 append 1321 of 2500 OK
# Edo 0 append 1322 of 2500 OK
# Edo 0 append 1323 of 2500 OK
# Edo 0 append 1324 of 2500 OK
# Edo 0 append 1325 of 2500 OK
# Edo 0 append 1326 of 2500 OK
# Edo 0 append 1327 of 2500 OK
# Edo 0 append 1328 of 2500 OK
# Edo 0 append 1329 of 2500 OK
# Edo 0 append 1330 of 2500 OK
# Edo 0 append 1331 of 2500 OK
# Edo 0 append 1332 of 2500 OK
# Edo 0 append 1333 of 2500 OK
# Edo 0 append 1334 of 2500 OK
# Edo 0 append 1335 of 2500 OK
# Edo 0 append 1336 of 2500 OK
# Edo 0 append 1337 of 2500 OK
# Edo 0 append 1338 of 2500 OK
# Edo 0 append 1339 of 2500 OK
# Edo 0 append 1340 of 2500 OK
# Edo 0 append 1341 of 2500 OK
# Edo 0 append 1342 of 2500 OK
# Edo 0 append 1343 of 2500 OK
# Edo 0 append 1344 of 2500 OK
# Edo 0 append 1345 of 2500 OK
# Edo 0 append 1346 of 2500 OK
# Edo 0 append 1347 of 2500 OK
# Edo 0 append 1348 of 2500 OK
# Edo 0 append 1349 of 2500 OK
# Edo 0 append 1350 of 2500 OK
# Edo 0 append 1351 of 2500 OK
# Edo 0 append 1352 of 2500 OK
# Edo 0 append 1353 of 2500 OK
# Edo 0 append 1354 of 2500 OK
# Edo 0 append 1355 of 2500 OK
# Edo 0 append 1356 of 2500 OK
# Edo 0 append 1357 of 2500 OK
# Edo 0 append 1358 of 2500 OK
# Edo 0 append 1359 of 2500 OK
# Edo 0 append 1360 of 2500 OK
# Edo 0 append 1361 of 2500 OK
# Edo 0 append 1362 of 2500 OK
# Edo 0 append 1363 of 2500 OK
# Edo 0 append 1364 of 2500 OK
# Edo 0 append 1365 of 2500 OK
# Edo 0 append 1366 of 2500 OK
# Edo 0 append 1367 of 2500 OK
# Edo 0 append 1368 of 2500 OK
# Edo 0 append 1369 of 2500 OK
# Edo 0 append 1370 of 2500 OK
# Edo 0 append 1371 of 2500 OK
# Edo 0 append 1372 of 2500 OK
# Edo 0 append 1373 of 2500 OK
# Edo 0 append 1374 of 2500 OK
# Edo 0 append 1375 of 2500 OK
# Edo 0 append 1376 of 2500 OK
# Edo 0 append 1377 of 2500 OK
# Edo 0 append 1378 of 2500 OK
# Edo 0 append 1379 of 2500 OK
# Edo 0 append 1380 of 2500 OK
# Edo 0 append 1381 of 2500 OK
# Edo 0 append 1382 of 2500 OK
# Edo 0 append 1383 of 2500 OK
# Edo 0 append 1384 of 2500 OK
# Edo 0 append 1385 of 2500 OK
# Edo 0 append 1386 of 2500 OK
# Edo 0 append 1387 of 2500 OK
# Edo 0 append 1388 of 2500 OK
# Edo 0 append 1389 of 2500 OK
# Edo 0 append 1390 of 2500 OK
# Edo 0 append 1391 of 2500 OK
# Edo 0 append 1392 of 2500 OK
# Edo 0 append 1393 of 2500 OK
# Edo 0 append 1394 of 2500 OK
# Edo 0 append 1395 of 2500 OK
# Edo 0 append 1396 of 2500 OK
# Edo 0 append 1397 of 2500 OK
# Edo 0 append 1398 of 2500 OK
# Edo 0 append 1399 of 2500 OK
# Edo 0 append 1400 of 2500 OK
# Edo 0 append 1401 of 2500 OK
# Edo 0 append 1402 of 2500 OK
# Edo 0 append 1403 of 2500 OK
# Edo 0 append 1404 of 2500 OK
# Edo 0 append 1405 of 2500 OK
# Edo 0 append 1406 of 2500 OK
# Edo 0 append 1407 of 2500 OK
# Edo 0 append 1408 of 2500 OK
# Edo 0 append 1409 of 2500 OK
# Edo 0 append 1410 of 2500 OK
# Edo 0 append 1411 of 2500 OK
# Edo 0 append 1412 of 2500 OK
# Edo 0 append 1413 of 2500 OK
# Edo 0 append 1414 of 2500 OK
# Edo 0 append 1415 of 2500 OK
# Edo 0 append 1416 of 2500 OK
# Edo 0 append 1417 of 2500 OK
# Edo 0 append 1418 of 2500 OK
# Edo 0 append 1419 of 2500 OK
# Edo 0 append 1420 of 2500 OK
# Edo 0 append 1421 of 2500 OK
# Edo 0 append 1422 of 2500 OK
# Edo 0 append 1423 of 2500 OK
# Edo 0 append 1424 of 2500 OK
# Edo 0 append 1425 of 2500 OK
# Edo 0 append 1426 of 2500 OK
# Edo 0 append 1427 of 2500 OK
# Edo 0 append 1428 of 2500 OK
# Edo 0 append 1429 of 2500 OK
# Edo 0 append 1430 of 2500 OK
# Edo 0 append 1431 of 2500 OK
# Edo 0 append 1432 of 2500 OK
# Edo 0 append 1433 of 2500 OK
# Edo 0 append 1434 of 2500 OK
# Edo 0 append 1435 of 2500 OK
# Edo 0 append 1436 of 2500 OK
# Edo 0 append 1437 of 2500 OK
# Edo 0 append 1438 of 2500 OK
# Edo 0 append 1439 of 2500 OK
# Edo 0 append 1440 of 2500 OK
# Edo 0 append 1441 of 2500 OK
# Edo 0 append 1442 of 2500 OK
# Edo 0 append 1443 of 2500 OK
# Edo 0 append 1444 of 2500 OK
# Edo 0 append 1445 of 2500 OK
# Edo 0 append 1446 of 2500 OK
# Edo 0 append 1447 of 2500 OK
# Edo 0 append 1448 of 2500 OK
# Edo 0 append 1449 of 2500 OK
# Edo 0 append 1450 of 2500 OK
# Edo 0 append 1451 of 2500 OK
# Edo 0 append 1452 of 2500 OK
# Edo 0 append 1453 of 2500 OK
# Edo 0 append 1454 of 2500 OK
# Edo 0 append 1455 of 2500 OK
# Edo 0 append 1456 of 2500 OK
# Edo 0 append 1457 of 2500 OK
# Edo 0 append 1458 of 2500 OK
# Edo 0 append 1459 of 2500 OK
# Edo 0 append 1460 of 2500 OK
# Edo 0 append 1461 of 2500 OK
# Edo 0 append 1462 of 2500 OK
# Edo 0 append 1463 of 2500 OK
# Edo 0 append 1464 of 2500 OK
# Edo 0 append 1465 of 2500 OK
# Edo 0 append 1466 of 2500 OK
# Edo 0 append 1467 of 2500 OK
# Edo 0 append 1468 of 2500 OK
# Edo 0 append 1469 of 2500 OK
# Edo 0 append 1470 of 2500 OK
# Edo 0 append 1471 of 2500 OK
# Edo 0 append 1472 of 2500 OK
# Edo 0 append 1473 of 2500 OK
# Edo 0 append 1474 of 2500 OK
# Edo 0 append 1475 of 2500 OK
# Edo 0 append 1476 of 2500 OK
# Edo 0 append 1477 of 2500 OK
# Edo 0 append 1478 of 2500 OK
# Edo 0 append 1479 of 2500 OK
# Edo 0 append 1480 of 2500 OK
# Edo 0 append 1481 of 2500 OK
# Edo 0 append 1482 of 2500 OK
# Edo 0 append 1483 of 2500 OK
# Edo 0 append 1484 of 2500 OK
# Edo 0 append 1485 of 2500 OK
# Edo 0 append 1486 of 2500 OK
# Edo 0 append 1487 of 2500 OK
# Edo 0 append 1488 of 2500 OK
# Edo 0 append 1489 of 2500 OK
# Edo 0 append 1490 of 2500 OK
# Edo 0 append 1491 of 2500 OK
# Edo 0 append 1492 of 2500 OK
# Edo 0 append 1493 of 2500 OK
# Edo 0 append 1494 of 2500 OK
# Edo 0 append 1495 of 2500 OK
# Edo 0 append 1496 of 2500 OK
# Edo 0 append 1497 of 2500 OK
# Edo 0 append 1498 of 2500 OK
# Edo 0 append 1499 of 2500 OK
# Edo 0 append 1500 of 2500 OK
# Edo 0 append 1501 of 2500 OK
# Edo 0 append 1502 of 2500 OK
# Edo 0 append 1503 of 2500 OK
# Edo 0 append 1504 of 2500 OK
# Edo 0 append 1505 of 2500 OK
# Edo 0 append 1506 of 2500 OK
# Edo 0 append 1507 of 2500 OK
# Edo 0 append 1508 of 2500 OK
# Edo 0 append 1509 of 2500 OK
# Edo 0 append 1510 of 2500 OK
# Edo 0 append 1511 of 2500 OK
# Edo 0 append 1512 of 2500 OK
# Edo 0 append 1513 of 2500 OK
# Edo 0 append 1514 of 2500 OK
# Edo 0 append 1515 of 2500 OK
# Edo 0 append 1516 of 2500 OK
# Edo 0 append 1517 of 2500 OK
# Edo 0 append 1518 of 2500 OK
# Edo 0 append 1519 of 2500 OK
# Edo 0 append 1520 of 2500 OK
# Edo 0 append 1521 of 2500 OK
# Edo 0 append 1522 of 2500 OK
# Edo 0 append 1523 of 2500 OK
# Edo 0 append 1524 of 2500 OK
# Edo 0 append 1525 of 2500 OK
# Edo 0 append 1526 of 2500 OK
# Edo 0 append 1527 of 2500 OK
# Edo 0 append 1528 of 2500 OK
# Edo 0 append 1529 of 2500 OK
# Edo 0 append 1530 of 2500 OK
# Edo 0 append 1531 of 2500 OK
# Edo 0 append 1532 of 2500 OK
# Edo 0 append 1533 of 2500 OK
# Edo 0 append 1534 of 2500 OK
# Edo 0 append 1535 of 2500 OK
# Edo 0 append 1536 of 2500 OK
# Edo 0 append 1537 of 2500 OK
# Edo 0 append 1538 of 2500 OK
# Edo 0 append 1539 of 2500 OK
# Edo 0 append 1540 of 2500 OK
# Edo 0 append 1541 of 2500 OK
# Edo 0 append 1542 of 2500 OK
# Edo 0 append 1543 of 2500 OK
# Edo 0 append 1544 of 2500 OK
# Edo 0 append 1545 of 2500 OK
# Edo 0 append 1546 of 2500 OK
# Edo 0 append 1547 of 2500 OK
# Edo 0 append 1548 of 2500 OK
# Edo 0 append 1549 of 2500 OK
# Edo 0 append 1550 of 2500 OK
# Edo 0 append 1551 of 2500 OK
# Edo 0 append 1552 of 2500 OK
# Edo 0 append 1553 of 2500 OK
# Edo 0 append 1554 of 2500 OK
# Edo 0 append 1555 of 2500 OK
# Edo 0 append 1556 of 2500 OK
# Edo 0 append 1557 of 2500 OK
# Edo 0 append 1558 of 2500 OK
# Edo 0 append 1559 of 2500 OK
# Edo 0 append 1560 of 2500 OK
# Edo 0 append 1561 of 2500 OK
# Edo 0 append 1562 of 2500 OK
# Edo 0 append 1563 of 2500 OK
# Edo 0 append 1564 of 2500 OK
# Edo 0 append 1565 of 2500 OK
# Edo 0 append 1566 of 2500 OK
# Edo 0 append 1567 of 2500 OK
# Edo 0 append 1568 of 2500 OK
# Edo 0 append 1569 of 2500 OK
# Edo 0 append 1570 of 2500 OK
# Edo 0 append 1571 of 2500 OK
# Edo 0 append 1572 of 2500 OK
# Edo 0 append 1573 of 2500 OK
# Edo 0 append 1574 of 2500 OK
# Edo 0 append 1575 of 2500 OK
# Edo 0 append 1576 of 2500 OK
# Edo 0 append 1577 of 2500 OK
# Edo 0 append 1578 of 2500 OK
# Edo 0 append 1579 of 2500 OK
# Edo 0 append 1580 of 2500 OK
# Edo 0 append 1581 of 2500 OK
# Edo 0 append 1582 of 2500 OK
# Edo 0 append 1583 of 2500 OK
# Edo 0 append 1584 of 2500 OK
# Edo 0 append 1585 of 2500 OK
# Edo 0 append 1586 of 2500 OK
# Edo 0 append 1587 of 2500 OK
# Edo 0 append 1588 of 2500 OK
# Edo 0 append 1589 of 2500 OK
# Edo 0 append 1590 of 2500 OK
# Edo 0 append 1591 of 2500 OK
# Edo 0 append 1592 of 2500 OK
# Edo 0 append 1593 of 2500 OK
# Edo 0 append 1594 of 2500 OK
# Edo 0 append 1595 of 2500 OK
# Edo 0 append 1596 of 2500 OK
# Edo 0 append 1597 of 2500 OK
# Edo 0 append 1598 of 2500 OK
# Edo 0 append 1599 of 2500 OK
# Edo 0 append 1600 of 2500 OK
# Edo 0 append 1601 of 2500 OK
# Edo 0 append 1602 of 2500 OK
# Edo 0 append 1603 of 2500 OK
# Edo 0 append 1604 of 2500 OK
# Edo 0 append 1605 of 2500 OK
# Edo 0 append 1606 of 2500 OK
# Edo 0 append 1607 of 2500 OK
# Edo 0 append 1608 of 2500 OK
# Edo 0 append 1609 of 2500 OK
# Edo 0 append 1610 of 2500 OK
# Edo 0 append 1611 of 2500 OK
# Edo 0 append 1612 of 2500 OK
# Edo 0 append 1613 of 2500 OK
# Edo 0 append 1614 of 2500 OK
# Edo 0 append 1615 of 2500 OK
# Edo 0 append 1616 of 2500 OK
# Edo 0 append 1617 of 2500 OK
# Edo 0 append 1618 of 2500 OK
# Edo 0 append 1619 of 2500 OK
# Edo 0 append 1620 of 2500 OK
# Edo 0 append 1621 of 2500 OK
# Edo 0 append 1622 of 2500 OK
# Edo 0 append 1623 of 2500 OK
# Edo 0 append 1624 of 2500 OK
# Edo 0 append 1625 of 2500 OK
# Edo 0 append 1626 of 2500 OK
# Edo 0 append 1627 of 2500 OK
# Edo 0 append 1628 of 2500 OK
# Edo 0 append 1629 of 2500 OK
# Edo 0 append 1630 of 2500 OK
# Edo 0 append 1631 of 2500 OK
# Edo 0 append 1632 of 2500 OK
# Edo 0 append 1633 of 2500 OK
# Edo 0 append 1634 of 2500 OK
# Edo 0 append 1635 of 2500 OK
# Edo 0 append 1636 of 2500 OK
# Edo 0 append 1637 of 2500 OK
# Edo 0 append 1638 of 2500 OK
# Edo 0 append 1639 of 2500 OK
# Edo 0 append 1640 of 2500 OK
# Edo 0 append 1641 of 2500 OK
# Edo 0 append 1642 of 2500 OK
# Edo 0 append 1643 of 2500 OK
# Edo 0 append 1644 of 2500 OK
# Edo 0 append 1645 of 2500 OK
# Edo 0 append 1646 of 2500 OK
# Edo 0 append 1647 of 2500 OK
# Edo 0 append 1648 of 2500 OK
# Edo 0 append 1649 of 2500 OK
# Edo 0 append 1650 of 2500 OK
# Edo 0 append 1651 of 2500 OK
# Edo 0 append 1652 of 2500 OK
# Edo 0 append 1653 of 2500 OK
# Edo 0 append 1654 of 2500 OK
# Edo 0 append 1655 of 2500 OK
# Edo 0 append 1656 of 2500 OK
# Edo 0 append 1657 of 2500 OK
# Edo 0 append 1658 of 2500 OK
# Edo 0 append 1659 of 2500 OK
# Edo 0 append 1660 of 2500 OK
# Edo 0 append 1661 of 2500 OK
# Edo 0 append 1662 of 2500 OK
# Edo 0 append 1663 of 2500 OK
# Edo 0 append 1664 of 2500 OK
# Edo 0 append 1665 of 2500 OK
# Edo 0 append 1666 of 2500 OK
# Edo 0 append 1667 of 2500 OK
# Edo 0 append 1668 of 2500 OK
# Edo 0 append 1669 of 2500 OK
# Edo 0 append 1670 of 2500 OK
# Edo 0 append 1671 of 2500 OK
# Edo 0 append 1672 of 2500 OK
# Edo 0 append 1673 of 2500 OK
# Edo 0 append 1674 of 2500 OK
# Edo 0 append 1675 of 2500 OK
# Edo 0 append 1676 of 2500 OK
# Edo 0 append 1677 of 2500 OK
# Edo 0 append 1678 of 2500 OK
# Edo 0 append 1679 of 2500 OK
# Edo 0 append 1680 of 2500 OK
# Edo 0 append 1681 of 2500 OK
# Edo 0 append 1682 of 2500 OK
# Edo 0 append 1683 of 2500 OK
# Edo 0 append 1684 of 2500 OK
# Edo 0 append 1685 of 2500 OK
# Edo 0 append 1686 of 2500 OK
# Edo 0 append 1687 of 2500 OK
# Edo 0 append 1688 of 2500 OK
# Edo 0 append 1689 of 2500 OK
# Edo 0 append 1690 of 2500 OK
# Edo 0 append 1691 of 2500 OK
# ...
# Edo 2 append 15865 of 16380 OK
# Edo 2 append 15866 of 16380 OK
# Edo 2 append 15867 of 16380 OK
# Edo 2 append 15868 of 16380 OK
# Edo 2 append 15869 of 16380 OK
# Edo 2 append 15870 of 16380 OK
# Edo 2 append 15871 of 16380 OK
# Edo 2 append 15872 of 16380 OK
# Edo 2 append 15873 of 16380 OK
# Edo 2 append 15874 of 16380 OK
# Edo 2 append 15875 of 16380 OK
# Edo 2 append 15876 of 16380 OK
# Edo 2 append 15877 of 16380 OK
# Edo 2 append 15878 of 16380 OK
# Edo 2 append 15879 of 16380 OK
# Edo 2 append 15880 of 16380 OK
# Edo 2 append 15881 of 16380 OK
# Edo 2 append 15882 of 16380 OK
# Edo 2 append 15883 of 16380 OK
# Edo 2 append 15884 of 16380 OK
# Edo 2 append 15885 of 16380 OK
# Edo 2 append 15886 of 16380 OK
# Edo 2 append 15887 of 16380 OK
# Edo 2 append 15888 of 16380 OK
# Edo 2 append 15889 of 16380 OK
# Edo 2 append 15890 of 16380 OK
# Edo 2 append 15891 of 16380 OK
# Edo 2 append 15892 of 16380 OK
# Edo 2 append 15893 of 16380 OK
# Edo 2 append 15894 of 16380 OK
# Edo 2 append 15895 of 16380 OK
# Edo 2 append 15896 of 16380 OK
# Edo 2 append 15897 of 16380 OK
# Edo 2 append 15898 of 16380 OK
# Edo 2 append 15899 of 16380 OK
# Edo 2 append 15900 of 16380 OK
# Edo 2 append 15901 of 16380 OK
# Edo 2 append 15902 of 16380 OK
# Edo 2 append 15903 of 16380 OK
# Edo 2 append 15904 of 16380 OK
# Edo 2 append 15905 of 16380 OK
# Edo 2 append 15906 of 16380 OK
# Edo 2 append 15907 of 16380 OK
# Edo 2 append 15908 of 16380 OK
# Edo 2 append 15909 of 16380 OK
# Edo 2 append 15910 of 16380 OK
# Edo 2 append 15911 of 16380 OK
# Edo 2 append 15912 of 16380 OK
# Edo 2 append 15913 of 16380 OK
# Edo 2 append 15914 of 16380 OK
# Edo 2 append 15915 of 16380 OK
# Edo 2 append 15916 of 16380 OK
# Edo 2 append 15917 of 16380 OK
# Edo 2 append 15918 of 16380 OK
# Edo 2 append 15919 of 16380 OK
# Edo 2 append 15920 of 16380 OK
# Edo 2 append 15921 of 16380 OK
# Edo 2 append 15922 of 16380 OK
# Edo 2 append 15923 of 16380 OK
# Edo 2 append 15924 of 16380 OK
# Edo 2 append 15925 of 16380 OK
# Edo 2 append 15926 of 16380 OK
# Edo 2 append 15927 of 16380 OK
# Edo 2 append 15928 of 16380 OK
# Edo 2 append 15929 of 16380 OK
# Edo 2 append 15930 of 16380 OK
# Edo 2 append 15931 of 16380 OK
# Edo 2 append 15932 of 16380 OK
# Edo 2 append 15933 of 16380 OK
# Edo 2 append 15934 of 16380 OK
# Edo 2 append 15935 of 16380 OK
# Edo 2 append 15936 of 16380 OK
# Edo 2 append 15937 of 16380 OK
# Edo 2 append 15938 of 16380 OK
# Edo 2 append 15939 of 16380 OK
# Edo 2 append 15940 of 16380 OK
# Edo 2 append 15941 of 16380 OK
# Edo 2 append 15942 of 16380 OK
# Edo 2 append 15943 of 16380 OK
# Edo 2 append 15944 of 16380 OK
# Edo 2 append 15945 of 16380 OK
# Edo 2 append 15946 of 16380 OK
# Edo 2 append 15947 of 16380 OK
# Edo 2 append 15948 of 16380 OK
# Edo 2 append 15949 of 16380 OK
# Edo 2 append 15950 of 16380 OK
# Edo 2 append 15951 of 16380 OK
# Edo 2 append 15952 of 16380 OK
# Edo 2 append 15953 of 16380 OK
# Edo 2 append 15954 of 16380 OK
# Edo 2 append 15955 of 16380 OK
# Edo 2 append 15956 of 16380 OK
# Edo 2 append 15957 of 16380 OK
# Edo 2 append 15958 of 16380 OK
# Edo 2 append 15959 of 16380 OK
# Edo 2 append 15960 of 16380 OK
# Edo 2 append 15961 of 16380 OK
# Edo 2 append 15962 of 16380 OK
# Edo 2 append 15963 of 16380 OK
# Edo 2 append 15964 of 16380 OK
# Edo 2 append 15965 of 16380 OK
# Edo 2 append 15966 of 16380 OK
# Edo 2 append 15967 of 16380 OK
# Edo 2 append 15968 of 16380 OK
# Edo 2 append 15969 of 16380 OK
# Edo 2 append 15970 of 16380 OK
# Edo 2 append 15971 of 16380 OK
# Edo 2 append 15972 of 16380 OK
# Edo 2 append 15973 of 16380 OK
# Edo 2 append 15974 of 16380 OK
# Edo 2 append 15975 of 16380 OK
# Edo 2 append 15976 of 16380 OK
# Edo 2 append 15977 of 16380 OK
# Edo 2 append 15978 of 16380 OK
# Edo 2 append 15979 of 16380 OK
# Edo 2 append 15980 of 16380 OK
# Edo 2 append 15981 of 16380 OK
# Edo 2 append 15982 of 16380 OK
# Edo 2 append 15983 of 16380 OK
# Edo 2 append 15984 of 16380 OK
# Edo 2 append 15985 of 16380 OK
# Edo 2 append 15986 of 16380 OK
# Edo 2 append 15987 of 16380 OK
# Edo 2 append 15988 of 16380 OK
# Edo 2 append 15989 of 16380 OK
# Edo 2 append 15990 of 16380 OK
# Edo 2 append 15991 of 16380 OK
# Edo 2 append 15992 of 16380 OK
# Edo 2 append 15993 of 16380 OK
# Edo 2 append 15994 of 16380 OK
# Edo 2 append 15995 of 16380 OK
# Edo 2 append 15996 of 16380 OK
# Edo 2 append 15997 of 16380 OK
# Edo 2 append 15998 of 16380 OK
# Edo 2 append 15999 of 16380 OK
# Edo 2 append 16000 of 16380 OK
# Edo 2 append 16001 of 16380 OK
# Edo 2 append 16002 of 16380 OK
# Edo 2 append 16003 of 16380 OK
# Edo 2 append 16004 of 16380 OK
# Edo 2 append 16005 of 16380 OK
# Edo 2 append 16006 of 16380 OK
# Edo 2 append 16007 of 16380 OK
# Edo 2 append 16008 of 16380 OK
# Edo 2 append 16009 of 16380 OK
# Edo 2 append 16010 of 16380 OK
# Edo 2 append 16011 of 16380 OK
# Edo 2 append 16012 of 16380 OK
# Edo 2 append 16013 of 16380 OK
# Edo 2 append 16014 of 16380 OK
# Edo 2 append 16015 of 16380 OK
# Edo 2 append 16016 of 16380 OK
# Edo 2 append 16017 of 16380 OK
# Edo 2 append 16018 of 16380 OK
# Edo 2 append 16019 of 16380 OK
# Edo 2 append 16020 of 16380 OK
# Edo 2 append 16021 of 16380 OK
# Edo 2 append 16022 of 16380 OK
# Edo 2 append 16023 of 16380 OK
# Edo 2 append 16024 of 16380 OK
# Edo 2 append 16025 of 16380 OK
# Edo 2 append 16026 of 16380 OK
# Edo 2 append 16027 of 16380 OK
# Edo 2 append 16028 of 16380 OK
# Edo 2 append 16029 of 16380 OK
# Edo 2 append 16030 of 16380 OK
# Edo 2 append 16031 of 16380 OK
# Edo 2 append 16032 of 16380 OK
# Edo 2 append 16033 of 16380 OK
# Edo 2 append 16034 of 16380 OK
# Edo 2 append 16035 of 16380 OK
# Edo 2 append 16036 of 16380 OK
# Edo 2 append 16037 of 16380 OK
# Edo 2 append 16038 of 16380 OK
# Edo 2 append 16039 of 16380 OK
# Edo 2 append 16040 of 16380 OK
# Edo 2 append 16041 of 16380 OK
# Edo 2 append 16042 of 16380 OK
# Edo 2 append 16043 of 16380 OK
# Edo 2 append 16044 of 16380 OK
# Edo 2 append 16045 of 16380 OK
# Edo 2 append 16046 of 16380 OK
# Edo 2 append 16047 of 16380 OK
# Edo 2 append 16048 of 16380 OK
# Edo 2 append 16049 of 16380 OK
# Edo 2 append 16050 of 16380 OK
# Edo 2 append 16051 of 16380 OK
# Edo 2 append 16052 of 16380 OK
# Edo 2 append 16053 of 16380 OK
# Edo 2 append 16054 of 16380 OK
# Edo 2 append 16055 of 16380 OK
# Edo 2 append 16056 of 16380 OK
# Edo 2 append 16057 of 16380 OK
# Edo 2 append 16058 of 16380 OK
# Edo 2 append 16059 of 16380 OK
# Edo 2 append 16060 of 16380 OK
# Edo 2 append 16061 of 16380 OK
# Edo 2 append 16062 of 16380 OK
# Edo 2 append 16063 of 16380 OK
# Edo 2 append 16064 of 16380 OK
# Edo 2 append 16065 of 16380 OK
# Edo 2 append 16066 of 16380 OK
# Edo 2 append 16067 of 16380 OK
# Edo 2 append 16068 of 16380 OK
# Edo 2 append 16069 of 16380 OK
# Edo 2 append 16070 of 16380 OK
# Edo 2 append 16071 of 16380 OK
# Edo 2 append 16072 of 16380 OK
# Edo 2 append 16073 of 16380 OK
# Edo 2 append 16074 of 16380 OK
# Edo 2 append 16075 of 16380 OK
# Edo 2 append 16076 of 16380 OK
# Edo 2 append 16077 of 16380 OK
# Edo 2 append 16078 of 16380 OK
# Edo 2 append 16079 of 16380 OK
# Edo 2 append 16080 of 16380 OK
# Edo 2 append 16081 of 16380 OK
# Edo 2 append 16082 of 16380 OK
# Edo 2 append 16083 of 16380 OK
# Edo 2 append 16084 of 16380 OK
# Edo 2 append 16085 of 16380 OK
# Edo 2 append 16086 of 16380 OK
# Edo 2 append 16087 of 16380 OK
# Edo 2 append 16088 of 16380 OK
# Edo 2 append 16089 of 16380 OK
# Edo 2 append 16090 of 16380 OK
# Edo 2 append 16091 of 16380 OK
# Edo 2 append 16092 of 16380 OK
# Edo 2 append 16093 of 16380 OK
# Edo 2 append 16094 of 16380 OK
# Edo 2 append 16095 of 16380 OK
# Edo 2 append 16096 of 16380 OK
# Edo 2 append 16097 of 16380 OK
# Edo 2 append 16098 of 16380 OK
# Edo 2 append 16099 of 16380 OK
# Edo 2 append 16100 of 16380 OK
# Edo 2 append 16101 of 16380 OK
# Edo 2 append 16102 of 16380 OK
# Edo 2 append 16103 of 16380 OK
# Edo 2 append 16104 of 16380 OK
# Edo 2 append 16105 of 16380 OK
# Edo 2 append 16106 of 16380 OK
# Edo 2 append 16107 of 16380 OK
# Edo 2 append 16108 of 16380 OK
# Edo 2 append 16109 of 16380 OK
# Edo 2 append 16110 of 16380 OK
# Edo 2 append 16111 of 16380 OK
# Edo 2 append 16112 of 16380 OK
# Edo 2 append 16113 of 16380 OK
# Edo 2 append 16114 of 16380 OK
# Edo 2 append 16115 of 16380 OK
# Edo 2 append 16116 of 16380 OK
# Edo 2 append 16117 of 16380 OK
# Edo 2 append 16118 of 16380 OK
# Edo 2 append 16119 of 16380 OK
# Edo 2 append 16120 of 16380 OK
# Edo 2 append 16121 of 16380 OK
# Edo 2 append 16122 of 16380 OK
# Edo 2 append 16123 of 16380 OK
# Edo 2 append 16124 of 16380 OK
# Edo 2 append 16125 of 16380 OK
# Edo 2 append 16126 of 16380 OK
# Edo 2 append 16127 of 16380 OK
# Edo 2 append 16128 of 16380 OK
# Edo 2 append 16129 of 16380 OK
# Edo 2 append 16130 of 16380 OK
# Edo 2 append 16131 of 16380 OK
# Edo 2 append 16132 of 16380 OK
# Edo 2 append 16133 of 16380 OK
# Edo 2 append 16134 of 16380 OK
# Edo 2 append 16135 of 16380 OK
# Edo 2 append 16136 of 16380 OK
# Edo 2 append 16137 of 16380 OK
# Edo 2 append 16138 of 16380 OK
# Edo 2 append 16139 of 16380 OK
# Edo 2 append 16140 of 16380 OK
# Edo 2 append 16141 of 16380 OK
# Edo 2 append 16142 of 16380 OK
# Edo 2 append 16143 of 16380 OK
# Edo 2 append 16144 of 16380 OK
# Edo 2 append 16145 of 16380 OK
# Edo 2 append 16146 of 16380 OK
# Edo 2 append 16147 of 16380 OK
# Edo 2 append 16148 of 16380 OK
# Edo 2 append 16149 of 16380 OK
# Edo 2 append 16150 of 16380 OK
# Edo 2 append 16151 of 16380 OK
# Edo 2 append 16152 of 16380 OK
# Edo 2 append 16153 of 16380 OK
# Edo 2 append 16154 of 16380 OK
# Edo 2 append 16155 of 16380 OK
# Edo 2 append 16156 of 16380 OK
# Edo 2 append 16157 of 16380 OK
# Edo 2 append 16158 of 16380 OK
# Edo 2 append 16159 of 16380 OK
# Edo 2 append 16160 of 16380 OK
# Edo 2 append 16161 of 16380 OK
# Edo 2 append 16162 of 16380 OK
# Edo 2 append 16163 of 16380 OK
# Edo 2 append 16164 of 16380 OK
# Edo 2 append 16165 of 16380 OK
# Edo 2 append 16166 of 16380 OK
# Edo 2 append 16167 of 16380 OK
# Edo 2 append 16168 of 16380 OK
# Edo 2 append 16169 of 16380 OK
# Edo 2 append 16170 of 16380 OK
# Edo 2 append 16171 of 16380 OK
# Edo 2 append 16172 of 16380 OK
# Edo 2 append 16173 of 16380 OK
# Edo 2 append 16174 of 16380 OK
# Edo 2 append 16175 of 16380 OK
# Edo 2 append 16176 of 16380 OK
# Edo 2 append 16177 of 16380 OK
# Edo 2 append 16178 of 16380 OK
# Edo 2 append 16179 of 16380 OK
# Edo 2 append 16180 of 16380 OK
# Edo 2 append 16181 of 16380 OK
# Edo 2 append 16182 of 16380 OK
# Edo 2 append 16183 of 16380 OK
# Edo 2 append 16184 of 16380 OK
# Edo 2 append 16185 of 16380 OK
# Edo 2 append 16186 of 16380 OK
# Edo 2 append 16187 of 16380 OK
# Edo 2 append 16188 of 16380 OK
# Edo 2 append 16189 of 16380 OK
# Edo 2 append 16190 of 16380 OK
# Edo 2 append 16191 of 16380 OK
# Edo 2 append 16192 of 16380 OK
# Edo 2 append 16193 of 16380 OK
# Edo 2 append 16194 of 16380 OK
# Edo 2 append 16195 of 16380 OK
# Edo 2 append 16196 of 16380 OK
# Edo 2 append 16197 of 16380 OK
# Edo 2 append 16198 of 16380 OK
# Edo 2 append 16199 of 16380 OK
# Edo 2 append 16200 of 16380 OK
# Edo 2 append 16201 of 16380 OK
# Edo 2 append 16202 of 16380 OK
# Edo 2 append 16203 of 16380 OK
# Edo 2 append 16204 of 16380 OK
# Edo 2 append 16205 of 16380 OK
# Edo 2 append 16206 of 16380 OK
# Edo 2 append 16207 of 16380 OK
# Edo 2 append 16208 of 16380 OK
# Edo 2 append 16209 of 16380 OK
# Edo 2 append 16210 of 16380 OK
# Edo 2 append 16211 of 16380 OK
# Edo 2 append 16212 of 16380 OK
# Edo 2 append 16213 of 16380 OK
# Edo 2 append 16214 of 16380 OK
# Edo 2 append 16215 of 16380 OK
# Edo 2 append 16216 of 16380 OK
# Edo 2 append 16217 of 16380 OK
# Edo 2 append 16218 of 16380 OK
# Edo 2 append 16219 of 16380 OK
# Edo 2 append 16220 of 16380 OK
# Edo 2 append 16221 of 16380 OK
# Edo 2 append 16222 of 16380 OK
# Edo 2 append 16223 of 16380 OK
# Edo 2 append 16224 of 16380 OK
# Edo 2 append 16225 of 16380 OK
# Edo 2 append 16226 of 16380 OK
# Edo 2 append 16227 of 16380 OK
# Edo 2 append 16228 of 16380 OK
# Edo 2 append 16229 of 16380 OK
# Edo 2 append 16230 of 16380 OK
# Edo 2 append 16231 of 16380 OK
# Edo 2 append 16232 of 16380 OK
# Edo 2 append 16233 of 16380 OK
# Edo 2 append 16234 of 16380 OK
# Edo 2 append 16235 of 16380 OK
# Edo 2 append 16236 of 16380 OK
# Edo 2 append 16237 of 16380 OK
# Edo 2 append 16238 of 16380 OK
# Edo 2 append 16239 of 16380 OK
# Edo 2 append 16240 of 16380 OK
# Edo 2 append 16241 of 16380 OK
# Edo 2 append 16242 of 16380 OK
# Edo 2 append 16243 of 16380 OK
# Edo 2 append 16244 of 16380 OK
# Edo 2 append 16245 of 16380 OK
# Edo 2 append 16246 of 16380 OK
# Edo 2 append 16247 of 16380 OK
# Edo 2 append 16248 of 16380 OK
# Edo 2 append 16249 of 16380 OK
# Edo 2 append 16250 of 16380 OK
# Edo 2 append 16251 of 16380 OK
# Edo 2 append 16252 of 16380 OK
# Edo 2 append 16253 of 16380 OK
# Edo 2 append 16254 of 16380 OK
# Edo 2 append 16255 of 16380 OK
# Edo 2 append 16256 of 16380 OK
# Edo 2 append 16257 of 16380 OK
# Edo 2 append 16258 of 16380 OK
# Edo 2 append 16259 of 16380 OK
# Edo 2 append 16260 of 16380 OK
# Edo 2 append 16261 of 16380 OK
# Edo 2 append 16262 of 16380 OK
# Edo 2 append 16263 of 16380 OK
# Edo 2 append 16264 of 16380 OK
# Edo 2 append 16265 of 16380 OK
# Edo 2 append 16266 of 16380 OK
# Edo 2 append 16267 of 16380 OK
# Edo 2 append 16268 of 16380 OK
# Edo 2 append 16269 of 16380 OK
# Edo 2 append 16270 of 16380 OK
# Edo 2 append 16271 of 16380 OK
# Edo 2 append 16272 of 16380 OK
# Edo 2 append 16273 of 16380 OK
# Edo 2 append 16274 of 16380 OK
# Edo 2 append 16275 of 16380 OK
# Edo 2 append 16276 of 16380 OK
# Edo 2 append 16277 of 16380 OK
# Edo 2 append 16278 of 16380 OK
# Edo 2 append 16279 of 16380 OK
# Edo 2 append 16280 of 16380 OK
# Edo 2 append 16281 of 16380 OK
# Edo 2 append 16282 of 16380 OK
# Edo 2 append 16283 of 16380 OK
# Edo 2 append 16284 of 16380 OK
# Edo 2 append 16285 of 16380 OK
# Edo 2 append 16286 of 16380 OK
# Edo 2 append 16287 of 16380 OK
# Edo 2 append 16288 of 16380 OK
# Edo 2 append 16289 of 16380 OK
# Edo 2 append 16290 of 16380 OK
# Edo 2 append 16291 of 16380 OK
# Edo 2 append 16292 of 16380 OK
# Edo 2 append 16293 of 16380 OK
# Edo 2 append 16294 of 16380 OK
# Edo 2 append 16295 of 16380 OK
# Edo 2 append 16296 of 16380 OK
# Edo 2 append 16297 of 16380 OK
# Edo 2 append 16298 of 16380 OK
# Edo 2 append 16299 of 16380 OK
# Edo 2 append 16300 of 16380 OK
# Edo 2 append 16301 of 16380 OK
# Edo 2 append 16302 of 16380 OK
# Edo 2 append 16303 of 16380 OK
# Edo 2 append 16304 of 16380 OK
# Edo 2 append 16305 of 16380 OK
# Edo 2 append 16306 of 16380 OK
# Edo 2 append 16307 of 16380 OK
# Edo 2 append 16308 of 16380 OK
# Edo 2 append 16309 of 16380 OK
# Edo 2 append 16310 of 16380 OK
# Edo 2 append 16311 of 16380 OK
# Edo 2 append 16312 of 16380 OK
# Edo 2 append 16313 of 16380 OK
# Edo 2 append 16314 of 16380 OK
# Edo 2 append 16315 of 16380 OK
# Edo 2 append 16316 of 16380 OK
# Edo 2 append 16317 of 16380 OK
# Edo 2 append 16318 of 16380 OK
# Edo 2 append 16319 of 16380 OK
# Edo 2 append 16320 of 16380 OK
# Edo 2 append 16321 of 16380 OK
# Edo 2 append 16322 of 16380 OK
# Edo 2 append 16323 of 16380 OK
# Edo 2 append 16324 of 16380 OK
# Edo 2 append 16325 of 16380 OK
# Edo 2 append 16326 of 16380 OK
# Edo 2 append 16327 of 16380 OK
# Edo 2 append 16328 of 16380 OK
# Edo 2 append 16329 of 16380 OK
# Edo 2 append 16330 of 16380 OK
# Edo 2 append 16331 of 16380 OK
# Edo 2 append 16332 of 16380 OK
# Edo 2 append 16333 of 16380 OK
# Edo 2 append 16334 of 16380 OK
# Edo 2 append 16335 of 16380 OK
# Edo 2 append 16336 of 16380 OK
# Edo 2 append 16337 of 16380 OK
# Edo 2 append 16338 of 16380 OK
# Edo 2 append 16339 of 16380 OK
# Edo 2 append 16340 of 16380 OK
# Edo 2 append 16341 of 16380 OK
# Edo 2 append 16342 of 16380 OK
# Edo 2 append 16343 of 16380 OK
# Edo 2 append 16344 of 16380 OK
# Edo 2 append 16345 of 16380 OK
# Edo 2 append 16346 of 16380 OK
# Edo 2 append 16347 of 16380 OK
# Edo 2 append 16348 of 16380 OK
# Edo 2 append 16349 of 16380 OK
# Edo 2 append 16350 of 16380 OK
# Edo 2 append 16351 of 16380 OK
# Edo 2 append 16352 of 16380 OK
# Edo 2 append 16353 of 16380 OK
# Edo 2 append 16354 of 16380 OK
# Edo 2 append 16355 of 16380 OK
# Edo 2 append 16356 of 16380 OK
# Edo 2 append 16357 of 16380 OK
# Edo 2 append 16358 of 16380 OK
# Edo 2 append 16359 of 16380 OK
# Edo 2 append 16360 of 16380 OK
# Edo 2 append 16361 of 16380 OK
# Edo 2 append 16362 of 16380 OK
# Edo 2 append 16363 of 16380 OK
# Edo 2 append 16364 of 16380 OK
# Edo 2 append 16365 of 16380 OK
# Edo 2 append 16366 of 16380 OK
# Edo 2 append 16367 of 16380 OK
# Edo 2 append 16368 of 16380 OK
# Edo 2 append 16369 of 16380 OK
# Edo 2 append 16370 of 16380 OK
# Edo 2 append 16371 of 16380 OK
# Edo 2 append 16372 of 16380 OK
# Edo 2 append 16373 of 16380 OK
# Edo 2 append 16374 of 16380 OK
# Edo 2 append 16375 of 16380 OK
# Edo 2 append 16376 of 16380 OK
# Edo 2 append 16377 of 16380 OK
# Edo 2 append 16378 of 16380 OK
# Edo 2 append 16379 of 16380 OK
# ALL CSVs OK

# %%
Propiedades

# %%
soup

# %%
url = f"https://www.inmuebles24.com/propiedades/ciudad-argentum-53621157.html"
#url = f"https://www.inmuebles24.com/propiedades/venta-de-casa-en-privada-san-roman-ciudad-del-carmen-58203306.html"
#url = f"https://www.inmuebles24.com/inmuebles-en-venta-en-{Estado}.html"
browser.visit(url)
time.sleep(2)  
html = browser.html
soup = bs(html,"html.parser")

# %%
#Ubicacion = soup.findAll('li', class_="bread-item")
#Ubicacion
Generales = soup.findAll('li', class_="bread-item")
Marca = Generales[0].getText().replace('\n', '').strip()
Clasificacion = Generales[1].getText().replace('\n', '').strip()
Tipo = Generales[2].getText().replace('\n', '').strip()
Estado = Generales[3].getText().replace('\n', '').strip()
Municipio = Generales[4].getText().replace('\n', '').strip()
Colonia = Generales[5].getText().replace('\n', '').strip()
Colonia2 = Generales[6].getText().replace('\n', '').strip()
#A = Ubicacion[0].getText().replace('\n', '').strip()
#B = Ubicacion[1].getText().replace('\n', '').strip()
#C = Ubicacion[2].getText().replace('\n', '').strip()
#D = Ubicacion[3].getText().replace('\n', '').strip()
#E = Ubicacion[4].getText().replace('\n', '').strip()
#F = Ubicacion[5].getText().replace('\n', '').strip()
#G = Ubicacion[6].getText().replace('\n', '').strip()

print(f"Pagina posicion 0 = {Marca}")
print(f"Construccion posicion 1 = {Clasificacion}")
print(f"Tipo posicion 2 = {Tipo}")
print(f"Estado posicion 3 = {Estado}")
print(f"Municipio posicion 4 = {Municipio}")
print(f"Colonia posicion 5 = {Colonia}")
print(f"Colonia2 posicion 6 = {Colonia2}")

# %%
Street = soup.findAll('div', class_="section-location")
Street[0].getText().replace('\n', '').strip()

# %%
#Opcion1
Price = soup.findAll('span', class_="data-price")
Price = Price[0].getText().replace('\n', '').strip()
Moneda = Price[:3]
Price1 = Price.replace('MN ', '').strip()
Price1 = Price1.replace(',', '').strip()

# %%
#Opcion2
Price = soup.findAll('div', class_="price-items")
Price = Price[0].getText().replace('\n', '').strip()
Moneda = Price[:3]
Price = Price.replace('MN ', '').strip()
Price = Price.replace(',', '').strip()
print(Moneda)
print(Price)

# %%
#Opcion1.1
HouseDATA1 = soup.findAll('span', class_="data")
M2_Const = HouseDATA1[1].getText()
Recamaras = HouseDATA1[3].getText()
M2_Terreno = HouseDATA1[4].getText()
Estacionamiento = HouseDATA1[5].getText()

print(f"M2 Construidos ={M2_Const}")
print(f"Recamaras posicion 3 ={Recamaras}")
print(f"M2 Terreno posicion 4 ={M2_Terreno}")
print(f"M2 Construidos posicion 5 ={Estacionamiento}")

# %%
#Opcion2.1
HouseData2 = soup.findAll('li', class_="icon-feature")
Terreno = HouseData2[0].getText().replace('\n', '').strip()
Construccion = HouseData2[1].getText().replace('\n', '').strip()
Banos = HouseData2[2].getText().replace('\n', '').strip()
Estacionamiento = HouseData2[3].getText().replace('\n', '').strip()
Recamaras = HouseData2[4].getText().replace('\n', '').strip()
Medio_Bano = HouseData2[5].getText().replace('\n', '').strip()
print(Terreno)
print(Construccion)
print(Banos)
print(Estacionamiento)
print(Recamaras)
print(Medio_Bano)

# %%
Coord = soup.findAll('img', class_="static-map")
Coord = Coord[0]['src']
Coord = re.findall('center=(.+)&zoom', Coord)
Coord
#Coord[0].getText().replace('\n', '').strip()

# %%
Propiedades = {
        'Tipo':[],#data3['@type'']
        #'Propiedad':[],#data3['address']['addressRegion']
        'Pais':[],#data3['address']['addressCountry']
        'Ciudad':[],#data3['address']['addressRegion']
        'Municipio':[],#data3['address']['addressLocality']
        'Calle':[],#data3['address']['streetAddress']
        'Codigo_Postal':[],#data3['address']['postalCode']
        'Precio':[],#data3['potentialAction']['priceSpecification']['price']
        'Moneda':[],#data3['potentialAction']['priceSpecification']['priceCurrency']
        #'Superficie_Total':[],#data3[]
        'Superficie_Construida':[],#data3['floorSize']
        'Recamaras':[],#data3['numberOfRooms']
        #'Estacionamientos':[],#data3[]
        'DataT':[],#DataT
        'Tipo2':[],#Tipo
        'Precio2':[],#Precio
        'Superficie_Total2':[],#Terreno
        'Superficie_Construida2':[],#Construccion
        'Recamaras2':[],#Recamaras
        'Banos2':[],#BanosC
        'MBanos':[],#MBanos
        'Estacionamientos2':[],#Estacionamientos
        'Niveles':[],#Niveles
        'CordA':[],#Coord4
        'URL':[],#f'https://century21mexico.com{CasasList[x]}'
    
    }

# %%
for x in range(0,len(CasasList)):
    try:
        url = f'https://century21mexico.com{CasasList[x]}'
        Century_request = requests.get(url)
        Century = bs(Century_request.text, "html.parser")
        #time.sleep(4)
        data2 = Century.find('script', type='application/ld+json')
        data2_1 = str(data2)
        data2_1 = data2_1.replace('<script type="application/ld+json">\n', '').strip()
        data2_1 = data2_1.replace('\n', '').strip()
        data2_1 = data2_1.replace('\t', '').strip()
        data2_1 = data2_1.replace('</script>', '').strip()
        data3 = json.loads(data2_1)
        try:
            Coord2 = Century.find('img', class_="img-static-map").get('onclick')
            Coord3 = Coord2.replace('myNavFunc(', '').strip()
            Coord4 = Coord3.replace(')', '').strip()
        except:
            Coord4 = Century.find('img', class_="img-static-map")
        DataT = Century.find('div', class_="col-lg-6").text
        DataT = DataT.replace('\n', '').strip()
        Tipo = re.findall('Tipo:(.+)Precio de venta:', DataT)
        Precio = re.findall('Precio de venta:(.+)Superficie de terreno:', DataT)
        Terreno = re.findall('Superficie de terreno:(.+)Superficie de construcción:', DataT)
        Construccion = re.findall('Superficie de construcción:(.+)Superficie de frente:', DataT)
        Recamaras = re.findall('Recámaras:(.+)Baños completos:', DataT)
        BanosC = re.findall('Baños completos:(.+)Medios Baños:', DataT)
        MBanos = re.findall('Medios Baños:(.+)Estacionamientos:', DataT)
        Estacionamientos = re.findall('Estacionamientos:(.+)Edad:', DataT)
        Niveles = re.findall('Niveles construidos:(.+)Cocina:', DataT)
        #print(f"OK {CasasList[x]} corresponde a {x}")
        #Propiedades["Categoria"].append(Valores[0].getText().replace('\n', '').strip())
        Propiedades["Tipo"].append(data3['@type'])
        #print("OK Tipo")
        #Propiedades["V o R"].append()
        Propiedades["Pais"].append(data3['address']['addressCountry'])
        #print("OK Pais")
        Propiedades["Ciudad"].append(data3['address']['addressRegion'])
        #print("OK Ciudad")
        Propiedades["Municipio"].append(data3['address']['addressLocality'])
        #print("OK Municipio")
        Propiedades["Calle"].append(data3['address']['streetAddress'])
        #print("OK Calle")
        Propiedades["Codigo_Postal"].append(data3['address']['postalCode'])
        #print("OK Codigo Postal")
        Propiedades["Precio"].append(data3['potentialAction']['priceSpecification']['price'])
        #print("OK Precio")
        Propiedades["Moneda"].append(data3['potentialAction']['priceSpecification']['priceCurrency'])
        #print("OK Moneda")
        #Propiedades["Superficie_Total"].append()
        Propiedades["Superficie_Construida"].append(data3['floorSize'])
        #print("OK Sup Construida")
        Propiedades["Recamaras"].append(data3['numberOfRooms'])
        #print("OK Recamaras 1")
        #Propiedades["Banos"].append()
        #Propiedades["Estacionamientos"].append()
        Propiedades["DataT"].append(DataT)
        #print("OK DataT")
        Propiedades["Tipo2"].append(Tipo)
        #print("OK Tipo2")
        Propiedades["Precio2"].append(Precio)
        #print("OK Precio2")
        Propiedades["Superficie_Total2"].append(Terreno)
        #print("OK Terreno")
        Propiedades["Superficie_Construida2"].append(Construccion)
        #print("OK Construccion")
        Propiedades["Recamaras2"].append(Recamaras)
        #print("OK Recamaras")
        Propiedades["Banos2"].append(BanosC)
        #print("OK BanosC")
        Propiedades["MBanos"].append(MBanos)
        #print("OK MBanos")
        Propiedades["Estacionamientos2"].append(Estacionamientos)
        #print("OK Estacionamientos2")
        Propiedades["Niveles"].append(Niveles)
        #print("OK Niveles")
        Propiedades["CordA"].append(Coord4)
        #print("OK CordA")
        Propiedades["URL"].append(f'https://century21mexico.com{CasasList[x]}')
        print(f"OK {x} de {len(CasasList)}")
        
    except:
        print(f"Error Pagina {x}")
        pass

Propiedades_DF = pd.DataFrame(Propiedades)
Propiedades_DF.to_csv('Propiedades_DF.csv', index=False, encoding='utf-8-sig')
Propiedades_DF

# %%
# URL of page to be scraped
url = 'https://www.inmuebles24.com/inmuebles-en-venta-pagina-14139.html'

# %%
browser.visit(url)
time.sleep(2)  
html = browser.html
soup = bs(html,"html.parser")

# %%
soup

# %%
Casas = soup.findAll('h2', class_="posting-title")
TotalCasas = len(Casas)
TotalCasas

# %%
Data4 = Century.findAll('div', class_="col blackTxt border-right")
X = Data4[0].text
X

# %%
print(Data4[0].text)
print(Data4[1].text)
print(Data4[2].text)
print(Data4[3].text)

# %%
Data5 = Century.findAll('div', class_="col blackTxt")
X = Data5[0].text
X
#X = Data4[0].text
#X

# %%
data2 = Century.find('script', type='application/ld+json')
data2

# %%
data2_1 = str(data2)
data2_1

# %%
data2_1 = data2_1.replace('<script type="application/ld+json">\n', '').strip()
data2_1 = data2_1.replace('\n', '').strip()
data2_1 = data2_1.replace('\t', '').strip()
data2_1 = data2_1.replace('</script>', '').strip()
data2_1

# %%
data3 = json.loads(data2_1)
data3

# %%
print(f"Tipo {data3['@type']}")
print(f" Pais {data3['address']['addressCountry']}")
print(f"Estado {data3['address']['addressRegion']}")
print(f" Municipio {data3['address']['addressLocality']}")
print(f" Calle {data3['address']['streetAddress']}")
print(f" CP {data3['address']['postalCode']}")
print(f" Precio {data3['potentialAction']['priceSpecification']['price']}")
print(f" Moneda {data3['potentialAction']['priceSpecification']['priceCurrency']}")
print(f" Construccion {data3['floorSize']}")
print(f" Cuartos {data3['numberOfRooms']}")

# %%
Coord = Century.find('div', id='map-static')#.get('img')#, onclick=True)
#Coord = Century.getElementById('map-static').onclick.toString()
Coord

# %%
Coord2 = Century.find('img', class_="img-static-map").get('onclick')#, onclick=True)
#Coord = Century.getElementById('map-static').onclick.toString()
Coord2

# %%
Coord3 = Coord2.replace('myNavFunc(', '').strip()
Coord4 = Coord3.replace(')', '').strip()
Coord4

# %%
url

# %%
DataT = Century.find('div', class_="col-lg-6").text
DataT = DataT.replace('\n', '').strip()
#DataT = Century.findAll('i', class_="fal fa-tags")
DataT

# %%
Tipo = re.findall('Tipo:(.+)Precio de venta:', DataT)
Precio = re.findall('Precio de venta:(.+)Superficie de terreno:', DataT)
Terreno = re.findall('Superficie de terreno:(.+)Superficie de construcción:', DataT)
Construccion = re.findall('Superficie de construcción:(.+)Superficie de frente:', DataT)
Recamaras = re.findall('Recámaras:(.+)Baños completos:', DataT)
BanosC = re.findall('Baños completos:(.+)Medios Baños:', DataT)
MBanos = re.findall('Medios Baños:(.+)Estacionamientos:', DataT)
Estacionamientos = re.findall('Estacionamientos:(.+)Edad:', DataT)
Niveles = re.findall('Niveles construidos:(.+)Cocina:', DataT)
print(Tipo)
print(Precio)
print(Terreno)
print(Construccion)
print(Recamaras)
print(BanosC)
print(MBanos)
print(Estacionamientos)
print(Niveles)

# %%
Propiedades_DF = pd.DataFrame(Propiedades)
Propiedades_DF.to_csv('Propiedades_DF.csv', index=False, encoding='utf-8-sig')
Propiedades_DF

# %%
Recamaras

# %%
Century_request = requests.get(TEST)
Century = bs(Century_request.text, "html.parser")
time.sleep(4)
data2 = Century.find('script', type='application/ld+json')
data2_1 = str(data2)
data2_1 = data2_1.replace('<script type="application/ld+json">\n', '').strip()
data2_1 = data2_1.replace('\n', '').strip()
data2_1 = data2_1.replace('\t', '').strip()
data2_1 = data2_1.replace('</script>', '').strip()
data3 = json.loads(data2_1)
Coord2 = Century.find('img', class_="img-static-map")#.get('onclick')
#Coord3 = Coord2.replace('myNavFunc(', '').strip()
#Coord4 = Coord3.replace(')', '').strip()
DataT = Century.find('div', class_="col-lg-6").text
DataT = DataT.replace('\n', '').strip()
Tipo = re.findall('Tipo:(.+)Precio de venta:', DataT)
Precio = re.findall('Precio de venta:(.+)Superficie de terreno:', DataT)
Terreno = re.findall('Superficie de terreno:(.+)Superficie de construcción:', DataT)
Construccion = re.findall('Superficie de construcción:(.+)Superficie de frente:', DataT)
Recamaras = re.findall('Recámaras:(.+)Baños completos:', DataT)
BanosC = re.findall('Baños completos:(.+)Medios Baños:', DataT)
MBanos = re.findall('Medios Baños:(.+)Estacionamientos:', DataT)
Estacionamientos = re.findall('Estacionamientos:(.+)Edad:', DataT)
Niveles = re.findall('Niveles construidos:(.+)Cocina:', DataT)
print(f"OK")#{CasasList[x]} corresponde a {x}")

# %%
Casas2 = Century2.findAll('div', class_="row propiedades")
Casas2_1 = bs(Casas2.text, "html.parser")
Casas2_1
#Casas3 = Casas3.findAll('div', class_="card rounded-0")
#Casas3

# %%
#for Casas = Century2.findAll('div', class_="card rounded-0")
for Inmuebles1 in Century2.find_all('div', attrs={'class': 'row propiedades'}):
    for Inmuebles2 in Inmuebles1.find_all('div', attrs={'class': 'card rounded-0'}):
        Casas = Century2.find_all("div", attrs={'class': 'card rounded-0'})
#    for a in bar.find('p'):
#        print(a)  
Casas

# %%
Ciudades = ["Puebla",
            "Morelos",
            "estado-de-mexico",
            "distrito-federal",
            "Hidalgo"
           ]
Ciudades

# %%
PMin1 = "1000000"
PMax1 = "1249999"
PMin2 = "1250000"
PMax2 = "1499999"
PMin3 = "1500000"
PMax3 = "1749999"
PMin4 = "1750000"
PMax4 = "2000000"
Pagina = 1

# %%
##All Cities 1
for i in Ciudades:
    ciudad = i
    print(f"Inicia {ciudad}")
    URL = f"https://inmuebles.mercadolibre.com.mx/casas/venta/{ciudad}/_Desde_{Pagina}_OrderId_PRICE*DESC_PriceRange_{PMin1}-{PMax1}"
    browser.visit(URL)
    time.sleep(4)  
    html = browser.html
    soup = bs(html,"html.parser")
    ##Paginas a visitar##
    Paginas= []
    Casas = []
    ### Diccionario MORELOS ###
    Propiedades = {
        'Categoria':[],
        'Tipo':[],
        'V o R':[],
        'Propiedad':[],
        'Ciudad':[],
        'Municipio':[],
        'Colonia':[],
        'Precio':[],
        'Superficie total':[],
        'Superficie construida':[],
        'Recámaras':[],
        'Baños':[],
        'Estacionamientos':[],
        'CordA':[],
        'CordB':[],
        'CordC':[],
        'CordD':[],
        'CordE':[],
        'CordF':[],
        'CordG':[],
        'CordH':[],
        'CordI':[],
        'CordJ':[],
        'CordK':[],
        'CordL':[],
        'CordM':[],
        'CordN':[],
        'CordO':[],
        'CordP':[],
        'CordQ':[],
        'CordR':[],
        'CordS':[],
        'url':[]
    }
    
    for a in soup.find_all('a', class_="andes-pagination__link"):
        Paginas.append(a['href'])
    
    for x in Paginas:
        try:
            browser.visit(x)
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            for a in soup.find_all('a', class_="item__info-link"):
                Casas.append(a['href'])
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
    
    TotalCasas = len(Casas)
    print(f"Total de casas {TotalCasas} en {ciudad} ")
    
    for y in range(0, TotalCasas):
        try:
            browser.visit(Casas[y])
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            Valores = soup.findAll('a', class_="breadcrumb")
          
            price = soup.find('span', class_="price-tag-fraction").getText()  
            Caracteristicas = soup.findAll('li', class_="specs-item")
          
            Location = soup.findAll('img')
            CordA = Location[15]['src']
            CordB = Location[16]['src']
            CordC = Location[17]['src']
            try:
                CordD = Location[18]['src']
            except:
                pass
            try:
                CordE = Location[19]['src']
            except:
                pass
            try:
                CordF = Location[20]['src']
            except:
                pass
            try:
                CordG = Location[21]['src']
            except:
                pass
            try:
                CordH = Location[22]['src']
            except:
                pass
            try:
                CordI = Location[23]['src']
            except:
                pass
            try:
                CordJ = Location[24]['src']
            except:
                pass
            try:
                CordK = Location[25]['src']
            except:
                pass
            try:
                CordL = Location[26]['src']
            except:
                pass
            try:
                CordM = Location[27]['src']
            except:
                pass
            try:
                CordN = Location[28]['src']
            except:
                pass
            try:
                CordO = Location[28]['src']
            except:
                pass
            try:
                CordP = Location[29]['src']
            except:
                pass
            try:
                CordQ = Location[30]['src']
            except:
                pass
            try:
                CordR = Location[31]['src']
            except:
                pass
            try:
                CordS = Location[32]['src']
            except:
                pass
          
        
        
            Propiedades["Categoria"].append(Valores[0].getText().replace('\n', '').strip())
            Propiedades["Tipo"].append(Valores[1].getText().replace('\n', '').strip())
            Propiedades["V o R"].append(Valores[2].getText().replace('\n', '').strip())
            Propiedades["Propiedad"].append(Valores[3].getText().replace('\n', '').strip())
            Propiedades["Ciudad"].append(Valores[4].getText().replace('\n', '').strip())
            Propiedades["Municipio"].append(Valores[5].getText().replace('\n', '').strip())
            Propiedades["Colonia"].append(Valores[6].getText().replace('\n', '').strip())
            Propiedades["Precio"].append(price)
            Propiedades["Superficie total"].append(Caracteristicas[0].getText().replace('\n', '').strip())
            Propiedades["Superficie construida"].append(Caracteristicas[1].getText().replace('\n', '').strip())
            Propiedades["Recámaras"].append(Caracteristicas[2].getText().replace('\n', '').strip())
            Propiedades["Baños"].append(Caracteristicas[3].getText().replace('\n', '').strip())
            Propiedades["Estacionamientos"].append(Caracteristicas[4].getText().replace('\n', '').strip())
            Propiedades["CordA"].append(CordA)
            Propiedades["CordB"].append(CordB)
            Propiedades["CordC"].append(CordC)
            Propiedades["CordD"].append(CordD)
            Propiedades["CordE"].append(CordE)
            Propiedades["CordF"].append(CordF)
            Propiedades["CordG"].append(CordG)
            Propiedades["CordH"].append(CordH)
            Propiedades["CordI"].append(CordI)
            Propiedades["CordJ"].append(CordJ)
            Propiedades["CordK"].append(CordK)
            Propiedades["CordL"].append(CordL)
            Propiedades["CordM"].append(CordM)
            Propiedades["CordN"].append(CordN)
            Propiedades["CordO"].append(CordO)
            Propiedades["CordP"].append(CordP)
            Propiedades["CordQ"].append(CordQ)
            Propiedades["CordR"].append(CordR)
            Propiedades["CordS"].append(CordS)
            Propiedades["url"].append(Casas[y])            
            print(f"{y} de {ciudad}")
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
        
    Data_DF = pd.DataFrame.from_dict(Propiedades, orient='index').T
    Data_DF.to_csv(f'Propiedades{ciudad}1.csv', index=False, encoding='utf-8-sig')
     
    print(f"***FINAL {ciudad}***")

# %%
##All Cities 2
for i in Ciudades:
    ciudad = i
    print(f"Inicia {ciudad}")
    URL = f"https://inmuebles.mercadolibre.com.mx/casas/venta/{ciudad}/_Desde_{Pagina}_OrderId_PRICE*DESC_PriceRange_{PMin2}-{PMax2}"
    browser.visit(URL)
    time.sleep(4)  
    html = browser.html
    soup = bs(html,"html.parser")
    ##Paginas a visitar##
    Paginas= []
    Casas = []
    ### Diccionario MORELOS ###
    Propiedades = {
        'Categoria':[],
        'Tipo':[],
        'V o R':[],
        'Propiedad':[],
        'Ciudad':[],
        'Municipio':[],
        'Colonia':[],
        'Precio':[],
        'Superficie total':[],
        'Superficie construida':[],
        'Recámaras':[],
        'Baños':[],
        'Estacionamientos':[],
        'CordA':[],
        'CordB':[],
        'CordC':[],
        'CordD':[],
        'CordE':[],
        'CordF':[],
        'CordG':[],
        'CordH':[],
        'CordI':[],
        'CordJ':[],
        'CordK':[],
        'CordL':[],
        'CordM':[],
        'CordN':[],
        'CordO':[],
        'CordP':[],
        'CordQ':[],
        'CordR':[],
        'CordS':[],
        'url':[]
    }
    
    for a in soup.find_all('a', class_="andes-pagination__link"):
        Paginas.append(a['href'])
    
    for x in Paginas:
        try:
            browser.visit(x)
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            for a in soup.find_all('a', class_="item__info-link"):
                Casas.append(a['href'])
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
    
    TotalCasas = len(Casas)
    print(f"Total de casas {TotalCasas} en {ciudad} ")
    
    for y in range(0, TotalCasas):
        try:
            browser.visit(Casas[y])
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            Valores = soup.findAll('a', class_="breadcrumb")
          
            price = soup.find('span', class_="price-tag-fraction").getText()  
            Caracteristicas = soup.findAll('li', class_="specs-item")
          
            Location = soup.findAll('img')
            CordA = Location[15]['src']
            CordB = Location[16]['src']
            CordC = Location[17]['src']
            try:
                CordD = Location[18]['src']
            except:
                pass
            try:
                CordE = Location[19]['src']
            except:
                pass
            try:
                CordF = Location[20]['src']
            except:
                pass
            try:
                CordG = Location[21]['src']
            except:
                pass
            try:
                CordH = Location[22]['src']
            except:
                pass
            try:
                CordI = Location[23]['src']
            except:
                pass
            try:
                CordJ = Location[24]['src']
            except:
                pass
            try:
                CordK = Location[25]['src']
            except:
                pass
            try:
                CordL = Location[26]['src']
            except:
                pass
            try:
                CordM = Location[27]['src']
            except:
                pass
            try:
                CordN = Location[28]['src']
            except:
                pass
            try:
                CordO = Location[28]['src']
            except:
                pass
            try:
                CordP = Location[29]['src']
            except:
                pass
            try:
                CordQ = Location[30]['src']
            except:
                pass
            try:
                CordR = Location[31]['src']
            except:
                pass
            try:
                CordS = Location[32]['src']
            except:
                pass
          
        
        
            Propiedades["Categoria"].append(Valores[0].getText().replace('\n', '').strip())
            Propiedades["Tipo"].append(Valores[1].getText().replace('\n', '').strip())
            Propiedades["V o R"].append(Valores[2].getText().replace('\n', '').strip())
            Propiedades["Propiedad"].append(Valores[3].getText().replace('\n', '').strip())
            Propiedades["Ciudad"].append(Valores[4].getText().replace('\n', '').strip())
            Propiedades["Municipio"].append(Valores[5].getText().replace('\n', '').strip())
            Propiedades["Colonia"].append(Valores[6].getText().replace('\n', '').strip())
            Propiedades["Precio"].append(price)
            Propiedades["Superficie total"].append(Caracteristicas[0].getText().replace('\n', '').strip())
            Propiedades["Superficie construida"].append(Caracteristicas[1].getText().replace('\n', '').strip())
            Propiedades["Recámaras"].append(Caracteristicas[2].getText().replace('\n', '').strip())
            Propiedades["Baños"].append(Caracteristicas[3].getText().replace('\n', '').strip())
            Propiedades["Estacionamientos"].append(Caracteristicas[4].getText().replace('\n', '').strip())
            Propiedades["CordA"].append(CordA)
            Propiedades["CordB"].append(CordB)
            Propiedades["CordC"].append(CordC)
            Propiedades["CordD"].append(CordD)
            Propiedades["CordE"].append(CordE)
            Propiedades["CordF"].append(CordF)
            Propiedades["CordG"].append(CordG)
            Propiedades["CordH"].append(CordH)
            Propiedades["CordI"].append(CordI)
            Propiedades["CordJ"].append(CordJ)
            Propiedades["CordK"].append(CordK)
            Propiedades["CordL"].append(CordL)
            Propiedades["CordM"].append(CordM)
            Propiedades["CordN"].append(CordN)
            Propiedades["CordO"].append(CordO)
            Propiedades["CordP"].append(CordP)
            Propiedades["CordQ"].append(CordQ)
            Propiedades["CordR"].append(CordR)
            Propiedades["CordS"].append(CordS)
            Propiedades["url"].append(Casas[y])            
            print(f"{y} de {ciudad}")
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
        
    Data_DF = pd.DataFrame.from_dict(Propiedades, orient='index').T
    Data_DF.to_csv(f'Propiedades{ciudad}2.csv', index=False, encoding='utf-8-sig')
     
    print(f"***FINAL {ciudad}***")

# %%
##All Cities 3
for i in Ciudades:
    ciudad = i
    print(f"Inicia {ciudad}")
    URL = f"https://inmuebles.mercadolibre.com.mx/casas/venta/{ciudad}/_Desde_{Pagina}_OrderId_PRICE*DESC_PriceRange_{PMin3}-{PMax3}"
    browser.visit(URL)
    time.sleep(4)  
    html = browser.html
    soup = bs(html,"html.parser")
    ##Paginas a visitar##
    Paginas= []
    Casas = []
    ### Diccionario MORELOS ###
    Propiedades = {
        'Categoria':[],
        'Tipo':[],
        'V o R':[],
        'Propiedad':[],
        'Ciudad':[],
        'Municipio':[],
        'Colonia':[],
        'Precio':[],
        'Superficie total':[],
        'Superficie construida':[],
        'Recámaras':[],
        'Baños':[],
        'Estacionamientos':[],
        'CordA':[],
        'CordB':[],
        'CordC':[],
        'CordD':[],
        'CordE':[],
        'CordF':[],
        'CordG':[],
        'CordH':[],
        'CordI':[],
        'CordJ':[],
        'CordK':[],
        'CordL':[],
        'CordM':[],
        'CordN':[],
        'CordO':[],
        'CordP':[],
        'CordQ':[],
        'CordR':[],
        'CordS':[],
        'url':[]
    }
    
    for a in soup.find_all('a', class_="andes-pagination__link"):
        Paginas.append(a['href'])
    
    for x in Paginas:
        try:
            browser.visit(x)
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            for a in soup.find_all('a', class_="item__info-link"):
                Casas.append(a['href'])
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
    
    TotalCasas = len(Casas)
    print(f"Total de casas {TotalCasas} en {ciudad} ")
    
    for y in range(0, TotalCasas):
        try:
            browser.visit(Casas[y])
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            Valores = soup.findAll('a', class_="breadcrumb")
          
            price = soup.find('span', class_="price-tag-fraction").getText()  
            Caracteristicas = soup.findAll('li', class_="specs-item")
          
            Location = soup.findAll('img')
            CordA = Location[15]['src']
            CordB = Location[16]['src']
            CordC = Location[17]['src']
            try:
                CordD = Location[18]['src']
            except:
                pass
            try:
                CordE = Location[19]['src']
            except:
                pass
            try:
                CordF = Location[20]['src']
            except:
                pass
            try:
                CordG = Location[21]['src']
            except:
                pass
            try:
                CordH = Location[22]['src']
            except:
                pass
            try:
                CordI = Location[23]['src']
            except:
                pass
            try:
                CordJ = Location[24]['src']
            except:
                pass
            try:
                CordK = Location[25]['src']
            except:
                pass
            try:
                CordL = Location[26]['src']
            except:
                pass
            try:
                CordM = Location[27]['src']
            except:
                pass
            try:
                CordN = Location[28]['src']
            except:
                pass
            try:
                CordO = Location[28]['src']
            except:
                pass
            try:
                CordP = Location[29]['src']
            except:
                pass
            try:
                CordQ = Location[30]['src']
            except:
                pass
            try:
                CordR = Location[31]['src']
            except:
                pass
            try:
                CordS = Location[32]['src']
            except:
                pass
          
        
        
            Propiedades["Categoria"].append(Valores[0].getText().replace('\n', '').strip())
            Propiedades["Tipo"].append(Valores[1].getText().replace('\n', '').strip())
            Propiedades["V o R"].append(Valores[2].getText().replace('\n', '').strip())
            Propiedades["Propiedad"].append(Valores[3].getText().replace('\n', '').strip())
            Propiedades["Ciudad"].append(Valores[4].getText().replace('\n', '').strip())
            Propiedades["Municipio"].append(Valores[5].getText().replace('\n', '').strip())
            Propiedades["Colonia"].append(Valores[6].getText().replace('\n', '').strip())
            Propiedades["Precio"].append(price)
            Propiedades["Superficie total"].append(Caracteristicas[0].getText().replace('\n', '').strip())
            Propiedades["Superficie construida"].append(Caracteristicas[1].getText().replace('\n', '').strip())
            Propiedades["Recámaras"].append(Caracteristicas[2].getText().replace('\n', '').strip())
            Propiedades["Baños"].append(Caracteristicas[3].getText().replace('\n', '').strip())
            Propiedades["Estacionamientos"].append(Caracteristicas[4].getText().replace('\n', '').strip())
            Propiedades["CordA"].append(CordA)
            Propiedades["CordB"].append(CordB)
            Propiedades["CordC"].append(CordC)
            Propiedades["CordD"].append(CordD)
            Propiedades["CordE"].append(CordE)
            Propiedades["CordF"].append(CordF)
            Propiedades["CordG"].append(CordG)
            Propiedades["CordH"].append(CordH)
            Propiedades["CordI"].append(CordI)
            Propiedades["CordJ"].append(CordJ)
            Propiedades["CordK"].append(CordK)
            Propiedades["CordL"].append(CordL)
            Propiedades["CordM"].append(CordM)
            Propiedades["CordN"].append(CordN)
            Propiedades["CordO"].append(CordO)
            Propiedades["CordP"].append(CordP)
            Propiedades["CordQ"].append(CordQ)
            Propiedades["CordR"].append(CordR)
            Propiedades["CordS"].append(CordS)
            Propiedades["url"].append(Casas[y])            
            print(f"{y} de {ciudad}")
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass

    Data_DF = pd.DataFrame.from_dict(Propiedades, orient='index').T
    Data_DF.to_csv(f'Propiedades{ciudad}3.csv', index=False, encoding='utf-8-sig')
     
    print(f"***FINAL {ciudad}***")

# %%
##All Cities 4
for i in Ciudades:
    ciudad = i
    print(f"Inicia {ciudad}")
    URL = f"https://inmuebles.mercadolibre.com.mx/casas/venta/{ciudad}/_Desde_{Pagina}_OrderId_PRICE*DESC_PriceRange_{PMin4}-{PMax4}"
    browser.visit(URL)
    time.sleep(4)  
    html = browser.html
    soup = bs(html,"html.parser")
    ##Paginas a visitar##
    Paginas= []
    Casas = []
    ### Diccionario MORELOS ###
    Propiedades = {
        'Categoria':[],
        'Tipo':[],
        'V o R':[],
        'Propiedad':[],
        'Ciudad':[],
        'Municipio':[],
        'Colonia':[],
        'Precio':[],
        'Superficie total':[],
        'Superficie construida':[],
        'Recámaras':[],
        'Baños':[],
        'Estacionamientos':[],
        'CordA':[],
        'CordB':[],
        'CordC':[],
        'CordD':[],
        'CordE':[],
        'CordF':[],
        'CordG':[],
        'CordH':[],
        'CordI':[],
        'CordJ':[],
        'CordK':[],
        'CordL':[],
        'CordM':[],
        'CordN':[],
        'CordO':[],
        'CordP':[],
        'CordQ':[],
        'CordR':[],
        'CordS':[],
        'url':[]
    }
    
    for a in soup.find_all('a', class_="andes-pagination__link"):
        Paginas.append(a['href'])
    
    for x in Paginas:
        try:
            browser.visit(x)
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            for a in soup.find_all('a', class_="item__info-link"):
                Casas.append(a['href'])
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
    
    TotalCasas = len(Casas)
    print(f"Total de casas {TotalCasas} en {ciudad} ")
    
    for y in range(0, TotalCasas):
        try:
            browser.visit(Casas[y])
            time.sleep(4)  
            html = browser.html
            soup = bs(html,"html.parser")
            Valores = soup.findAll('a', class_="breadcrumb")
          
            price = soup.find('span', class_="price-tag-fraction").getText()  
            Caracteristicas = soup.findAll('li', class_="specs-item")
          
            Location = soup.findAll('img')
            CordA = Location[15]['src']
            CordB = Location[16]['src']
            CordC = Location[17]['src']
            try:
                CordD = Location[18]['src']
            except:
                pass
            try:
                CordE = Location[19]['src']
            except:
                pass
            try:
                CordF = Location[20]['src']
            except:
                pass
            try:
                CordG = Location[21]['src']
            except:
                pass
            try:
                CordH = Location[22]['src']
            except:
                pass
            try:
                CordI = Location[23]['src']
            except:
                pass
            try:
                CordJ = Location[24]['src']
            except:
                pass
            try:
                CordK = Location[25]['src']
            except:
                pass
            try:
                CordL = Location[26]['src']
            except:
                pass
            try:
                CordM = Location[27]['src']
            except:
                pass
            try:
                CordN = Location[28]['src']
            except:
                pass
            try:
                CordO = Location[28]['src']
            except:
                pass
            try:
                CordP = Location[29]['src']
            except:
                pass
            try:
                CordQ = Location[30]['src']
            except:
                pass
            try:
                CordR = Location[31]['src']
            except:
                pass
            try:
                CordS = Location[32]['src']
            except:
                pass
          
        
        
            Propiedades["Categoria"].append(Valores[0].getText().replace('\n', '').strip())
            Propiedades["Tipo"].append(Valores[1].getText().replace('\n', '').strip())
            Propiedades["V o R"].append(Valores[2].getText().replace('\n', '').strip())
            Propiedades["Propiedad"].append(Valores[3].getText().replace('\n', '').strip())
            Propiedades["Ciudad"].append(Valores[4].getText().replace('\n', '').strip())
            Propiedades["Municipio"].append(Valores[5].getText().replace('\n', '').strip())
            Propiedades["Colonia"].append(Valores[6].getText().replace('\n', '').strip())
            Propiedades["Precio"].append(price)
            Propiedades["Superficie total"].append(Caracteristicas[0].getText().replace('\n', '').strip())
            Propiedades["Superficie construida"].append(Caracteristicas[1].getText().replace('\n', '').strip())
            Propiedades["Recámaras"].append(Caracteristicas[2].getText().replace('\n', '').strip())
            Propiedades["Baños"].append(Caracteristicas[3].getText().replace('\n', '').strip())
            Propiedades["Estacionamientos"].append(Caracteristicas[4].getText().replace('\n', '').strip())
            Propiedades["CordA"].append(CordA)
            Propiedades["CordB"].append(CordB)
            Propiedades["CordC"].append(CordC)
            Propiedades["CordD"].append(CordD)
            Propiedades["CordE"].append(CordE)
            Propiedades["CordF"].append(CordF)
            Propiedades["CordG"].append(CordG)
            Propiedades["CordH"].append(CordH)
            Propiedades["CordI"].append(CordI)
            Propiedades["CordJ"].append(CordJ)
            Propiedades["CordK"].append(CordK)
            Propiedades["CordL"].append(CordL)
            Propiedades["CordM"].append(CordM)
            Propiedades["CordN"].append(CordN)
            Propiedades["CordO"].append(CordO)
            Propiedades["CordP"].append(CordP)
            Propiedades["CordQ"].append(CordQ)
            Propiedades["CordR"].append(CordR)
            Propiedades["CordS"].append(CordS)
            Propiedades["url"].append(Casas[y])            
            print(f"{y} de {ciudad}")
        except:
            print(f"Error Pagina {x} de {ciudad}")
            pass
    
    Data_DF = pd.DataFrame.from_dict(Propiedades, orient='index').T
    Data_DF.to_csv(f'Propiedades{ciudad}4.csv', index=False, encoding='utf-8-sig')
     
    print(f"***FINAL {ciudad}***")

# %%
##All Cities 4

ciudad = "tlaxcala"
print(f"Inicia {ciudad}")
URL = f"https://inmuebles.mercadolibre.com.mx/casas/venta/{ciudad}/_Desde_{Pagina}_OrderId_PRICE*DESC_PriceRange_{PMin1}-{PMax4}"
browser.visit(URL)
time.sleep(4)  
html = browser.html
soup = bs(html,"html.parser")
##Paginas a visitar##
Paginas= []
Casas = []
### Diccionario MORELOS ###
Propiedades = {
    'Categoria':[],
    'Tipo':[],
    'V o R':[],
    'Propiedad':[],
    'Ciudad':[],
    'Municipio':[],
    'Colonia':[],
    'Precio':[],
    'Superficie total':[],
    'Superficie construida':[],
    'Recámaras':[],
    'Baños':[],
    'Estacionamientos':[],
    'CordA':[],
    'CordB':[],
    'CordC':[],
    'CordD':[],
    'CordE':[],
    'CordF':[],
    'CordG':[],
    'CordH':[],
    'CordI':[],
    'CordJ':[],
    'CordK':[],
    'CordL':[],
    'CordM':[],
    'CordN':[],
    'CordO':[],
    'CordP':[],
    'CordQ':[],
    'CordR':[],
    'CordS':[],
    'url':[]
    }
    
for a in soup.find_all('a', class_="andes-pagination__link"):
    Paginas.append(a['href'])
    
for x in Paginas:
    try:
        browser.visit(x)
        time.sleep(4)  
        html = browser.html
        soup = bs(html,"html.parser")
        for a in soup.find_all('a', class_="item__info-link"):
            Casas.append(a['href'])
    except:
        print(f"Error Pagina {x} de {ciudad}")
        pass
    
TotalCasas = len(Casas)
print(f"Total de casas {TotalCasas} en {ciudad} ")
    
for y in range(0, TotalCasas):
    try:
        browser.visit(Casas[y])
        time.sleep(4)  
        html = browser.html
        soup = bs(html,"html.parser")
        Valores = soup.findAll('a', class_="breadcrumb")
          
        price = soup.find('span', class_="price-tag-fraction").getText()  
        Caracteristicas = soup.findAll('li', class_="specs-item")
          
        Location = soup.findAll('img')
        CordA = Location[15]['src']
        CordB = Location[16]['src']
        CordC = Location[17]['src']
        try:
            CordD = Location[18]['src']
        except:
            pass
        try:
            CordE = Location[19]['src']
        except:
            pass
        try:
            CordF = Location[20]['src']
        except:
            pass
        try:
            CordG = Location[21]['src']
        except:
            pass
        try:
            CordH = Location[22]['src']
        except:
            pass
        try:
            CordI = Location[23]['src']
        except:
            pass
        try:
            CordJ = Location[24]['src']
        except:
            pass
        try:
            CordK = Location[25]['src']
        except:
            pass
        try:
            CordL = Location[26]['src']
        except:
            pass
        try:
            CordM = Location[27]['src']
        except:
            pass
        try:
            CordN = Location[28]['src']
        except:
            pass
        try:
            CordO = Location[28]['src']
        except:
            pass
        try:
            CordP = Location[29]['src']
        except:
            pass
        try:
            CordQ = Location[30]['src']
        except:
            pass
        try:
            CordR = Location[31]['src']
        except:
            pass
        try:
            CordS = Location[32]['src']
        except:
            pass
          
        
        
        Propiedades["Categoria"].append(Valores[0].getText().replace('\n', '').strip())
        Propiedades["Tipo"].append(Valores[1].getText().replace('\n', '').strip())
        Propiedades["V o R"].append(Valores[2].getText().replace('\n', '').strip())
        Propiedades["Propiedad"].append(Valores[3].getText().replace('\n', '').strip())
        Propiedades["Ciudad"].append(Valores[4].getText().replace('\n', '').strip())
        Propiedades["Municipio"].append(Valores[5].getText().replace('\n', '').strip())
        Propiedades["Colonia"].append(Valores[6].getText().replace('\n', '').strip())
        Propiedades["Precio"].append(price)
        Propiedades["Superficie total"].append(Caracteristicas[0].getText().replace('\n', '').strip())
        Propiedades["Superficie construida"].append(Caracteristicas[1].getText().replace('\n', '').strip())
        Propiedades["Recámaras"].append(Caracteristicas[2].getText().replace('\n', '').strip())
        Propiedades["Baños"].append(Caracteristicas[3].getText().replace('\n', '').strip())
        Propiedades["Estacionamientos"].append(Caracteristicas[4].getText().replace('\n', '').strip())
        Propiedades["CordA"].append(CordA)
        Propiedades["CordB"].append(CordB)
        Propiedades["CordC"].append(CordC)
        Propiedades["CordD"].append(CordD)
        Propiedades["CordE"].append(CordE)
        Propiedades["CordF"].append(CordF)
        Propiedades["CordG"].append(CordG)
        Propiedades["CordH"].append(CordH)
        Propiedades["CordI"].append(CordI)
        Propiedades["CordJ"].append(CordJ)
        Propiedades["CordK"].append(CordK)
        Propiedades["CordL"].append(CordL)
        Propiedades["CordM"].append(CordM)
        Propiedades["CordN"].append(CordN)
        Propiedades["CordO"].append(CordO)
        Propiedades["CordP"].append(CordP)
        Propiedades["CordQ"].append(CordQ)
        Propiedades["CordR"].append(CordR)
        Propiedades["CordS"].append(CordS)
        Propiedades["url"].append(Casas[y])            
        print(f"{y} de {ciudad}")
    except:
        print(f"Error Pagina {x} de {ciudad}")
        pass
    
Data_DF = pd.DataFrame.from_dict(Propiedades, orient='index').T
Data_DF.to_csv(f'Propiedades{ciudad}4.csv', index=False, encoding='utf-8-sig')
     
print(f"***FINAL {ciudad}***")
